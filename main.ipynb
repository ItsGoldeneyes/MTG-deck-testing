# %%
import pandas as pd
import itertools

import os
import shutil

from dotenv import load_dotenv
load_dotenv()
os.environ['FORGE_JAR_PATH'] = os.getenv('FORGE_JAR_PATH', '')

# %% [markdown]
# ### Helper Functions

# %% [markdown]
# #### Decklist Generation

# %%
def generate_decklists(cards_df):
    """
    Creates all possible Jumpstart decks (two half decks put together), then generates output .dck files for use in Forge

    Args:
        cards_df (DataFrame): Dataframe containing cards categorized into decks

    Returns:
        String: Path to output folder
    """
    deck_names = cards_df['deck'].unique()
    deck_combinations = itertools.combinations(deck_names, 2)
    output_path = os.path.join('output', 'jumpstart')

    for deck1_name, deck2_name in deck_combinations:
        deck1 = cards_df[cards_df['deck'] == deck1_name]
        deck2 = cards_df[cards_df['deck'] == deck2_name]
        deck = pd.concat([deck1, deck2])

        generate_deck_file(deck, deck1_name+" "+deck2_name, output_path)

    return output_path


def generate_deck_file(deck, name='Sample Deck', output_path='output/jumpstart'):
    """
    Saves deck as a .dck file for Forge

    Args:
        deck (DataFrame): Dataframe containing cards in a deck
        name (String): Deck name
        output_path (String): Path to output folder
    """
    os.makedirs(output_path, exist_ok=True)

    with open(os.path.join(output_path, f"{name}.dck"), 'w') as f:
        f.write('[metadata]\n')
        f.write(f'Name={name}\n')
        f.write('[Avatar]\n\n')
        f.write('[Main]\n')
        for _, row in deck.iterrows():
            set_code = row['set_code'] if row['set_code'] else ''
            f.write(f"{row['quantity']} {row['name']}|{set_code}|1\n")

        f.write('[Sideboard]\n\n')
        f.write('[Planes]\n\n')
        f.write('[Schemes]\n\n')
        f.write('[Conspiracy]\n\n')
        f.write('[Dungeon]')


def add_lands(cards_df):
    """
    Adds lands to decks that do not have lands. Tedious to do in Archidekt, so it's automated!

    Args:
        cards_df (DataFrame): Dataframe containing cards categorized into decks

    Returns:
        DataFrame: Dataframe containing cards categorized into decks, with added lands
    """
    deck_names = cards_df['deck'].unique()
    lands = {
        'W': [
            {
                'quantity': '7',
                'name':     'Plains',
                'set_code': 'JMP',
                'tag':      'Land',
            },
            {
                'quantity': '1',
                'name':     'Thriving Heath',
                'set_code': 'JMP',
                'tag':      'Land'
            }
        ],
        'U': [
            {
                'quantity': '7',
                'name':     'Island',
                'set_code': 'JMP',
                'tag':      'Land'
            },
            {
                'quantity': '1',
                'name':     'Thriving Isle',
                'set_code': 'JMP',
                'tag':      'Land'
            }
        ],
        'B': [
            {
                'quantity': '7',
                'name':     'Swamp',
                'set_code': 'JMP',
                'tag':      'Land'
            },
            {
                'quantity': '1',
                'name':     'Thriving Moor',
                'set_code': 'JMP',
                'tag':      'Land'
            }
        ],
        'R': [
            {
                'quantity': '7',
                'name':     'Mountain',
                'set_code': 'JMP',
                'tag':      'Land'
            },
            {
                'quantity': '1',
                'name':     'Thriving Bluff',
                'set_code': 'JMP',
                'tag':      'Land'
            }
        ],
        'G': [
            {
                'quantity': '7',
                'name':     'Forest',
                'set_code': 'JMP',
                'tag':      'Land'
            },
            {
                'quantity': '1',
                'name':     'Thriving Grove',
                'set_code': 'JMP',
                'tag':      'Land'
            }
        ],
    }

    for deck in deck_names:
        deck_df = cards_df[cards_df['deck'] == deck]
        colour = deck_df['colour'].iloc[0]

        if deck_df[deck_df['name'].isin(['Plains', 'Island', 'Swamp', 'Mountain', 'Forest'])].empty:
            lands_df = pd.DataFrame.from_dict(lands[colour])
            lands_df['deck'] = deck

            cards_df = pd.concat([cards_df, lands_df])


    return cards_df


def parse_card(card):
    """
    Parses an individual card line from input CSV

    Args:
        card (String): Individual card line from CSV

    Returns:
        Dictionary: Card line parsed into dictionary
    """
    split_card = card.split()

    card_dict = {
        'quantity': '',
        'name':     '',
        'colour':   '',
        'set_code': '',
        'deck':     '',
        'tag':      '',
    }

    card_dict['quantity'] = split_card[0].split('x')[0]

    step = 0
    for index, word in enumerate(split_card[1:]):
        if step == 0 and '(' not in word:
            card_dict['name'] = card_dict['name'] + ' ' + word
        elif step == 0:
            step = 1

        if step == 1:
            card_dict['set_code'] = card_dict['set_code'] + ' ' + word.strip('()').upper()
            if ')' in word:
                step = 2
                continue

        if step == 2:
            deck_name = word.strip('[]')
            card_dict['deck'] = card_dict['deck'] + ' ' + deck_name
            if ' - ' in card_dict['deck']:
                card_dict['colour'] = card_dict['deck'].split(' - ')[0].strip()
                card_dict['deck'] = card_dict['deck'].split(' - ')[1].strip()
            if ']' in word:
                step = 3
            continue

        if step == 3:
            card_dict['tag'] = word.split(',')[0].strip('^')

    for key in card_dict:
        card_dict[key] = card_dict[key].strip().replace('/', '')

    return card_dict


def parse_decks(cards):
    """
    Parses an input CSV

    Args:
        cards (List): List of card lines from CSV

    Returns:
        DataFrame: All cards processed
    """
    card_list = [parse_card(card) for card in cards]
    cards_df = pd.DataFrame.from_dict(card_list)

    return cards_df

# %% [markdown]
# ### Running Games

# %%
import subprocess
import concurrent.futures
from threading import Lock
import time

# %%
# Global lock for thread-safe operations if needed
game_lock = Lock()

def run_game(deck1_name, deck2_name, num_games=1, working_dir=None):
    """
    Run a single game between two decks

    Args:
        deck1_name (str): Name of the first deck
        deck2_name (str): Name of the second deck
        num_games (int): Number of games to run (default 1)
        working_dir (str): Working directory for the Java process

    Returns:
        subprocess.CompletedProcess: Game output
    """
    if working_dir is None:
        working_dir = os.path.dirname(os.environ.get("FORGE_JAR_PATH", ""))

    original_cwd = os.getcwd()
    try:
        if working_dir:
            os.chdir(working_dir)

        game_output = subprocess.run([
            "java", "-jar", os.path.basename(os.environ.get("FORGE_JAR_PATH", "")),
            "sim", "-d",
            os.path.join("JUMPSTART", f"{deck1_name}.dck"),
            os.path.join("JUMPSTART", f"{deck2_name}.dck"),
            "-m", str(num_games),
            "-q"
        ], capture_output=True, text=True, timeout=120)

        return game_output
    finally:
        os.chdir(original_cwd)

def run_games_multithreaded(deck_pairs, num_games_per_pair=10, max_workers=4):
    """
    Run multiple games concurrently using ThreadPoolExecutor

    Args:
        deck_pairs (list): List of tuples containing (deck1_name, deck2_name)
        num_games_per_pair (int): Number of games to run for each deck pair
        max_workers (int): Maximum number of concurrent threads

    Returns:
        list: List of results for each game
    """
    results = []

    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit all games to the thread pool
        future_to_decks = {}

        for deck1, deck2 in deck_pairs:
            future = executor.submit(run_game, deck1, deck2, num_games_per_pair)
            future_to_decks[future] = (deck1, deck2)

        # Collect results as they complete
        for future in concurrent.futures.as_completed(future_to_decks):
            deck1, deck2 = future_to_decks[future]
            try:
                result = future.result()
                results.append({
                    'deck1': deck1,
                    'deck2': deck2,
                    'result': result,
                    'success': result.returncode == 0
                })
                print(f"Completed: {deck1} vs {deck2}")
            except Exception as exc:
                print(f"Game {deck1} vs {deck2} generated an exception: {exc}")
                results.append({
                    'deck1': deck1,
                    'deck2': deck2,
                    'result': None,
                    'success': False,
                    'error': str(exc)
                })

    return results

def run_games_batch(deck_pairs, num_games_per_pair=10, max_workers=4, batch_size=None):
    """
    Run games in batches to avoid overwhelming the system

    Args:
        deck_pairs (list): List of tuples containing (deck1_name, deck2_name)
        num_games_per_pair (int): Number of games to run for each deck pair
        max_workers (int): Maximum number of concurrent threads
        batch_size (int): Number of deck pairs to process in each batch (default: max_workers * 2)

    Returns:
        list: List of results for all games
    """
    if batch_size is None:
        batch_size = max_workers * 2

    all_results = []

    for i in range(0, len(deck_pairs), batch_size):
        batch = deck_pairs[i:i + batch_size]
        print(f"Processing batch {i//batch_size + 1}/{(len(deck_pairs) + batch_size - 1)//batch_size}")

        batch_results = run_games_multithreaded(batch, num_games_per_pair, max_workers)
        all_results.extend(batch_results)

        # Optional: Add a small delay between batches to prevent system overload
        time.sleep(0.5)

    return all_results

# %%
# Example usage functions

def get_all_deck_combinations():
    """
    Get all possible deck combinations from the output directory
    Each .dck file is a complete deck, so we create pairs of these decks to battle against each other

    Returns:
        list: List of tuples containing (deck1_name, deck2_name) where each name is a complete deck file name (without .dck extension)
    """
    jumpstart_dir = os.path.join('output', 'jumpstart')
    if not os.path.exists(jumpstart_dir):
        return []

    # Get all deck file names (without .dck extension)
    deck_names = [f[:-4] for f in os.listdir(jumpstart_dir) if f.endswith('.dck')]

    # deck_names = [name for name in deck_names if 'living' in name.lower() or 'dragons' in name.lower()]

    # Create all possible combinations of decks to battle against each other
    deck_pairs = []
    for i, deck1 in enumerate(deck_names):
        for deck2 in deck_names[i+1:]:  # Avoid duplicates and self-matches
            deck_pairs.append((deck1, deck2))

    return deck_pairs

def get_sample_deck_combinations(num_combinations=10):
    """
    Get a sample of deck combinations for testing

    Args:
        num_combinations (int): Number of random combinations to return

    Returns:
        list: List of tuples containing (deck1_name, deck2_name)
    """
    import random
    all_combinations = get_all_deck_combinations()

    if len(all_combinations) <= num_combinations:
        return all_combinations

    return random.sample(all_combinations, num_combinations)

def evaluate_all_decks_multithreaded(num_games=10, max_workers=4):
    """
    Evaluate all deck combinations using multithreading

    Args:
        num_games (int): Number of games to run for each deck pair
        max_workers (int): Maximum number of concurrent threads

    Returns:
        list: Results from all games
    """
    deck_pairs = get_all_deck_combinations()
    print(f"Found {len(deck_pairs)} deck combinations to evaluate")

    if not deck_pairs:
        print("No deck combinations found. Make sure decks have been generated first.")
        return []

    print(f"Running {num_games} games per combination with {max_workers} workers...")
    start_time = time.time()

    results = run_games_batch(deck_pairs, num_games, max_workers)

    end_time = time.time()
    print(f"Completed in {end_time - start_time:.2f} seconds")

    # Summary statistics
    successful_games = sum(1 for r in results if r['success'])
    failed_games = len(results) - successful_games

    print(f"Results: {successful_games} successful, {failed_games} failed")

    return results

def evaluate_sample_decks_multithreaded(num_combinations=10, num_games=10, max_workers=4):
    """
    Evaluate a sample of deck combinations using multithreading (useful for testing)

    Args:
        num_combinations (int): Number of random deck combinations to test
        num_games (int): Number of games to run for each deck pair
        max_workers (int): Maximum number of concurrent threads

    Returns:
        list: Results from all games
    """
    deck_pairs = get_sample_deck_combinations(num_combinations)
    print(f"Testing {len(deck_pairs)} random deck combinations")

    if not deck_pairs:
        print("No deck combinations found. Make sure decks have been generated first.")
        return []

    print(f"Running {num_games} games per combination with {max_workers} workers...")
    start_time = time.time()

    results = run_games_batch(deck_pairs, num_games, max_workers)

    end_time = time.time()
    print(f"Completed in {end_time - start_time:.2f} seconds")

    # Summary statistics
    successful_games = sum(1 for r in results if r['success'])
    failed_games = len(results) - successful_games

    print(f"Results: {successful_games} successful, {failed_games} failed")

    return results

def parse_game_results(results):
    """
    Parse game results to extract win rates and statistics, creating one row per deck

    Args:
        results (list): Results from run_games_multithreaded or run_games_batch

    Returns:
        pandas.DataFrame: DataFrame with one row per deck including wins, winrate, and turn count statistics
    """
    from statistics import mode, median

    # First, parse individual game results
    game_data = []

    for result in results:
        if result['success'] and result['result']:
            output = result['result'].stdout
            lines = output.strip().split('\n')

            wins_deck1 = 0
            wins_deck2 = 0
            total_games = 0
            turn_counts = []

            for line in lines:
                if 'game outcome: turn' in line.lower():
                    try:
                        turn_count = int(line.lower().split()[-1])
                        turn_counts.append(turn_count)
                    except (ValueError, IndexError):
                        pass

                if 'won!' in line.lower():
                    total_games += 1
                    if result['deck1'].lower() in line.lower():
                        wins_deck1 += 1
                    elif result['deck2'].lower() in line.lower():
                        wins_deck2 += 1

            # Add data for each deck in this matchup
            if total_games > 0:
                avg_turns = sum(turn_counts) / len(turn_counts) if turn_counts else 0
                median_turns = median(turn_counts) if turn_counts else 0
                try:
                    mode_turns = mode(turn_counts) if turn_counts else 0
                except:
                    mode_turns = turn_counts[0] if turn_counts else 0

                # Add deck1 data
                game_data.append({
                    'deck': result['deck1'],
                    'wins': wins_deck1,
                    'losses': wins_deck2,
                    'total_games': total_games,
                    'avg_turns': avg_turns,
                    'median_turns': median_turns,
                    'mode_turns': mode_turns
                })

                # Add deck2 data
                game_data.append({
                    'deck': result['deck2'],
                    'wins': wins_deck2,
                    'losses': wins_deck1,
                    'total_games': total_games,
                    'avg_turns': avg_turns,
                    'median_turns': median_turns,
                    'mode_turns': mode_turns
                })

    if not game_data:
        return pd.DataFrame()

    # Convert to DataFrame for easier aggregation
    df = pd.DataFrame(game_data)

    # Aggregate by deck name
    deck_summary = df.groupby('deck').agg({
        'wins': 'sum',
        'losses': 'sum',
        'total_games': 'sum',
        'avg_turns': 'mean',
        'median_turns': 'mean',
        'mode_turns': 'mean'
    }).reset_index()

    # Calculate win rate
    deck_summary['winrate'] = deck_summary['wins'] / deck_summary['total_games']
    deck_summary['winrate'] = deck_summary['winrate'].round(4)

    # Round turn statistics
    deck_summary['avg_turns'] = deck_summary['avg_turns'].round(2)
    deck_summary['median_turns'] = deck_summary['median_turns'].round(2)
    deck_summary['mode_turns'] = deck_summary['mode_turns'].round(2)

    # Sort by win rate (descending)
    deck_summary = deck_summary.sort_values('winrate', ascending=False).reset_index(drop=True)

    # Reorder columns for better readability
    deck_summary = deck_summary[['deck', 'wins', 'losses', 'total_games', 'winrate',
                                'avg_turns', 'median_turns', 'mode_turns']]

    print(f"\nDeck Performance Summary:")
    print(f"Total decks analyzed: {len(deck_summary)}")
    print(f"Best performing deck: {deck_summary.iloc[0]['deck']} ({deck_summary.iloc[0]['winrate']:.2%} win rate)")
    print(f"Worst performing deck: {deck_summary.iloc[-1]['deck']} ({deck_summary.iloc[-1]['winrate']:.2%} win rate)")

    return deck_summary

# %% [markdown]
# ### Process Decks

# %%
with open('input/jumpstart.txt', 'r') as file:
    cards = file.readlines()

cards_df = parse_decks(cards)
cards_df = add_lands(cards_df)

assert len(cards_df['deck'].unique()) == cards_df['quantity'].astype(int).sum() // 20, "Deck count does not match expected value (cards/20)"

deck_path = generate_decklists(cards_df)
forge_path = os.getenv("FORGE_DECKS_PATH")

# Clear the folder at FORGE_PATH
if forge_path and os.path.exists(forge_path):
    for filename in os.listdir(forge_path):
        file_path = os.path.join(forge_path, filename)
        if os.path.isfile(file_path) or os.path.islink(file_path):
            os.unlink(file_path)
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)

# Copy contents of deck_path to FORGE_PATH
if forge_path and os.path.exists(deck_path):
    for filename in os.listdir(deck_path):
        src_file = os.path.join(deck_path, filename)
        dst_file = os.path.join(forge_path, filename)
        shutil.copy2(src_file, dst_file)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 5
#       2     cards = file.readlines()
#       4 cards_df = parse_decks(cards)
# ----> 5 cards_df = add_lands(cards_df)
#       7 assert len(cards_df['deck'].unique()) == cards_df['quantity'].astype(int).sum() // 20, "Deck count does not match expected value (cards/20)"
#       9 deck_path = generate_decklists(cards_df)
#
# Cell In[30], line 141, in add_lands(cards_df)
#     138 colour = deck_df['colour'].iloc[0]
#     140 if deck_df[deck_df['name'].isin(['Plains', 'Island', 'Swamp', 'Mountain', 'Forest'])].empty:
# --> 141     lands_df = pd.DataFrame.from_dict(lands[colour])
#     142     lands_df['deck'] = deck
#     144     cards_df = pd.concat([cards_df, lands_df])
#
# KeyError: 'Sideboard{noDeck}{noPrice},G'

# %% [markdown]
# ### Run Games

# %%
all_results = evaluate_all_decks_multithreaded(num_games=2, max_workers=6)
# Out:
# Found 2145 deck combinations to evaluate
# Running 2 games per combination with 6 workers...
# Processing batch 1/179
# Completed: Aggressive Bloodthirsty vs Aggressive Dragons
# Completed: Aggressive Bloodthirsty vs Aggressive Gambling
# Completed: Aggressive Bloodthirsty vs Aggressive Living
# Completed: Aggressive Bloodthirsty vs Aggressive Goblins
# Completed: Aggressive Bloodthirsty vs Aggressive Morbid
# Completed: Aggressive Bloodthirsty vs Aggressive Plundering
# Completed: Aggressive Bloodthirsty vs Aggressive Stompy
# Completed: Aggressive Bloodthirsty vs Aggressive Necromancy
# Completed: Aggressive Bloodthirsty vs Bloodthirsty Dragons
# Completed: Aggressive Bloodthirsty vs Bloodthirsty Morbid
# Completed: Aggressive Bloodthirsty vs Bloodthirsty Elvish
# Game Aggressive Bloodthirsty vs Aggressive Elvish generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Bloodthirsty.dck', 'JUMPSTART\\Aggressive Elvish.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 2/179
# Completed: Aggressive Bloodthirsty vs Elvish Dragons
# Completed: Aggressive Bloodthirsty vs Elvish Stompy
# Completed: Aggressive Bloodthirsty vs Dragons Morbid
# Completed: Aggressive Bloodthirsty vs Gambling Bloodthirsty
# Completed: Aggressive Bloodthirsty vs Bloodthirsty Stompy
# Completed: Aggressive Bloodthirsty vs Gambling Dragons
# Completed: Aggressive Bloodthirsty vs Elvish Morbid
# Completed: Aggressive Bloodthirsty vs Gambling Goblins
# Completed: Aggressive Bloodthirsty vs Gambling Stompy
# Completed: Aggressive Bloodthirsty vs Gambling Necromancy
# Completed: Aggressive Bloodthirsty vs Gambling Morbid
# Game Aggressive Bloodthirsty vs Gambling Elvish generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Bloodthirsty.dck', 'JUMPSTART\\Gambling Elvish.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 3/179
# Completed: Aggressive Bloodthirsty vs Goblins Bloodthirsty
# Completed: Aggressive Bloodthirsty vs Goblins Stompy
# Completed: Aggressive Bloodthirsty vs Goblins Morbid
# Completed: Aggressive Bloodthirsty vs Goblins Dragons
# Completed: Aggressive Bloodthirsty vs Goblins Elvish
# Completed: Aggressive Bloodthirsty vs Goblins Necromancy
# Completed: Aggressive Bloodthirsty vs Growth Bloodthirsty
# Completed: Aggressive Bloodthirsty vs Growth Aggressive
# Completed: Aggressive Bloodthirsty vs Growth Dragons
# Completed: Aggressive Bloodthirsty vs Growth Gambling
# Completed: Aggressive Bloodthirsty vs Growth Goblins
# Completed: Aggressive Bloodthirsty vs Growth Elvish
# Processing batch 4/179
# Completed: Aggressive Bloodthirsty vs Growth Necromancy
# Completed: Aggressive Bloodthirsty vs Growth Plundering
# Completed: Aggressive Bloodthirsty vs Living Bloodthirsty
# Completed: Aggressive Bloodthirsty vs Growth Stompy
# Completed: Aggressive Bloodthirsty vs Growth Morbid
# Completed: Aggressive Bloodthirsty vs Growth Living
# Completed: Aggressive Bloodthirsty vs Living Dragons
# Completed: Aggressive Bloodthirsty vs Living Elvish
# Completed: Aggressive Bloodthirsty vs Living Gambling
# Completed: Aggressive Bloodthirsty vs Living Necromancy
# Completed: Aggressive Bloodthirsty vs Living Goblins
# Completed: Aggressive Bloodthirsty vs Living Morbid
# Processing batch 5/179
# Completed: Aggressive Bloodthirsty vs Necromancy Stompy
# Completed: Aggressive Bloodthirsty vs Necromancy Dragons
# Completed: Aggressive Bloodthirsty vs Living Stompy
# Completed: Aggressive Bloodthirsty vs Necromancy Morbid
# Completed: Aggressive Bloodthirsty vs Necromancy Bloodthirsty
# Completed: Aggressive Bloodthirsty vs Plundering Bloodthirsty
# Completed: Aggressive Bloodthirsty vs Necromancy Elvish
# Completed: Aggressive Bloodthirsty vs Plundering Dragons
# Completed: Aggressive Bloodthirsty vs Plundering Gambling
# Completed: Aggressive Bloodthirsty vs Plundering Elvish
# Completed: Aggressive Bloodthirsty vs Plundering Living
# Game Aggressive Bloodthirsty vs Plundering Goblins generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Bloodthirsty.dck', 'JUMPSTART\\Plundering Goblins.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 6/179
# Completed: Aggressive Bloodthirsty vs Stompy Morbid
# Completed: Aggressive Bloodthirsty vs Stompy Dragons
# Completed: Aggressive Bloodthirsty vs Plundering Morbid
# Completed: Aggressive Dragons vs Aggressive Elvish
# Completed: Aggressive Bloodthirsty vs Plundering Necromancy
# Completed: Aggressive Dragons vs Aggressive Gambling
# Completed: Aggressive Bloodthirsty vs Plundering Stompy
# Completed: Aggressive Dragons vs Aggressive Goblins
# Completed: Aggressive Dragons vs Aggressive Morbid
# Completed: Aggressive Dragons vs Aggressive Living
# Completed: Aggressive Dragons vs Aggressive Necromancy
# Completed: Aggressive Dragons vs Aggressive Plundering
# Processing batch 7/179
# Completed: Aggressive Dragons vs Bloodthirsty Stompy
# Completed: Aggressive Dragons vs Bloodthirsty Morbid
# Completed: Aggressive Dragons vs Bloodthirsty Dragons
# Completed: Aggressive Dragons vs Dragons Morbid
# Completed: Aggressive Dragons vs Bloodthirsty Elvish
# Completed: Aggressive Dragons vs Aggressive Stompy
# Completed: Aggressive Dragons vs Elvish Dragons
# Completed: Aggressive Dragons vs Elvish Morbid
# Completed: Aggressive Dragons vs Gambling Bloodthirsty
# Completed: Aggressive Dragons vs Gambling Dragons
# Completed: Aggressive Dragons vs Elvish Stompy
# Completed: Aggressive Dragons vs Gambling Elvish
# Processing batch 8/179
# Completed: Aggressive Dragons vs Gambling Stompy
# Completed: Aggressive Dragons vs Goblins Bloodthirsty
# Completed: Aggressive Dragons vs Gambling Necromancy
# Completed: Aggressive Dragons vs Gambling Morbid
# Completed: Aggressive Dragons vs Goblins Dragons
# Completed: Aggressive Dragons vs Gambling Goblins
# Completed: Aggressive Dragons vs Goblins Elvish
# Completed: Aggressive Dragons vs Goblins Stompy
# Completed: Aggressive Dragons vs Growth Bloodthirsty
# Completed: Aggressive Dragons vs Growth Aggressive
# Completed: Aggressive Dragons vs Goblins Morbid
# Game Aggressive Dragons vs Goblins Necromancy generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Dragons.dck', 'JUMPSTART\\Goblins Necromancy.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 9/179
# Completed: Aggressive Dragons vs Growth Goblins
# Completed: Aggressive Dragons vs Growth Dragons
# Completed: Aggressive Dragons vs Growth Gambling
# Completed: Aggressive Dragons vs Growth Elvish
# Completed: Aggressive Dragons vs Growth Morbid
# Completed: Aggressive Dragons vs Growth Living
# Completed: Aggressive Dragons vs Growth Stompy
# Completed: Aggressive Dragons vs Growth Necromancy
# Completed: Aggressive Dragons vs Growth Plundering
# Completed: Aggressive Dragons vs Living Dragons
# Completed: Aggressive Dragons vs Living Elvish
# Completed: Aggressive Dragons vs Living Bloodthirsty
# Processing batch 10/179
# Completed: Aggressive Dragons vs Necromancy Bloodthirsty
# Completed: Aggressive Dragons vs Living Goblins
# Completed: Aggressive Dragons vs Living Gambling
# Completed: Aggressive Dragons vs Living Necromancy
# Completed: Aggressive Dragons vs Living Stompy
# Completed: Aggressive Dragons vs Living Morbid
# Completed: Aggressive Dragons vs Necromancy Dragons
# Completed: Aggressive Dragons vs Necromancy Stompy
# Completed: Aggressive Dragons vs Necromancy Morbid
# Completed: Aggressive Dragons vs Plundering Bloodthirsty
# Completed: Aggressive Dragons vs Plundering Dragons
# Completed: Aggressive Dragons vs Necromancy Elvish
# Processing batch 11/179
# Completed: Aggressive Dragons vs Plundering Living
# Completed: Aggressive Dragons vs Plundering Elvish
# Completed: Aggressive Dragons vs Plundering Gambling
# Completed: Aggressive Dragons vs Plundering Necromancy
# Completed: Aggressive Dragons vs Plundering Morbid
# Completed: Aggressive Dragons vs Plundering Goblins
# Completed: Aggressive Dragons vs Plundering Stompy
# Completed: Aggressive Dragons vs Stompy Morbid
# Completed: Aggressive Dragons vs Stompy Dragons
# Completed: Aggressive Elvish vs Aggressive Gambling
# Game Aggressive Elvish vs Aggressive Living generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Elvish.dck', 'JUMPSTART\\Aggressive Living.dck', '-m', '2', '-q']' timed out after 120 seconds
# Game Aggressive Elvish vs Aggressive Goblins generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Elvish.dck', 'JUMPSTART\\Aggressive Goblins.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 12/179
# Completed: Aggressive Elvish vs Aggressive Morbid
# Completed: Aggressive Elvish vs Aggressive Plundering
# Completed: Aggressive Elvish vs Bloodthirsty Dragons
# Completed: Aggressive Elvish vs Bloodthirsty Elvish
# Completed: Aggressive Elvish vs Aggressive Stompy
# Completed: Aggressive Elvish vs Bloodthirsty Stompy
# Completed: Aggressive Elvish vs Aggressive Necromancy
# Completed: Aggressive Elvish vs Bloodthirsty Morbid
# Completed: Aggressive Elvish vs Dragons Morbid
# Completed: Aggressive Elvish vs Elvish Morbid
# Completed: Aggressive Elvish vs Elvish Stompy
# Game Aggressive Elvish vs Elvish Dragons generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Elvish.dck', 'JUMPSTART\\Elvish Dragons.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 13/179
# Completed: Aggressive Elvish vs Gambling Dragons
# Completed: Aggressive Elvish vs Gambling Morbid
# Completed: Aggressive Elvish vs Gambling Goblins
# Completed: Aggressive Elvish vs Gambling Elvish
# Completed: Aggressive Elvish vs Gambling Necromancy
# Completed: Aggressive Elvish vs Goblins Bloodthirsty
# Completed: Aggressive Elvish vs Gambling Stompy
# Completed: Aggressive Elvish vs Gambling Bloodthirsty
# Completed: Aggressive Elvish vs Goblins Dragons
# Completed: Aggressive Elvish vs Goblins Elvish
# Completed: Aggressive Elvish vs Goblins Necromancy
# Game Aggressive Elvish vs Goblins Morbid generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Elvish.dck', 'JUMPSTART\\Goblins Morbid.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 14/179
# Completed: Aggressive Elvish vs Goblins Stompy
# Completed: Aggressive Elvish vs Growth Dragons
# Completed: Aggressive Elvish vs Growth Aggressive
# Completed: Aggressive Elvish vs Growth Elvish
# Completed: Aggressive Elvish vs Growth Bloodthirsty
# Completed: Aggressive Elvish vs Growth Living
# Completed: Aggressive Elvish vs Growth Necromancy
# Completed: Aggressive Elvish vs Growth Stompy
# Completed: Aggressive Elvish vs Growth Gambling
# Completed: Aggressive Elvish vs Growth Morbid
# Completed: Aggressive Elvish vs Growth Plundering
# Game Aggressive Elvish vs Growth Goblins generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Elvish.dck', 'JUMPSTART\\Growth Goblins.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 15/179
# Completed: Aggressive Elvish vs Living Dragons
# Completed: Aggressive Elvish vs Living Morbid
# Completed: Aggressive Elvish vs Living Gambling
# Completed: Aggressive Elvish vs Living Bloodthirsty
# Completed: Aggressive Elvish vs Necromancy Dragons
# Completed: Aggressive Elvish vs Necromancy Bloodthirsty
# Completed: Aggressive Elvish vs Living Stompy
# Game Aggressive Elvish vs Living Goblins generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Elvish.dck', 'JUMPSTART\\Living Goblins.dck', '-m', '2', '-q']' timed out after 120 seconds
# Completed: Aggressive Elvish vs Necromancy Morbid
# Game Aggressive Elvish vs Living Necromancy generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Elvish.dck', 'JUMPSTART\\Living Necromancy.dck', '-m', '2', '-q']' timed out after 120 seconds
# Completed: Aggressive Elvish vs Necromancy Elvish
# Game Aggressive Elvish vs Living Elvish generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Elvish.dck', 'JUMPSTART\\Living Elvish.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 16/179
# Completed: Aggressive Elvish vs Plundering Bloodthirsty
# Completed: Aggressive Elvish vs Plundering Gambling
# Completed: Aggressive Elvish vs Plundering Dragons
# Completed: Aggressive Elvish vs Plundering Elvish
# Completed: Aggressive Elvish vs Plundering Living
# Completed: Aggressive Elvish vs Plundering Goblins
# Completed: Aggressive Elvish vs Necromancy Stompy
# Completed: Aggressive Elvish vs Plundering Necromancy
# Completed: Aggressive Elvish vs Stompy Dragons
# Completed: Aggressive Elvish vs Plundering Morbid
# Completed: Aggressive Elvish vs Plundering Stompy
# Completed: Aggressive Elvish vs Stompy Morbid
# Processing batch 17/179
# Completed: Aggressive Gambling vs Aggressive Morbid
# Completed: Aggressive Gambling vs Aggressive Goblins
# Completed: Aggressive Gambling vs Aggressive Plundering
# Completed: Aggressive Gambling vs Aggressive Necromancy
# Completed: Aggressive Gambling vs Aggressive Stompy
# Completed: Aggressive Gambling vs Aggressive Living
# Completed: Aggressive Gambling vs Bloodthirsty Dragons
# Completed: Aggressive Gambling vs Bloodthirsty Elvish
# Completed: Aggressive Gambling vs Bloodthirsty Stompy
# Completed: Aggressive Gambling vs Dragons Morbid
# Completed: Aggressive Gambling vs Bloodthirsty Morbid
# Completed: Aggressive Gambling vs Elvish Dragons
# Processing batch 18/179
# Completed: Aggressive Gambling vs Gambling Goblins
# Completed: Aggressive Gambling vs Gambling Dragons
# Completed: Aggressive Gambling vs Gambling Bloodthirsty
# Completed: Aggressive Gambling vs Elvish Stompy
# Completed: Aggressive Gambling vs Elvish Morbid
# Completed: Aggressive Gambling vs Gambling Necromancy
# Completed: Aggressive Gambling vs Gambling Stompy
# Completed: Aggressive Gambling vs Goblins Bloodthirsty
# Completed: Aggressive Gambling vs Gambling Morbid
# Completed: Aggressive Gambling vs Gambling Elvish
# Completed: Aggressive Gambling vs Goblins Dragons
# Completed: Aggressive Gambling vs Goblins Elvish
# Processing batch 19/179
# Completed: Aggressive Gambling vs Growth Bloodthirsty
# Completed: Aggressive Gambling vs Goblins Stompy
# Completed: Aggressive Gambling vs Goblins Morbid
# Completed: Aggressive Gambling vs Growth Dragons
# Completed: Aggressive Gambling vs Goblins Necromancy
# Completed: Aggressive Gambling vs Growth Goblins
# Completed: Aggressive Gambling vs Growth Elvish
# Completed: Aggressive Gambling vs Growth Morbid
# Completed: Aggressive Gambling vs Growth Living
# Completed: Aggressive Gambling vs Growth Gambling
# Completed: Aggressive Gambling vs Growth Aggressive
# Completed: Aggressive Gambling vs Growth Necromancy
# Processing batch 20/179
# Completed: Aggressive Gambling vs Growth Stompy
# Completed: Aggressive Gambling vs Living Dragons
# Completed: Aggressive Gambling vs Living Bloodthirsty
# Completed: Aggressive Gambling vs Growth Plundering
# Completed: Aggressive Gambling vs Living Elvish
# Completed: Aggressive Gambling vs Living Morbid
# Completed: Aggressive Gambling vs Living Gambling
# Completed: Aggressive Gambling vs Living Goblins
# Completed: Aggressive Gambling vs Necromancy Bloodthirsty
# Completed: Aggressive Gambling vs Living Stompy
# Completed: Aggressive Gambling vs Living Necromancy
# Completed: Aggressive Gambling vs Necromancy Dragons
# Processing batch 21/179
# Completed: Aggressive Gambling vs Plundering Dragons
# Completed: Aggressive Gambling vs Necromancy Morbid
# Completed: Aggressive Gambling vs Necromancy Elvish
# Completed: Aggressive Gambling vs Plundering Elvish
# Completed: Aggressive Gambling vs Plundering Bloodthirsty
# Completed: Aggressive Gambling vs Plundering Goblins
# Completed: Aggressive Gambling vs Plundering Living
# Completed: Aggressive Gambling vs Plundering Stompy
# Completed: Aggressive Gambling vs Plundering Necromancy
# Completed: Aggressive Gambling vs Necromancy Stompy
# Completed: Aggressive Gambling vs Plundering Morbid
# Game Aggressive Gambling vs Plundering Gambling generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Gambling.dck', 'JUMPSTART\\Plundering Gambling.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 22/179
# Completed: Aggressive Gambling vs Stompy Dragons
# Completed: Aggressive Goblins vs Aggressive Necromancy
# Completed: Aggressive Gambling vs Stompy Morbid
# Completed: Aggressive Goblins vs Aggressive Morbid
# Completed: Aggressive Goblins vs Aggressive Plundering
# Completed: Aggressive Goblins vs Aggressive Living
# Completed: Aggressive Goblins vs Bloodthirsty Dragons
# Completed: Aggressive Goblins vs Bloodthirsty Elvish
# Completed: Aggressive Goblins vs Aggressive Stompy
# Completed: Aggressive Goblins vs Dragons Morbid
# Completed: Aggressive Goblins vs Bloodthirsty Stompy
# Completed: Aggressive Goblins vs Bloodthirsty Morbid
# Processing batch 23/179
# Completed: Aggressive Goblins vs Elvish Morbid
# Completed: Aggressive Goblins vs Elvish Dragons
# Completed: Aggressive Goblins vs Elvish Stompy
# Completed: Aggressive Goblins vs Gambling Dragons
# Completed: Aggressive Goblins vs Gambling Morbid
# Completed: Aggressive Goblins vs Gambling Necromancy
# Completed: Aggressive Goblins vs Gambling Elvish
# Completed: Aggressive Goblins vs Gambling Bloodthirsty
# Completed: Aggressive Goblins vs Gambling Stompy
# Completed: Aggressive Goblins vs Goblins Dragons
# Completed: Aggressive Goblins vs Goblins Bloodthirsty
# Completed: Aggressive Goblins vs Gambling Goblins
# Processing batch 24/179
# Completed: Aggressive Goblins vs Growth Aggressive
# Completed: Aggressive Goblins vs Growth Bloodthirsty
# Completed: Aggressive Goblins vs Goblins Stompy
# Completed: Aggressive Goblins vs Growth Dragons
# Completed: Aggressive Goblins vs Goblins Elvish
# Completed: Aggressive Goblins vs Growth Goblins
# Completed: Aggressive Goblins vs Growth Gambling
# Completed: Aggressive Goblins vs Growth Living
# Completed: Aggressive Goblins vs Growth Morbid
# Completed: Aggressive Goblins vs Goblins Necromancy
# Completed: Aggressive Goblins vs Growth Elvish
# Game Aggressive Goblins vs Goblins Morbid generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Goblins.dck', 'JUMPSTART\\Goblins Morbid.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 25/179
# Completed: Aggressive Goblins vs Living Dragons
# Completed: Aggressive Goblins vs Growth Stompy
# Completed: Aggressive Goblins vs Living Bloodthirsty
# Completed: Aggressive Goblins vs Growth Necromancy
# Completed: Aggressive Goblins vs Growth Plundering
# Completed: Aggressive Goblins vs Living Elvish
# Completed: Aggressive Goblins vs Living Goblins
# Completed: Aggressive Goblins vs Living Gambling
# Completed: Aggressive Goblins vs Living Necromancy
# Completed: Aggressive Goblins vs Living Stompy
# Completed: Aggressive Goblins vs Necromancy Bloodthirsty
# Completed: Aggressive Goblins vs Living Morbid
# Processing batch 26/179
# Completed: Aggressive Goblins vs Necromancy Morbid
# Completed: Aggressive Goblins vs Necromancy Stompy
# Completed: Aggressive Goblins vs Necromancy Dragons
# Completed: Aggressive Goblins vs Necromancy Elvish
# Completed: Aggressive Goblins vs Plundering Dragons
# Completed: Aggressive Goblins vs Plundering Bloodthirsty
# Completed: Aggressive Goblins vs Plundering Gambling
# Completed: Aggressive Goblins vs Plundering Necromancy
# Completed: Aggressive Goblins vs Plundering Living
# Completed: Aggressive Goblins vs Plundering Goblins
# Completed: Aggressive Goblins vs Plundering Morbid
# Game Aggressive Goblins vs Plundering Elvish generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Goblins.dck', 'JUMPSTART\\Plundering Elvish.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 27/179
# Completed: Aggressive Goblins vs Stompy Morbid
# Completed: Aggressive Living vs Aggressive Necromancy
# Completed: Aggressive Living vs Aggressive Morbid
# Completed: Aggressive Goblins vs Stompy Dragons
# Completed: Aggressive Living vs Aggressive Stompy
# Completed: Aggressive Living vs Bloodthirsty Dragons
# Completed: Aggressive Living vs Bloodthirsty Elvish
# Completed: Aggressive Goblins vs Plundering Stompy
# Completed: Aggressive Living vs Bloodthirsty Morbid
# Completed: Aggressive Living vs Bloodthirsty Stompy
# Completed: Aggressive Living vs Dragons Morbid
# Game Aggressive Living vs Aggressive Plundering generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Living.dck', 'JUMPSTART\\Aggressive Plundering.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 28/179
# Completed: Aggressive Living vs Gambling Dragons
# Completed: Aggressive Living vs Elvish Stompy
# Completed: Aggressive Living vs Gambling Bloodthirsty
# Completed: Aggressive Living vs Elvish Dragons
# Completed: Aggressive Living vs Gambling Goblins
# Completed: Aggressive Living vs Gambling Elvish
# Completed: Aggressive Living vs Gambling Stompy
# Completed: Aggressive Living vs Gambling Necromancy
# Completed: Aggressive Living vs Gambling Morbid
# Completed: Aggressive Living vs Elvish Morbid
# Completed: Aggressive Living vs Goblins Dragons
# Completed: Aggressive Living vs Goblins Bloodthirsty
# Processing batch 29/179
# Completed: Aggressive Living vs Goblins Morbid
# Completed: Aggressive Living vs Goblins Stompy
# Completed: Aggressive Living vs Goblins Elvish
# Completed: Aggressive Living vs Growth Bloodthirsty
# Completed: Aggressive Living vs Goblins Necromancy
# Completed: Aggressive Living vs Growth Gambling
# Completed: Aggressive Living vs Growth Living
# Completed: Aggressive Living vs Growth Aggressive
# Completed: Aggressive Living vs Growth Elvish
# Completed: Aggressive Living vs Growth Dragons
# Completed: Aggressive Living vs Growth Morbid
# Completed: Aggressive Living vs Growth Goblins
# Processing batch 30/179
# Completed: Aggressive Living vs Growth Necromancy
# Completed: Aggressive Living vs Growth Stompy
# Completed: Aggressive Living vs Living Bloodthirsty
# Completed: Aggressive Living vs Growth Plundering
# Completed: Aggressive Living vs Living Dragons
# Completed: Aggressive Living vs Living Goblins
# Completed: Aggressive Living vs Living Morbid
# Completed: Aggressive Living vs Living Necromancy
# Completed: Aggressive Living vs Living Gambling
# Completed: Aggressive Living vs Living Stompy
# Completed: Aggressive Living vs Necromancy Bloodthirsty
# Completed: Aggressive Living vs Living Elvish
# Processing batch 31/179
# Completed: Aggressive Living vs Plundering Dragons
# Completed: Aggressive Living vs Necromancy Stompy
# Completed: Aggressive Living vs Necromancy Morbid
# Completed: Aggressive Living vs Plundering Bloodthirsty
# Completed: Aggressive Living vs Necromancy Dragons
# Completed: Aggressive Living vs Necromancy Elvish
# Completed: Aggressive Living vs Plundering Elvish
# Completed: Aggressive Living vs Plundering Living
# Completed: Aggressive Living vs Plundering Gambling
# Completed: Aggressive Living vs Plundering Goblins
# Completed: Aggressive Living vs Plundering Necromancy
# Completed: Aggressive Living vs Plundering Morbid
# Processing batch 32/179
# Completed: Aggressive Morbid vs Aggressive Plundering
# Completed: Aggressive Living vs Stompy Dragons
# Completed: Aggressive Morbid vs Aggressive Stompy
# Completed: Aggressive Morbid vs Aggressive Necromancy
# Completed: Aggressive Living vs Plundering Stompy
# Completed: Aggressive Living vs Stompy Morbid
# Completed: Aggressive Morbid vs Bloodthirsty Dragons
# Completed: Aggressive Morbid vs Bloodthirsty Elvish
# Completed: Aggressive Morbid vs Dragons Morbid
# Completed: Aggressive Morbid vs Bloodthirsty Stompy
# Completed: Aggressive Morbid vs Elvish Dragons
# Completed: Aggressive Morbid vs Bloodthirsty Morbid
# Processing batch 33/179
# Completed: Aggressive Morbid vs Gambling Dragons
# Completed: Aggressive Morbid vs Gambling Goblins
# Completed: Aggressive Morbid vs Elvish Stompy
# Completed: Aggressive Morbid vs Elvish Morbid
# Completed: Aggressive Morbid vs Gambling Elvish
# Completed: Aggressive Morbid vs Gambling Bloodthirsty
# Completed: Aggressive Morbid vs Gambling Stompy
# Completed: Aggressive Morbid vs Gambling Morbid
# Completed: Aggressive Morbid vs Goblins Bloodthirsty
# Completed: Aggressive Morbid vs Gambling Necromancy
# Completed: Aggressive Morbid vs Goblins Dragons
# Completed: Aggressive Morbid vs Goblins Elvish
# Processing batch 34/179
# Completed: Aggressive Morbid vs Growth Bloodthirsty
# Completed: Aggressive Morbid vs Growth Dragons
# Completed: Aggressive Morbid vs Goblins Stompy
# Completed: Aggressive Morbid vs Growth Aggressive
# Completed: Aggressive Morbid vs Goblins Necromancy
# Completed: Aggressive Morbid vs Growth Elvish
# Completed: Aggressive Morbid vs Growth Living
# Completed: Aggressive Morbid vs Growth Necromancy
# Game Aggressive Morbid vs Goblins Morbid generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Morbid.dck', 'JUMPSTART\\Goblins Morbid.dck', '-m', '2', '-q']' timed out after 120 seconds
# Completed: Aggressive Morbid vs Growth Morbid
# Completed: Aggressive Morbid vs Growth Gambling
# Completed: Aggressive Morbid vs Growth Goblins
# Processing batch 35/179
# Completed: Aggressive Morbid vs Living Dragons
# Completed: Aggressive Morbid vs Growth Stompy
# Completed: Aggressive Morbid vs Growth Plundering
# Completed: Aggressive Morbid vs Living Gambling
# Completed: Aggressive Morbid vs Living Elvish
# Completed: Aggressive Morbid vs Living Goblins
# Completed: Aggressive Morbid vs Living Morbid
# Completed: Aggressive Morbid vs Living Necromancy
# Completed: Aggressive Morbid vs Necromancy Bloodthirsty
# Completed: Aggressive Morbid vs Living Stompy
# Completed: Aggressive Morbid vs Necromancy Dragons
# Completed: Aggressive Morbid vs Living Bloodthirsty
# Processing batch 36/179
# Completed: Aggressive Morbid vs Necromancy Stompy
# Completed: Aggressive Morbid vs Plundering Dragons
# Completed: Aggressive Morbid vs Plundering Bloodthirsty
# Completed: Aggressive Morbid vs Necromancy Morbid
# Completed: Aggressive Morbid vs Plundering Gambling
# Completed: Aggressive Morbid vs Plundering Elvish
# Completed: Aggressive Morbid vs Plundering Living
# Completed: Aggressive Morbid vs Plundering Necromancy
# Completed: Aggressive Morbid vs Necromancy Elvish
# Completed: Aggressive Morbid vs Plundering Morbid
# Completed: Aggressive Morbid vs Plundering Stompy
# Game Aggressive Morbid vs Plundering Goblins generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Morbid.dck', 'JUMPSTART\\Plundering Goblins.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 37/179
# Completed: Aggressive Morbid vs Stompy Dragons
# Completed: Aggressive Necromancy vs Aggressive Stompy
# Completed: Aggressive Necromancy vs Bloodthirsty Elvish
# Completed: Aggressive Necromancy vs Bloodthirsty Dragons
# Completed: Aggressive Morbid vs Stompy Morbid
# Completed: Aggressive Necromancy vs Bloodthirsty Stompy
# Completed: Aggressive Necromancy vs Dragons Morbid
# Completed: Aggressive Necromancy vs Aggressive Plundering
# Completed: Aggressive Necromancy vs Bloodthirsty Morbid
# Completed: Aggressive Necromancy vs Elvish Dragons
# Completed: Aggressive Necromancy vs Elvish Stompy
# Completed: Aggressive Necromancy vs Elvish Morbid
# Processing batch 38/179
# Completed: Aggressive Necromancy vs Gambling Bloodthirsty
# Completed: Aggressive Necromancy vs Gambling Elvish
# Completed: Aggressive Necromancy vs Gambling Goblins
# Completed: Aggressive Necromancy vs Gambling Necromancy
# Completed: Aggressive Necromancy vs Gambling Dragons
# Completed: Aggressive Necromancy vs Gambling Morbid
# Completed: Aggressive Necromancy vs Gambling Stompy
# Completed: Aggressive Necromancy vs Goblins Dragons
# Completed: Aggressive Necromancy vs Goblins Morbid
# Completed: Aggressive Necromancy vs Goblins Bloodthirsty
# Completed: Aggressive Necromancy vs Goblins Necromancy
# Completed: Aggressive Necromancy vs Goblins Elvish
# Processing batch 39/179
# Completed: Aggressive Necromancy vs Growth Gambling
# Completed: Aggressive Necromancy vs Growth Bloodthirsty
# Completed: Aggressive Necromancy vs Growth Goblins
# Completed: Aggressive Necromancy vs Growth Elvish
# Completed: Aggressive Necromancy vs Growth Dragons
# Completed: Aggressive Necromancy vs Growth Aggressive
# Completed: Aggressive Necromancy vs Growth Living
# Completed: Aggressive Necromancy vs Growth Stompy
# Completed: Aggressive Necromancy vs Growth Plundering
# Completed: Aggressive Necromancy vs Growth Necromancy
# Completed: Aggressive Necromancy vs Growth Morbid
# Completed: Aggressive Necromancy vs Goblins Stompy
# Processing batch 40/179
# Completed: Aggressive Necromancy vs Living Gambling
# Completed: Aggressive Necromancy vs Living Dragons
# Completed: Aggressive Necromancy vs Living Goblins
# Completed: Aggressive Necromancy vs Living Bloodthirsty
# Completed: Aggressive Necromancy vs Living Morbid
# Completed: Aggressive Necromancy vs Living Elvish
# Completed: Aggressive Necromancy vs Living Necromancy
# Completed: Aggressive Necromancy vs Necromancy Bloodthirsty
# Completed: Aggressive Necromancy vs Necromancy Morbid
# Completed: Aggressive Necromancy vs Necromancy Dragons
# Completed: Aggressive Necromancy vs Living Stompy
# Completed: Aggressive Necromancy vs Necromancy Elvish
# Processing batch 41/179
# Completed: Aggressive Necromancy vs Plundering Goblins
# Completed: Aggressive Necromancy vs Plundering Dragons
# Completed: Aggressive Necromancy vs Plundering Bloodthirsty
# Completed: Aggressive Necromancy vs Plundering Gambling
# Completed: Aggressive Necromancy vs Plundering Elvish
# Completed: Aggressive Necromancy vs Necromancy Stompy
# Completed: Aggressive Necromancy vs Plundering Necromancy
# Completed: Aggressive Necromancy vs Plundering Morbid
# Completed: Aggressive Necromancy vs Stompy Morbid
# Completed: Aggressive Necromancy vs Stompy Dragons
# Completed: Aggressive Necromancy vs Plundering Living
# Completed: Aggressive Necromancy vs Plundering Stompy
# Processing batch 42/179
# Completed: Aggressive Plundering vs Bloodthirsty Stompy
# Completed: Aggressive Plundering vs Bloodthirsty Morbid
# Completed: Aggressive Plundering vs Dragons Morbid
# Completed: Aggressive Plundering vs Bloodthirsty Dragons
# Completed: Aggressive Plundering vs Aggressive Stompy
# Completed: Aggressive Plundering vs Bloodthirsty Elvish
# Completed: Aggressive Plundering vs Elvish Dragons
# Completed: Aggressive Plundering vs Gambling Dragons
# Completed: Aggressive Plundering vs Gambling Elvish
# Completed: Aggressive Plundering vs Gambling Bloodthirsty
# Completed: Aggressive Plundering vs Elvish Morbid
# Game Aggressive Plundering vs Elvish Stompy generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Plundering.dck', 'JUMPSTART\\Elvish Stompy.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 43/179
# Completed: Aggressive Plundering vs Goblins Dragons
# Completed: Aggressive Plundering vs Gambling Stompy
# Completed: Aggressive Plundering vs Gambling Morbid
# Completed: Aggressive Plundering vs Gambling Goblins
# Completed: Aggressive Plundering vs Gambling Necromancy
# Completed: Aggressive Plundering vs Goblins Necromancy
# Completed: Aggressive Plundering vs Goblins Morbid
# Completed: Aggressive Plundering vs Growth Bloodthirsty
# Completed: Aggressive Plundering vs Goblins Stompy
# Completed: Aggressive Plundering vs Goblins Bloodthirsty
# Completed: Aggressive Plundering vs Growth Aggressive
# Completed: Aggressive Plundering vs Goblins Elvish
# Processing batch 44/179
# Completed: Aggressive Plundering vs Growth Dragons
# Completed: Aggressive Plundering vs Growth Gambling
# Completed: Aggressive Plundering vs Growth Goblins
# Completed: Aggressive Plundering vs Growth Morbid
# Completed: Aggressive Plundering vs Growth Living
# Completed: Aggressive Plundering vs Growth Necromancy
# Completed: Aggressive Plundering vs Growth Plundering
# Completed: Aggressive Plundering vs Growth Stompy
# Completed: Aggressive Plundering vs Living Dragons
# Completed: Aggressive Plundering vs Living Bloodthirsty
# Completed: Aggressive Plundering vs Growth Elvish
# Game Aggressive Plundering vs Living Elvish generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Plundering.dck', 'JUMPSTART\\Living Elvish.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 45/179
# Completed: Aggressive Plundering vs Living Morbid
# Completed: Aggressive Plundering vs Living Necromancy
# Completed: Aggressive Plundering vs Living Gambling
# Completed: Aggressive Plundering vs Living Goblins
# Completed: Aggressive Plundering vs Necromancy Bloodthirsty
# Completed: Aggressive Plundering vs Necromancy Stompy
# Completed: Aggressive Plundering vs Necromancy Dragons
# Completed: Aggressive Plundering vs Living Stompy
# Completed: Aggressive Plundering vs Plundering Bloodthirsty
# Completed: Aggressive Plundering vs Necromancy Morbid
# Completed: Aggressive Plundering vs Plundering Dragons
# Completed: Aggressive Plundering vs Necromancy Elvish
# Processing batch 46/179
# Completed: Aggressive Plundering vs Plundering Living
# Completed: Aggressive Plundering vs Plundering Goblins
# Completed: Aggressive Plundering vs Plundering Necromancy
# Completed: Aggressive Plundering vs Plundering Morbid
# Completed: Aggressive Plundering vs Plundering Gambling
# Completed: Aggressive Plundering vs Plundering Stompy
# Completed: Aggressive Plundering vs Stompy Morbid
# Completed: Aggressive Stompy vs Bloodthirsty Dragons
# Completed: Aggressive Stompy vs Bloodthirsty Morbid
# Completed: Aggressive Plundering vs Stompy Dragons
# Completed: Aggressive Stompy vs Bloodthirsty Elvish
# Game Aggressive Plundering vs Plundering Elvish generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Plundering.dck', 'JUMPSTART\\Plundering Elvish.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 47/179
# Completed: Aggressive Stompy vs Dragons Morbid
# Completed: Aggressive Stompy vs Gambling Bloodthirsty
# Completed: Aggressive Stompy vs Elvish Dragons
# Completed: Aggressive Stompy vs Elvish Morbid
# Completed: Aggressive Stompy vs Gambling Dragons
# Completed: Aggressive Stompy vs Bloodthirsty Stompy
# Completed: Aggressive Stompy vs Gambling Elvish
# Completed: Aggressive Stompy vs Gambling Morbid
# Completed: Aggressive Stompy vs Elvish Stompy
# Completed: Aggressive Stompy vs Gambling Goblins
# Completed: Aggressive Stompy vs Gambling Stompy
# Completed: Aggressive Stompy vs Gambling Necromancy
# Processing batch 48/179
# Completed: Aggressive Stompy vs Goblins Dragons
# Completed: Aggressive Stompy vs Goblins Necromancy
# Completed: Aggressive Stompy vs Goblins Bloodthirsty
# Completed: Aggressive Stompy vs Goblins Elvish
# Completed: Aggressive Stompy vs Goblins Stompy
# Completed: Aggressive Stompy vs Growth Dragons
# Completed: Aggressive Stompy vs Goblins Morbid
# Completed: Aggressive Stompy vs Growth Aggressive
# Completed: Aggressive Stompy vs Growth Elvish
# Completed: Aggressive Stompy vs Growth Gambling
# Completed: Aggressive Stompy vs Growth Bloodthirsty
# Completed: Aggressive Stompy vs Growth Goblins
# Processing batch 49/179
# Completed: Aggressive Stompy vs Growth Necromancy
# Completed: Aggressive Stompy vs Growth Stompy
# Completed: Aggressive Stompy vs Living Bloodthirsty
# Completed: Aggressive Stompy vs Growth Plundering
# Completed: Aggressive Stompy vs Growth Living
# Completed: Aggressive Stompy vs Living Goblins
# Completed: Aggressive Stompy vs Living Elvish
# Completed: Aggressive Stompy vs Living Dragons
# Completed: Aggressive Stompy vs Living Morbid
# Completed: Aggressive Stompy vs Living Gambling
# Completed: Aggressive Stompy vs Living Necromancy
# Game Aggressive Stompy vs Growth Morbid generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Aggressive Stompy.dck', 'JUMPSTART\\Growth Morbid.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 50/179
# Completed: Aggressive Stompy vs Living Stompy
# Completed: Aggressive Stompy vs Necromancy Stompy
# Completed: Aggressive Stompy vs Necromancy Morbid
# Completed: Aggressive Stompy vs Necromancy Dragons
# Completed: Aggressive Stompy vs Necromancy Bloodthirsty
# Completed: Aggressive Stompy vs Necromancy Elvish
# Completed: Aggressive Stompy vs Plundering Dragons
# Completed: Aggressive Stompy vs Plundering Elvish
# Completed: Aggressive Stompy vs Plundering Bloodthirsty
# Completed: Aggressive Stompy vs Plundering Gambling
# Completed: Aggressive Stompy vs Plundering Goblins
# Completed: Aggressive Stompy vs Plundering Living
# Processing batch 51/179
# Completed: Aggressive Stompy vs Plundering Stompy
# Completed: Aggressive Stompy vs Stompy Dragons
# Completed: Aggressive Stompy vs Stompy Morbid
# Completed: Aggressive Stompy vs Plundering Necromancy
# Completed: Bloodthirsty Dragons vs Bloodthirsty Elvish
# Completed: Bloodthirsty Dragons vs Bloodthirsty Morbid
# Completed: Bloodthirsty Dragons vs Bloodthirsty Stompy
# Completed: Bloodthirsty Dragons vs Dragons Morbid
# Completed: Aggressive Stompy vs Plundering Morbid
# Completed: Bloodthirsty Dragons vs Elvish Morbid
# Completed: Bloodthirsty Dragons vs Elvish Stompy
# Game Bloodthirsty Dragons vs Elvish Dragons generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Bloodthirsty Dragons.dck', 'JUMPSTART\\Elvish Dragons.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 52/179
# Completed: Bloodthirsty Dragons vs Gambling Dragons
# Completed: Bloodthirsty Dragons vs Gambling Goblins
# Completed: Bloodthirsty Dragons vs Gambling Bloodthirsty
# Completed: Bloodthirsty Dragons vs Gambling Morbid
# Completed: Bloodthirsty Dragons vs Gambling Necromancy
# Completed: Bloodthirsty Dragons vs Gambling Elvish
# Completed: Bloodthirsty Dragons vs Gambling Stompy
# Completed: Bloodthirsty Dragons vs Goblins Dragons
# Completed: Bloodthirsty Dragons vs Goblins Morbid
# Completed: Bloodthirsty Dragons vs Goblins Elvish
# Completed: Bloodthirsty Dragons vs Goblins Necromancy
# Completed: Bloodthirsty Dragons vs Goblins Bloodthirsty
# Processing batch 53/179
# Completed: Bloodthirsty Dragons vs Growth Gambling
# Completed: Bloodthirsty Dragons vs Growth Elvish
# Completed: Bloodthirsty Dragons vs Growth Dragons
# Completed: Bloodthirsty Dragons vs Growth Bloodthirsty
# Completed: Bloodthirsty Dragons vs Growth Aggressive
# Completed: Bloodthirsty Dragons vs Goblins Stompy
# Completed: Bloodthirsty Dragons vs Growth Morbid
# Completed: Bloodthirsty Dragons vs Growth Living
# Completed: Bloodthirsty Dragons vs Growth Necromancy
# Completed: Bloodthirsty Dragons vs Growth Goblins
# Completed: Bloodthirsty Dragons vs Growth Stompy
# Completed: Bloodthirsty Dragons vs Growth Plundering
# Processing batch 54/179
# Completed: Bloodthirsty Dragons vs Living Goblins
# Completed: Bloodthirsty Dragons vs Living Dragons
# Completed: Bloodthirsty Dragons vs Living Morbid
# Completed: Bloodthirsty Dragons vs Living Bloodthirsty
# Completed: Bloodthirsty Dragons vs Living Gambling
# Completed: Bloodthirsty Dragons vs Living Necromancy
# Completed: Bloodthirsty Dragons vs Necromancy Elvish
# Completed: Bloodthirsty Dragons vs Living Elvish
# Completed: Bloodthirsty Dragons vs Necromancy Bloodthirsty
# Completed: Bloodthirsty Dragons vs Living Stompy
# Completed: Bloodthirsty Dragons vs Necromancy Dragons
# Completed: Bloodthirsty Dragons vs Necromancy Morbid
# Processing batch 55/179
# Completed: Bloodthirsty Dragons vs Plundering Dragons
# Completed: Bloodthirsty Dragons vs Plundering Bloodthirsty
# Completed: Bloodthirsty Dragons vs Necromancy Stompy
# Completed: Bloodthirsty Dragons vs Plundering Gambling
# Completed: Bloodthirsty Dragons vs Plundering Goblins
# Completed: Bloodthirsty Dragons vs Plundering Elvish
# Completed: Bloodthirsty Dragons vs Plundering Stompy
# Completed: Bloodthirsty Dragons vs Plundering Living
# Completed: Bloodthirsty Dragons vs Stompy Dragons
# Completed: Bloodthirsty Dragons vs Plundering Morbid
# Completed: Bloodthirsty Dragons vs Plundering Necromancy
# Completed: Bloodthirsty Dragons vs Stompy Morbid
# Processing batch 56/179
# Completed: Bloodthirsty Elvish vs Dragons Morbid
# Completed: Bloodthirsty Elvish vs Elvish Stompy
# Completed: Bloodthirsty Elvish vs Gambling Dragons
# Completed: Bloodthirsty Elvish vs Bloodthirsty Stompy
# Completed: Bloodthirsty Elvish vs Gambling Bloodthirsty
# Completed: Bloodthirsty Elvish vs Gambling Morbid
# Game Bloodthirsty Elvish vs Bloodthirsty Morbid generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Bloodthirsty Elvish.dck', 'JUMPSTART\\Bloodthirsty Morbid.dck', '-m', '2', '-q']' timed out after 120 seconds
# Game Bloodthirsty Elvish vs Elvish Dragons generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Bloodthirsty Elvish.dck', 'JUMPSTART\\Elvish Dragons.dck', '-m', '2', '-q']' timed out after 120 seconds
# Completed: Bloodthirsty Elvish vs Gambling Elvish
# Completed: Bloodthirsty Elvish vs Gambling Necromancy
# Completed: Bloodthirsty Elvish vs Gambling Goblins
# Game Bloodthirsty Elvish vs Elvish Morbid generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Bloodthirsty Elvish.dck', 'JUMPSTART\\Elvish Morbid.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 57/179
# Completed: Bloodthirsty Elvish vs Gambling Stompy
# Completed: Bloodthirsty Elvish vs Goblins Morbid
# Completed: Bloodthirsty Elvish vs Goblins Bloodthirsty
# Completed: Bloodthirsty Elvish vs Goblins Necromancy
# Completed: Bloodthirsty Elvish vs Goblins Stompy
# Completed: Bloodthirsty Elvish vs Growth Aggressive
# Completed: Bloodthirsty Elvish vs Growth Dragons
# Completed: Bloodthirsty Elvish vs Goblins Dragons
# Completed: Bloodthirsty Elvish vs Growth Bloodthirsty
# Completed: Bloodthirsty Elvish vs Growth Elvish
# Completed: Bloodthirsty Elvish vs Growth Gambling
# Game Bloodthirsty Elvish vs Goblins Elvish generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Bloodthirsty Elvish.dck', 'JUMPSTART\\Goblins Elvish.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 58/179
# Completed: Bloodthirsty Elvish vs Growth Necromancy
# Completed: Bloodthirsty Elvish vs Growth Morbid
# Completed: Bloodthirsty Elvish vs Growth Living
# Completed: Bloodthirsty Elvish vs Growth Stompy
# Completed: Bloodthirsty Elvish vs Growth Plundering
# Completed: Bloodthirsty Elvish vs Living Bloodthirsty
# Completed: Bloodthirsty Elvish vs Living Dragons
# Completed: Bloodthirsty Elvish vs Living Elvish
# Completed: Bloodthirsty Elvish vs Growth Goblins
# Completed: Bloodthirsty Elvish vs Living Goblins
# Completed: Bloodthirsty Elvish vs Living Morbid
# Completed: Bloodthirsty Elvish vs Living Gambling
# Processing batch 59/179
# Completed: Bloodthirsty Elvish vs Living Stompy
# Completed: Bloodthirsty Elvish vs Necromancy Elvish
# Completed: Bloodthirsty Elvish vs Necromancy Dragons
# Completed: Bloodthirsty Elvish vs Living Necromancy
# Completed: Bloodthirsty Elvish vs Necromancy Morbid
# Completed: Bloodthirsty Elvish vs Necromancy Stompy
# Completed: Bloodthirsty Elvish vs Plundering Bloodthirsty
# Completed: Bloodthirsty Elvish vs Plundering Dragons
# Completed: Bloodthirsty Elvish vs Necromancy Bloodthirsty
# Completed: Bloodthirsty Elvish vs Plundering Elvish
# Completed: Bloodthirsty Elvish vs Plundering Gambling
# Completed: Bloodthirsty Elvish vs Plundering Goblins
# Processing batch 60/179
# Completed: Bloodthirsty Elvish vs Stompy Dragons
# Completed: Bloodthirsty Elvish vs Plundering Living
# Completed: Bloodthirsty Morbid vs Bloodthirsty Stompy
# Completed: Bloodthirsty Morbid vs Dragons Morbid
# Completed: Bloodthirsty Elvish vs Stompy Morbid
# Completed: Bloodthirsty Morbid vs Elvish Dragons
# Completed: Bloodthirsty Morbid vs Elvish Stompy
# Completed: Bloodthirsty Morbid vs Elvish Morbid
# Completed: Bloodthirsty Morbid vs Gambling Bloodthirsty
# Completed: Bloodthirsty Elvish vs Plundering Morbid
# Game Bloodthirsty Elvish vs Plundering Stompy generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Bloodthirsty Elvish.dck', 'JUMPSTART\\Plundering Stompy.dck', '-m', '2', '-q']' timed out after 120 seconds
# Game Bloodthirsty Elvish vs Plundering Necromancy generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Bloodthirsty Elvish.dck', 'JUMPSTART\\Plundering Necromancy.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 61/179
# Completed: Bloodthirsty Morbid vs Gambling Stompy
# Completed: Bloodthirsty Morbid vs Gambling Necromancy
# Completed: Bloodthirsty Morbid vs Gambling Goblins
# Completed: Bloodthirsty Morbid vs Gambling Elvish
# Completed: Bloodthirsty Morbid vs Gambling Morbid
# Completed: Bloodthirsty Morbid vs Goblins Elvish
# Completed: Bloodthirsty Morbid vs Goblins Dragons
# Completed: Bloodthirsty Morbid vs Gambling Dragons
# Completed: Bloodthirsty Morbid vs Goblins Morbid
# Completed: Bloodthirsty Morbid vs Goblins Stompy
# Completed: Bloodthirsty Morbid vs Goblins Necromancy
# Completed: Bloodthirsty Morbid vs Goblins Bloodthirsty
# Processing batch 62/179
# Completed: Bloodthirsty Morbid vs Growth Goblins
# Completed: Bloodthirsty Morbid vs Growth Aggressive
# Completed: Bloodthirsty Morbid vs Growth Dragons
# Completed: Bloodthirsty Morbid vs Growth Elvish
# Completed: Bloodthirsty Morbid vs Growth Gambling
# Completed: Bloodthirsty Morbid vs Growth Bloodthirsty
# Completed: Bloodthirsty Morbid vs Growth Stompy
# Completed: Bloodthirsty Morbid vs Growth Living
# Completed: Bloodthirsty Morbid vs Living Bloodthirsty
# Completed: Bloodthirsty Morbid vs Growth Morbid
# Completed: Bloodthirsty Morbid vs Growth Necromancy
# Completed: Bloodthirsty Morbid vs Growth Plundering
# Processing batch 63/179
# Completed: Bloodthirsty Morbid vs Living Dragons
# Completed: Bloodthirsty Morbid vs Living Morbid
# Completed: Bloodthirsty Morbid vs Living Goblins
# Completed: Bloodthirsty Morbid vs Living Stompy
# Completed: Bloodthirsty Morbid vs Necromancy Bloodthirsty
# Completed: Bloodthirsty Morbid vs Living Elvish
# Completed: Bloodthirsty Morbid vs Necromancy Dragons
# Completed: Bloodthirsty Morbid vs Living Necromancy
# Completed: Bloodthirsty Morbid vs Living Gambling
# Completed: Bloodthirsty Morbid vs Necromancy Morbid
# Completed: Bloodthirsty Morbid vs Necromancy Stompy
# Completed: Bloodthirsty Morbid vs Necromancy Elvish
# Processing batch 64/179
# Completed: Bloodthirsty Morbid vs Plundering Dragons
# Completed: Bloodthirsty Morbid vs Plundering Gambling
# Completed: Bloodthirsty Morbid vs Plundering Living
# Completed: Bloodthirsty Morbid vs Plundering Bloodthirsty
# Completed: Bloodthirsty Morbid vs Plundering Necromancy
# Completed: Bloodthirsty Morbid vs Plundering Goblins
# Completed: Bloodthirsty Morbid vs Plundering Stompy
# Completed: Bloodthirsty Morbid vs Plundering Elvish
# Completed: Bloodthirsty Morbid vs Plundering Morbid
# Completed: Bloodthirsty Morbid vs Stompy Dragons
# Completed: Bloodthirsty Stompy vs Dragons Morbid
# Completed: Bloodthirsty Morbid vs Stompy Morbid
# Processing batch 65/179
# Completed: Bloodthirsty Stompy vs Gambling Dragons
# Completed: Bloodthirsty Stompy vs Gambling Bloodthirsty
# Completed: Bloodthirsty Stompy vs Elvish Dragons
# Completed: Bloodthirsty Stompy vs Gambling Morbid
# Completed: Bloodthirsty Stompy vs Elvish Stompy
# ...
# Completed: Living Bloodthirsty vs Necromancy Morbid
# Completed: Living Bloodthirsty vs Necromancy Elvish
# Completed: Living Bloodthirsty vs Plundering Elvish
# Processing batch 158/179
# Completed: Living Bloodthirsty vs Plundering Morbid
# Completed: Living Bloodthirsty vs Plundering Living
# Completed: Living Bloodthirsty vs Plundering Gambling
# Completed: Living Bloodthirsty vs Plundering Goblins
# Completed: Living Bloodthirsty vs Plundering Stompy
# Completed: Living Bloodthirsty vs Plundering Necromancy
# Completed: Living Bloodthirsty vs Stompy Dragons
# Completed: Living Dragons vs Living Goblins
# Completed: Living Bloodthirsty vs Stompy Morbid
# Completed: Living Dragons vs Living Gambling
# Completed: Living Dragons vs Living Elvish
# Completed: Living Dragons vs Living Morbid
# Processing batch 159/179
# Completed: Living Dragons vs Living Stompy
# Completed: Living Dragons vs Necromancy Morbid
# Completed: Living Dragons vs Necromancy Dragons
# Completed: Living Dragons vs Necromancy Elvish
# Completed: Living Dragons vs Necromancy Bloodthirsty
# Completed: Living Dragons vs Living Necromancy
# Completed: Living Dragons vs Plundering Dragons
# Completed: Living Dragons vs Necromancy Stompy
# Completed: Living Dragons vs Plundering Gambling
# Completed: Living Dragons vs Plundering Elvish
# Completed: Living Dragons vs Plundering Bloodthirsty
# Completed: Living Dragons vs Plundering Goblins
# Processing batch 160/179
# Completed: Living Dragons vs Plundering Morbid
# Completed: Living Dragons vs Plundering Stompy
# Completed: Living Dragons vs Plundering Living
# Completed: Living Dragons vs Stompy Dragons
# Completed: Living Dragons vs Plundering Necromancy
# Completed: Living Dragons vs Stompy Morbid
# Completed: Living Elvish vs Living Necromancy
# Completed: Living Elvish vs Living Morbid
# Completed: Living Elvish vs Living Gambling
# Completed: Living Elvish vs Living Goblins
# Completed: Living Elvish vs Necromancy Bloodthirsty
# Game Living Elvish vs Living Stompy generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Living Elvish.dck', 'JUMPSTART\\Living Stompy.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 161/179
# Completed: Living Elvish vs Necromancy Dragons
# Completed: Living Elvish vs Plundering Dragons
# Completed: Living Elvish vs Plundering Bloodthirsty
# Completed: Living Elvish vs Necromancy Morbid
# Completed: Living Elvish vs Necromancy Stompy
# Completed: Living Elvish vs Plundering Gambling
# Completed: Living Elvish vs Necromancy Elvish
# Completed: Living Elvish vs Plundering Living
# Completed: Living Elvish vs Plundering Goblins
# Completed: Living Elvish vs Plundering Necromancy
# Completed: Living Elvish vs Plundering Morbid
# Game Living Elvish vs Plundering Elvish generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Living Elvish.dck', 'JUMPSTART\\Plundering Elvish.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 162/179
# Completed: Living Elvish vs Stompy Dragons
# Completed: Living Gambling vs Living Goblins
# Completed: Living Gambling vs Living Morbid
# Completed: Living Elvish vs Stompy Morbid
# Completed: Living Gambling vs Living Stompy
# Completed: Living Elvish vs Plundering Stompy
# Completed: Living Gambling vs Living Necromancy
# Completed: Living Gambling vs Necromancy Bloodthirsty
# Completed: Living Gambling vs Necromancy Elvish
# Completed: Living Gambling vs Necromancy Dragons
# Completed: Living Gambling vs Necromancy Stompy
# Completed: Living Gambling vs Necromancy Morbid
# Processing batch 163/179
# Completed: Living Gambling vs Plundering Elvish
# Completed: Living Gambling vs Plundering Living
# Completed: Living Gambling vs Plundering Bloodthirsty
# Completed: Living Gambling vs Plundering Goblins
# Completed: Living Gambling vs Plundering Gambling
# Completed: Living Gambling vs Plundering Dragons
# Completed: Living Gambling vs Stompy Dragons
# Completed: Living Gambling vs Plundering Morbid
# Completed: Living Gambling vs Plundering Stompy
# Completed: Living Gambling vs Plundering Necromancy
# Completed: Living Gambling vs Stompy Morbid
# Completed: Living Goblins vs Living Morbid
# Processing batch 164/179
# Completed: Living Goblins vs Living Stompy
# Completed: Living Goblins vs Necromancy Dragons
# Completed: Living Goblins vs Necromancy Bloodthirsty
# Completed: Living Goblins vs Necromancy Elvish
# Completed: Living Goblins vs Living Necromancy
# Completed: Living Goblins vs Necromancy Morbid
# Completed: Living Goblins vs Plundering Dragons
# Completed: Living Goblins vs Plundering Bloodthirsty
# Completed: Living Goblins vs Plundering Gambling
# Completed: Living Goblins vs Necromancy Stompy
# Completed: Living Goblins vs Plundering Goblins
# Game Living Goblins vs Plundering Elvish generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Living Goblins.dck', 'JUMPSTART\\Plundering Elvish.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 165/179
# Completed: Living Goblins vs Plundering Stompy
# Completed: Living Goblins vs Plundering Necromancy
# Completed: Living Goblins vs Stompy Dragons
# Completed: Living Goblins vs Plundering Living
# Completed: Living Goblins vs Stompy Morbid
# Completed: Living Goblins vs Plundering Morbid
# Completed: Living Morbid vs Living Necromancy
# Completed: Living Morbid vs Necromancy Bloodthirsty
# Completed: Living Morbid vs Necromancy Dragons
# Completed: Living Morbid vs Living Stompy
# Completed: Living Morbid vs Necromancy Elvish
# Completed: Living Morbid vs Necromancy Morbid
# Processing batch 166/179
# Completed: Living Morbid vs Plundering Bloodthirsty
# Completed: Living Morbid vs Plundering Goblins
# Completed: Living Morbid vs Necromancy Stompy
# Completed: Living Morbid vs Plundering Gambling
# Completed: Living Morbid vs Plundering Dragons
# Completed: Living Morbid vs Plundering Necromancy
# Completed: Living Morbid vs Plundering Stompy
# Completed: Living Morbid vs Plundering Elvish
# Completed: Living Morbid vs Stompy Morbid
# Completed: Living Morbid vs Plundering Living
# Completed: Living Morbid vs Stompy Dragons
# Game Living Morbid vs Plundering Morbid generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Living Morbid.dck', 'JUMPSTART\\Plundering Morbid.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 167/179
# Completed: Living Necromancy vs Necromancy Bloodthirsty
# Completed: Living Necromancy vs Necromancy Dragons
# Completed: Living Necromancy vs Necromancy Stompy
# Completed: Living Necromancy vs Living Stompy
# Completed: Living Necromancy vs Necromancy Elvish
# Completed: Living Necromancy vs Necromancy Morbid
# Completed: Living Necromancy vs Plundering Bloodthirsty
# Completed: Living Necromancy vs Plundering Dragons
# Completed: Living Necromancy vs Plundering Gambling
# Completed: Living Necromancy vs Plundering Goblins
# Completed: Living Necromancy vs Plundering Elvish
# Completed: Living Necromancy vs Plundering Living
# Processing batch 168/179
# Completed: Living Necromancy vs Stompy Dragons
# Completed: Living Stompy vs Necromancy Bloodthirsty
# Completed: Living Necromancy vs Stompy Morbid
# Completed: Living Necromancy vs Plundering Stompy
# Completed: Living Necromancy vs Plundering Morbid
# Completed: Living Stompy vs Necromancy Dragons
# Completed: Living Necromancy vs Plundering Necromancy
# Completed: Living Stompy vs Plundering Bloodthirsty
# Completed: Living Stompy vs Plundering Dragons
# Completed: Living Stompy vs Necromancy Stompy
# Completed: Living Stompy vs Necromancy Morbid
# Completed: Living Stompy vs Necromancy Elvish
# Processing batch 169/179
# Completed: Living Stompy vs Plundering Living
# Completed: Living Stompy vs Plundering Goblins
# Completed: Living Stompy vs Plundering Gambling
# Completed: Living Stompy vs Plundering Necromancy
# Completed: Living Stompy vs Plundering Stompy
# Completed: Living Stompy vs Plundering Morbid
# Completed: Living Stompy vs Stompy Dragons
# Completed: Necromancy Bloodthirsty vs Necromancy Dragons
# Completed: Living Stompy vs Plundering Elvish
# Completed: Living Stompy vs Stompy Morbid
# Completed: Necromancy Bloodthirsty vs Necromancy Morbid
# Completed: Necromancy Bloodthirsty vs Necromancy Elvish
# Processing batch 170/179
# Completed: Necromancy Bloodthirsty vs Plundering Elvish
# Completed: Necromancy Bloodthirsty vs Plundering Dragons
# Completed: Necromancy Bloodthirsty vs Plundering Goblins
# Completed: Necromancy Bloodthirsty vs Plundering Gambling
# Completed: Necromancy Bloodthirsty vs Plundering Living
# Completed: Necromancy Bloodthirsty vs Plundering Bloodthirsty
# Completed: Necromancy Bloodthirsty vs Necromancy Stompy
# Completed: Necromancy Bloodthirsty vs Plundering Morbid
# Completed: Necromancy Bloodthirsty vs Stompy Dragons
# Completed: Necromancy Bloodthirsty vs Plundering Stompy
# Completed: Necromancy Bloodthirsty vs Stompy Morbid
# Completed: Necromancy Bloodthirsty vs Plundering Necromancy
# Processing batch 171/179
# Completed: Necromancy Dragons vs Plundering Bloodthirsty
# Completed: Necromancy Dragons vs Necromancy Morbid
# Completed: Necromancy Dragons vs Plundering Dragons
# Completed: Necromancy Dragons vs Necromancy Stompy
# Completed: Necromancy Dragons vs Plundering Elvish
# Completed: Necromancy Dragons vs Plundering Gambling
# Completed: Necromancy Dragons vs Necromancy Elvish
# Completed: Necromancy Dragons vs Plundering Goblins
# Completed: Necromancy Dragons vs Plundering Living
# Completed: Necromancy Dragons vs Plundering Stompy
# Completed: Necromancy Dragons vs Plundering Necromancy
# Completed: Necromancy Dragons vs Plundering Morbid
# Processing batch 172/179
# Completed: Necromancy Dragons vs Stompy Dragons
# Completed: Necromancy Elvish vs Plundering Bloodthirsty
# Completed: Necromancy Elvish vs Plundering Dragons
# Completed: Necromancy Elvish vs Necromancy Stompy
# Completed: Necromancy Dragons vs Stompy Morbid
# Completed: Necromancy Elvish vs Necromancy Morbid
# Completed: Necromancy Elvish vs Plundering Living
# Completed: Necromancy Elvish vs Plundering Gambling
# Completed: Necromancy Elvish vs Plundering Morbid
# Completed: Necromancy Elvish vs Plundering Goblins
# Completed: Necromancy Elvish vs Plundering Necromancy
# Game Necromancy Elvish vs Plundering Elvish generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Necromancy Elvish.dck', 'JUMPSTART\\Plundering Elvish.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 173/179
# Completed: Necromancy Elvish vs Stompy Dragons
# Completed: Necromancy Morbid vs Necromancy Stompy
# Completed: Necromancy Morbid vs Plundering Bloodthirsty
# Completed: Necromancy Morbid vs Plundering Dragons
# Completed: Necromancy Elvish vs Stompy Morbid
# Completed: Necromancy Elvish vs Plundering Stompy
# Completed: Necromancy Morbid vs Plundering Necromancy
# Completed: Necromancy Morbid vs Plundering Gambling
# Completed: Necromancy Morbid vs Plundering Morbid
# Completed: Necromancy Morbid vs Plundering Goblins
# Completed: Necromancy Morbid vs Plundering Living
# Completed: Necromancy Morbid vs Plundering Elvish
# Processing batch 174/179
# Completed: Necromancy Morbid vs Stompy Dragons
# Completed: Necromancy Morbid vs Plundering Stompy
# Completed: Necromancy Stompy vs Plundering Dragons
# Completed: Necromancy Morbid vs Stompy Morbid
# Completed: Necromancy Stompy vs Plundering Bloodthirsty
# Completed: Necromancy Stompy vs Plundering Gambling
# Completed: Necromancy Stompy vs Plundering Goblins
# Completed: Necromancy Stompy vs Plundering Morbid
# Completed: Necromancy Stompy vs Plundering Living
# Completed: Necromancy Stompy vs Plundering Elvish
# Completed: Necromancy Stompy vs Plundering Stompy
# Completed: Necromancy Stompy vs Plundering Necromancy
# Processing batch 175/179
# Completed: Plundering Bloodthirsty vs Plundering Dragons
# Completed: Plundering Bloodthirsty vs Plundering Gambling
# Completed: Necromancy Stompy vs Stompy Morbid
# Completed: Plundering Bloodthirsty vs Plundering Elvish
# Completed: Plundering Bloodthirsty vs Plundering Goblins
# Completed: Necromancy Stompy vs Stompy Dragons
# Completed: Plundering Bloodthirsty vs Plundering Stompy
# Completed: Plundering Bloodthirsty vs Plundering Morbid
# Completed: Plundering Bloodthirsty vs Plundering Living
# Completed: Plundering Bloodthirsty vs Plundering Necromancy
# Completed: Plundering Bloodthirsty vs Stompy Dragons
# Completed: Plundering Bloodthirsty vs Stompy Morbid
# Processing batch 176/179
# Completed: Plundering Dragons vs Plundering Goblins
# Completed: Plundering Dragons vs Plundering Elvish
# Completed: Plundering Dragons vs Plundering Living
# Completed: Plundering Dragons vs Plundering Necromancy
# Completed: Plundering Dragons vs Plundering Morbid
# Completed: Plundering Dragons vs Plundering Stompy
# Completed: Plundering Dragons vs Stompy Morbid
# Completed: Plundering Dragons vs Stompy Dragons
# Completed: Plundering Elvish vs Plundering Living
# Game Plundering Dragons vs Plundering Gambling generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Plundering Dragons.dck', 'JUMPSTART\\Plundering Gambling.dck', '-m', '2', '-q']' timed out after 120 seconds
# Game Plundering Elvish vs Plundering Gambling generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Plundering Elvish.dck', 'JUMPSTART\\Plundering Gambling.dck', '-m', '2', '-q']' timed out after 120 seconds
# Game Plundering Elvish vs Plundering Goblins generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Plundering Elvish.dck', 'JUMPSTART\\Plundering Goblins.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 177/179
# Completed: Plundering Elvish vs Plundering Stompy
# Completed: Plundering Elvish vs Stompy Dragons
# Completed: Plundering Gambling vs Plundering Goblins
# Completed: Plundering Elvish vs Plundering Necromancy
# Completed: Plundering Gambling vs Plundering Necromancy
# Completed: Plundering Gambling vs Plundering Living
# Completed: Plundering Gambling vs Plundering Stompy
# Completed: Plundering Gambling vs Stompy Dragons
# Completed: Plundering Gambling vs Stompy Morbid
# Completed: Plundering Gambling vs Plundering Morbid
# Game Plundering Elvish vs Stompy Morbid generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Plundering Elvish.dck', 'JUMPSTART\\Stompy Morbid.dck', '-m', '2', '-q']' timed out after 120 seconds
# Game Plundering Elvish vs Plundering Morbid generated an exception: Command '['java', '-jar', 'forge-gui-desktop-2.0.04-jar-with-dependencies.jar', 'sim', '-d', 'JUMPSTART\\Plundering Elvish.dck', 'JUMPSTART\\Plundering Morbid.dck', '-m', '2', '-q']' timed out after 120 seconds
# Processing batch 178/179
# Completed: Plundering Goblins vs Plundering Living
# Completed: Plundering Goblins vs Plundering Stompy
# Completed: Plundering Goblins vs Stompy Dragons
# Completed: Plundering Goblins vs Plundering Morbid
# Completed: Plundering Goblins vs Plundering Necromancy
# Completed: Plundering Goblins vs Stompy Morbid
# Completed: Plundering Living vs Plundering Necromancy
# Completed: Plundering Living vs Plundering Stompy
# Completed: Plundering Morbid vs Plundering Necromancy
# Completed: Plundering Living vs Plundering Morbid
# Completed: Plundering Living vs Stompy Dragons
# Completed: Plundering Living vs Stompy Morbid
# Processing batch 179/179
# Completed: Plundering Necromancy vs Stompy Dragons
# Completed: Plundering Morbid vs Stompy Morbid
# Completed: Plundering Necromancy vs Plundering Stompy
# Completed: Plundering Morbid vs Plundering Stompy
# Completed: Plundering Necromancy vs Stompy Morbid
# Completed: Plundering Stompy vs Stompy Dragons
# Completed: Plundering Stompy vs Stompy Morbid
# Completed: Stompy Dragons vs Stompy Morbid
# Completed: Plundering Morbid vs Stompy Dragons
# Completed in 24246.00 seconds
# Results: 2053 successful, 92 failed

# %%
os.chdir(r'C:\Users\adamc\OneDrive\Documents\GitHub\JumpstartForge')
game_df = parse_game_results(all_results)
game_df.to_csv('output/game_results.csv', index=False)
# Out:
# Deck Performance Summary:
# Total decks analyzed: 66
# Best performing deck: Elvish Stompy (76.81% win rate)
# Worst performing deck: Living Gambling (24.20% win rate)

# %% [markdown]
# ### Analyze Results

# %%
game_results_df = pd.read_csv('output/game_results.csv')
# Out:
#                       deck  wins  losses  total_games  winrate  avg_turns  \
# 0            Elvish Stompy   106      32          138   0.7681       8.57
# 1            Growth Elvish   101      37          138   0.7319       8.29
# 2            Elvish Morbid    96      36          132   0.7273       9.35
# 3  Necromancy Bloodthirsty   107      49          156   0.6859       9.23
# 4  Plundering Bloodthirsty   108      54          162   0.6667       8.78
#
#    median_turns  mode_turns
# 0          8.55        8.57
# 1          8.23        8.51
# 2          9.32        9.51
# 3          9.14        9.30
# 4          8.67        8.78

# %%
game_results_df['deck1'] = game_results_df['deck'].str.split().str[0]
game_results_df['deck2'] = game_results_df['deck'].str.split().str[1]

# %%
game_results_df.head()
# Out:
#                       deck  wins  losses  total_games  winrate  avg_turns  \
# 0            Elvish Stompy   106      32          138   0.7681       8.57
# 1            Growth Elvish   101      37          138   0.7319       8.29
# 2            Elvish Morbid    96      36          132   0.7273       9.35
# 3  Necromancy Bloodthirsty   107      49          156   0.6859       9.23
# 4  Plundering Bloodthirsty   108      54          162   0.6667       8.78
#
#    median_turns  mode_turns       deck1         deck2
# 0          8.55        8.57      Elvish        Stompy
# 1          8.23        8.51      Growth        Elvish
# 2          9.32        9.51      Elvish        Morbid
# 3          9.14        9.30  Necromancy  Bloodthirsty
# 4          8.67        8.78  Plundering  Bloodthirsty

# %%
deck1_summary = game_results_df.groupby('deck1').agg({
    'wins': 'sum',
    'losses': 'sum',
    'total_games': 'sum'
}).reset_index()

deck1_summary['winrate'] = deck1_summary['wins'] / deck1_summary['total_games']
deck1_summary['winrate'] = deck1_summary['winrate'].round(4)
deck1_summary.rename(columns={'deck1': 'deck'}, inplace=True)

deck2_summary = game_results_df.groupby('deck2').agg({
    'wins': 'sum',
    'losses': 'sum',
    'total_games': 'sum'
}).reset_index()

deck2_summary['winrate'] = deck2_summary['wins'] / deck2_summary['total_games']
deck2_summary['winrate'] = deck2_summary['winrate'].round(4)
deck2_summary.rename(columns={'deck2': 'deck'}, inplace=True)

combined_summary = pd.concat([deck1_summary, deck2_summary], ignore_index=True)
combined_summary = combined_summary.groupby('deck').agg({
    'wins': 'sum',
    'losses': 'sum',
    'total_games': 'sum'
}).reset_index()

combined_summary['winrate'] = combined_summary['wins'] / combined_summary['total_games']
combined_summary['winrate'] = combined_summary['winrate'].round(4)
combined_summary.to_csv('output/combined_deck_summary.csv', index=False)

# %%
game_results_df[game_results_df['deck'].str.contains('Dragons')]
# Out:
#                     deck  wins  losses  total_games  winrate  avg_turns  \
# 15       Goblins Dragons    95      68          163   0.5828       7.61
# 34        Elvish Dragons    71      69          140   0.5071       8.25
# 35    Aggressive Dragons    82      82          164   0.5000       8.09
# 40  Bloodthirsty Dragons    76      84          160   0.4750       8.66
# 45    Plundering Dragons    74      89          163   0.4540       8.76
# 49    Necromancy Dragons    69      91          160   0.4312       8.90
# 50        Growth Dragons    68      96          164   0.4146       8.26
# 56        Stompy Dragons    59      98          157   0.3758       8.45
# 59        Dragons Morbid    55     105          160   0.3438       8.41
# 61      Gambling Dragons    54     108          162   0.3333       7.66
# 64        Living Dragons    41     113          154   0.2662       7.97
#
#     median_turns  mode_turns         deck1    deck2
# 15          7.58        7.74       Goblins  Dragons
# 34          8.17        8.45        Elvish  Dragons
# 35          8.01        8.17    Aggressive  Dragons
# 40          8.71        8.38  Bloodthirsty  Dragons
# 45          8.62        8.69    Plundering  Dragons
# 49          8.79        8.71    Necromancy  Dragons
# 50          8.23        8.20        Growth  Dragons
# 56          8.28        8.15        Stompy  Dragons
# 59          8.31        8.41       Dragons   Morbid
# 61          7.59        7.66      Gambling  Dragons
# 64          7.92        7.88        Living  Dragons
