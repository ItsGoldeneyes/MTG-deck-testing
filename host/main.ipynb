# %%
import pandas as pd
import itertools

import os
import shutil

from dotenv import load_dotenv
load_dotenv()
os.environ['FORGE_JAR_PATH'] = os.getenv('FORGE_JAR_PATH', '')

# %% [markdown]
# ### Helper Functions

# %% [markdown]
# #### Decklist Generation

# %%
def generate_decklists(cards_df):
    """
    Creates all possible Jumpstart decks (two half decks put together), then generates output .dck files for use in Forge

    Args:
        cards_df (DataFrame): Dataframe containing cards categorized into decks

    Returns:
        String: Path to output folder
    """
    deck_names = cards_df['deck'].unique()
    deck_combinations = itertools.combinations(deck_names, 2)

    output_path = os.path.join('output', 'jumpstart')
    os.makedirs(output_path, exist_ok=True)
    for filename in os.listdir(output_path):
        file_path = os.path.join(output_path, filename)
        if os.path.isfile(file_path):
            os.unlink(file_path)

    for deck1_name, deck2_name in deck_combinations:
        deck1 = cards_df[cards_df['deck'] == deck1_name]
        deck2 = cards_df[cards_df['deck'] == deck2_name]
        deck = pd.concat([deck1, deck2])

        generate_deck_file(deck, deck1_name+" "+deck2_name, output_path)

    return output_path


def generate_deck_file(deck, name='Sample Deck', output_path='output/jumpstart'):
    """
    Saves deck as a .dck file for Forge

    Args:
        deck (DataFrame): Dataframe containing cards in a deck
        name (String): Deck name
        output_path (String): Path to output folder
    """
    os.makedirs(output_path, exist_ok=True)

    with open(os.path.join(output_path, f"{name}.dck"), 'w') as f:
        f.write('[metadata]\n')
        f.write(f'Name={name}\n')
        f.write('[Avatar]\n\n')
        f.write('[Main]\n')
        for _, row in deck.iterrows():
            set_code = row['set_code'] if row['set_code'] else ''
            f.write(f"{row['quantity']} {row['name']}|{set_code}|1\n")

        f.write('[Sideboard]\n\n')
        f.write('[Planes]\n\n')
        f.write('[Schemes]\n\n')
        f.write('[Conspiracy]\n\n')
        f.write('[Dungeon]')


def add_lands(cards_df):
    """
    Adds lands to decks that do not have lands. Tedious to do in Archidekt, so it's automated!

    Args:
        cards_df (DataFrame): Dataframe containing cards categorized into decks

    Returns:
        DataFrame: Dataframe containing cards categorized into decks, with added lands
    """
    deck_names = cards_df['deck'].unique()
    lands = {
        'W': [
            {
                'quantity': '7',
                'name':     'Plains',
                'set_code': 'JMP',
                'tag':      'Land',
            },
            {
                'quantity': '1',
                'name':     'Thriving Heath',
                'set_code': 'JMP',
                'tag':      'Land'
            }
        ],
        'U': [
            {
                'quantity': '7',
                'name':     'Island',
                'set_code': 'JMP',
                'tag':      'Land'
            },
            {
                'quantity': '1',
                'name':     'Thriving Isle',
                'set_code': 'JMP',
                'tag':      'Land'
            }
        ],
        'B': [
            {
                'quantity': '7',
                'name':     'Swamp',
                'set_code': 'JMP',
                'tag':      'Land'
            },
            {
                'quantity': '1',
                'name':     'Thriving Moor',
                'set_code': 'JMP',
                'tag':      'Land'
            }
        ],
        'R': [
            {
                'quantity': '7',
                'name':     'Mountain',
                'set_code': 'JMP',
                'tag':      'Land'
            },
            {
                'quantity': '1',
                'name':     'Thriving Bluff',
                'set_code': 'JMP',
                'tag':      'Land'
            }
        ],
        'G': [
            {
                'quantity': '7',
                'name':     'Forest',
                'set_code': 'JMP',
                'tag':      'Land'
            },
            {
                'quantity': '1',
                'name':     'Thriving Grove',
                'set_code': 'JMP',
                'tag':      'Land'
            }
        ],
    }

    for deck in deck_names:
        deck_df = cards_df[cards_df['deck'] == deck]
        colour = deck_df['colour'].iloc[0]

        if deck_df[deck_df['name'].isin(['Plains', 'Island', 'Swamp', 'Mountain', 'Forest'])].empty:
            lands_df = pd.DataFrame.from_dict(lands[colour])
            lands_df['deck'] = deck

            cards_df = pd.concat([cards_df, lands_df])


    return cards_df


def parse_card(card):
    """
    Parses an individual card line from input CSV

    Args:
        card (String): Individual card line from CSV

    Returns:
        Dictionary: Card line parsed into dictionary
    """
    split_card = card.split()

    card_dict = {
        'quantity': '',
        'name':     '',
        'colour':   '',
        'set_code': '',
        'deck':     '',
        'tag':      '',
    }

    card_dict['quantity'] = split_card[0].split('x')[0]

    step = 0
    for index, word in enumerate(split_card[1:]):
        if step == 0 and '(' not in word:
            card_dict['name'] = card_dict['name'] + ' ' + word
        elif step == 0:
            step = 1

        if step == 1:
            card_dict['set_code'] = card_dict['set_code'] + ' ' + word.strip('()').upper()
            if ')' in word:
                step = 2
                continue

        if step == 2:
            deck_name = word.strip('[]')
            card_dict['deck'] = card_dict['deck'] + ' ' + deck_name
            if ' - ' in card_dict['deck']:
                card_dict['colour'] = card_dict['deck'].split(' - ')[0].strip()
                card_dict['deck'] = card_dict['deck'].split(' - ')[1].strip()
            if ']' in word:
                step = 3
            continue

        if step == 3:
            card_dict['tag'] = word.split(',')[0].strip('^')

    for key in card_dict:
        card_dict[key] = card_dict[key].strip().replace('/', '')

    return card_dict


def parse_decks(cards):
    """
    Parses an input CSV

    Args:
        cards (List): List of card lines from CSV

    Returns:
        DataFrame: All cards processed
    """
    card_list = [parse_card(card) for card in cards]
    cards_df = pd.DataFrame.from_dict(card_list)

    return cards_df

# %% [markdown]
# ### Running Games

# %%
import subprocess
import concurrent.futures
from threading import Lock
import time

# %%
# Global lock for thread-safe operations if needed
game_lock = Lock()

def run_game(deck1_name, deck2_name, num_games=1, working_dir=None):
    """
    Run a single game between two decks

    Args:
        deck1_name (str): Name of the first deck
        deck2_name (str): Name of the second deck
        num_games (int): Number of games to run (default 1)
        working_dir (str): Working directory for the Java process

    Returns:
        subprocess.CompletedProcess: Game output
    """
    if working_dir is None:
        working_dir = os.path.dirname(os.environ.get("FORGE_JAR_PATH", ""))

    original_cwd = os.getcwd()
    try:
        if working_dir:
            os.chdir(working_dir)

        game_output = subprocess.run([
            "java", "-jar", os.path.basename(os.environ.get("FORGE_JAR_PATH", "")),
            "sim", "-d",
            os.path.join("JUMPSTART", f"{deck1_name}.dck"),
            os.path.join("JUMPSTART", f"{deck2_name}.dck"),
            "-m", str(num_games),
            "-q"
        ], capture_output=True, text=True, timeout=500)

        return game_output
    finally:
        os.chdir(original_cwd)

def run_games_multithreaded(deck_pairs, num_games_per_pair=10, max_workers=4):
    """
    Run multiple games concurrently using ThreadPoolExecutor

    Args:
        deck_pairs (list): List of tuples containing (deck1_name, deck2_name)
        num_games_per_pair (int): Number of games to run for each deck pair
        max_workers (int): Maximum number of concurrent threads

    Returns:
        list: List of results for each game
    """
    results = []

    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit all games to the thread pool
        future_to_decks = {}

        for deck1, deck2 in deck_pairs:
            future = executor.submit(run_game, deck1, deck2, num_games_per_pair)
            future_to_decks[future] = (deck1, deck2)

        # Collect results as they complete
        for future in concurrent.futures.as_completed(future_to_decks):
            deck1, deck2 = future_to_decks[future]
            try:
                result = future.result()
                results.append({
                    'deck1': deck1,
                    'deck2': deck2,
                    'result': result,
                    'success': result.returncode == 0
                })
                print(f"Completed: {deck1} vs {deck2}")
            except Exception as exc:
                print(f"Game {deck1} vs {deck2} generated an exception: {exc}")
                results.append({
                    'deck1': deck1,
                    'deck2': deck2,
                    'result': None,
                    'success': False,
                    'error': str(exc)
                })

    return results

def run_games_batch(deck_pairs, num_games_per_pair=10, max_workers=4, batch_size=None):
    """
    Run games in batches to avoid overwhelming the system

    Args:
        deck_pairs (list): List of tuples containing (deck1_name, deck2_name)
        num_games_per_pair (int): Number of games to run for each deck pair
        max_workers (int): Maximum number of concurrent threads
        batch_size (int): Number of deck pairs to process in each batch (default: max_workers * 2)

    Returns:
        list: List of results for all games
    """
    if batch_size is None:
        batch_size = max_workers * 2

    all_results = []

    for i in range(0, len(deck_pairs), batch_size):
        batch = deck_pairs[i:i + batch_size]
        print(f"Processing batch {i//batch_size + 1}/{(len(deck_pairs) + batch_size - 1)//batch_size}")

        batch_results = run_games_multithreaded(batch, num_games_per_pair, max_workers)
        all_results.extend(batch_results)

        # Optional: Add a small delay between batches to prevent system overload
        time.sleep(0.5)

    return all_results

# %%
def get_all_deck_combinations():
    """
    Get all possible deck combinations from the output directory
    Each .dck file is a complete deck, so we create pairs of these decks to play against each other

    Returns:
        list: List of tuples containing (deck1_name, deck2_name) where each name is a complete deck file name (without .dck extension)
    """
    jumpstart_dir = os.path.join('output', 'jumpstart')
    if not os.path.exists(jumpstart_dir):
        return []

    # Get all deck file names (without .dck extension)
    deck_names = [f[:-4] for f in os.listdir(jumpstart_dir) if f.endswith('.dck')]

    # deck_names = [name for name in deck_names if 'living' in name.lower() or 'dragons' in name.lower()]

    # Create all possible combinations of decks
    deck_pairs = []
    for i, deck1 in enumerate(deck_names):
        for deck2 in deck_names[i+1:]:  # Avoid duplicates and self-matches
            deck_pairs.append((deck1, deck2))
    return deck_pairs

def get_sample_deck_combinations(num_combinations=10):
    """
    Get a sample of deck combinations for testing

    Args:
        num_combinations (int): Number of random combinations to return

    Returns:
        list: List of tuples containing (deck1_name, deck2_name)
    """
    import random
    all_combinations = get_all_deck_combinations()

    if len(all_combinations) <= num_combinations:
        return all_combinations

    return random.sample(all_combinations, num_combinations)

def evaluate_all_decks_multithreaded(num_games=10, max_workers=4):
    """
    Evaluate all deck combinations using multithreading

    Args:
        num_games (int): Number of games to run for each deck pair
        max_workers (int): Maximum number of concurrent threads

    Returns:
        list: Results from all games
    """
    deck_pairs = get_all_deck_combinations()
    print(f"Found {len(deck_pairs)} deck combinations to evaluate")

    if not deck_pairs:
        print("No deck combinations found. Make sure decks have been generated first.")
        return []

    print(f"Running {num_games} games per combination with {max_workers} workers...")
    start_time = time.time()

    results = run_games_batch(deck_pairs, num_games, max_workers)

    end_time = time.time()
    print(f"Completed in {end_time - start_time:.2f} seconds")

    # Summary statistics
    successful_games = sum(1 for r in results if r['success'])
    failed_games = len(results) - successful_games

    print(f"Results: {successful_games} successful, {failed_games} failed")

    return results

def evaluate_sample_decks_multithreaded(num_combinations=10, num_games=10, max_workers=4):
    """
    Evaluate a sample of deck combinations using multithreading (useful for testing)

    Args:
        num_combinations (int): Number of random deck combinations to test
        num_games (int): Number of games to run for each deck pair
        max_workers (int): Maximum number of concurrent threads

    Returns:
        list: Results from all games
    """
    deck_pairs = get_sample_deck_combinations(num_combinations)
    print(f"Testing {len(deck_pairs)} random deck combinations")

    if not deck_pairs:
        print("No deck combinations found. Make sure decks have been generated first.")
        return []

    print(f"Running {num_games} games per combination with {max_workers} workers...")
    start_time = time.time()

    results = run_games_batch(deck_pairs, num_games, max_workers)

    end_time = time.time()
    print(f"Completed in {end_time - start_time:.2f} seconds")

    # Summary statistics
    successful_games = sum(1 for r in results if r['success'])
    failed_games = len(results) - successful_games

    print(f"Results: {successful_games} successful, {failed_games} failed")

    return results

def parse_game_results(results):
    """
    Parse game results to extract win rates and statistics, creating one row per deck

    Args:
        results (list): Results from run_games_multithreaded or run_games_batch

    Returns:
        pandas.DataFrame: DataFrame with one row per deck including wins, winrate, and turn count statistics
    """
    from statistics import mode, median

    # First, parse individual game results
    game_data = []

    for result in results:
        if result['success'] and result['result']:
            output = result['result'].stdout
            lines = output.strip().split('\n')

            wins_deck1 = 0
            wins_deck2 = 0
            total_games = 0
            turn_counts = []

            for line in lines:
                if 'game outcome: turn' in line.lower():
                    try:
                        turn_count = int(line.lower().split()[-1])
                        turn_counts.append(turn_count)
                    except (ValueError, IndexError):
                        pass

                if 'won!' in line.lower():
                    total_games += 1
                    if result['deck1'].lower() in line.lower():
                        wins_deck1 += 1
                    elif result['deck2'].lower() in line.lower():
                        wins_deck2 += 1

            # Add data for each deck in this matchup
            if total_games > 0:
                avg_turns = sum(turn_counts) / len(turn_counts) if turn_counts else 0
                median_turns = median(turn_counts) if turn_counts else 0
                try:
                    mode_turns = mode(turn_counts) if turn_counts else 0
                except:
                    mode_turns = turn_counts[0] if turn_counts else 0

                # Add deck1 data
                game_data.append({
                    'deck': result['deck1'],
                    'wins': wins_deck1,
                    'losses': wins_deck2,
                    'total_games': total_games,
                    'avg_turns': avg_turns,
                    'median_turns': median_turns,
                    'mode_turns': mode_turns
                })

                # Add deck2 data
                game_data.append({
                    'deck': result['deck2'],
                    'wins': wins_deck2,
                    'losses': wins_deck1,
                    'total_games': total_games,
                    'avg_turns': avg_turns,
                    'median_turns': median_turns,
                    'mode_turns': mode_turns
                })

    if not game_data:
        return pd.DataFrame()

    # Convert to DataFrame for easier aggregation
    df = pd.DataFrame(game_data)

    # Aggregate by deck name
    deck_summary = df.groupby('deck').agg({
        'wins': 'sum',
        'losses': 'sum',
        'total_games': 'sum',
        'avg_turns': 'mean',
        'median_turns': 'mean',
        'mode_turns': 'mean'
    }).reset_index()

    # Calculate win rate
    deck_summary['winrate'] = deck_summary['wins'] / deck_summary['total_games']
    deck_summary['winrate'] = deck_summary['winrate'].round(4)

    # Round turn statistics
    deck_summary['avg_turns'] = deck_summary['avg_turns'].round(2)
    deck_summary['median_turns'] = deck_summary['median_turns'].round(2)
    deck_summary['mode_turns'] = deck_summary['mode_turns'].round(2)

    # Sort by win rate (descending)
    deck_summary = deck_summary.sort_values('winrate', ascending=False).reset_index(drop=True)

    # Reorder columns for better readability
    deck_summary = deck_summary[['deck', 'wins', 'losses', 'total_games', 'winrate',
                                'avg_turns', 'median_turns', 'mode_turns']]

    print(f"\nDeck Performance Summary:")
    print(f"Total decks analyzed: {len(deck_summary)}")
    print(f"Best performing deck: {deck_summary.iloc[0]['deck']} ({deck_summary.iloc[0]['winrate']:.2%} win rate)")
    print(f"Worst performing deck: {deck_summary.iloc[-1]['deck']} ({deck_summary.iloc[-1]['winrate']:.2%} win rate)")

    return deck_summary

# %% [markdown]
# ### Process Decks

# %%
with open('input/jumpstart.txt', 'r') as file:
    cards = file.readlines()

cards_df = parse_decks(cards)
cards_df = add_lands(cards_df)

assert len(cards_df['deck'].unique()) == cards_df['quantity'].astype(int).sum() // 20, "Deck count does not match expected value (cards/20)"

deck_path = generate_decklists(cards_df)
forge_path = os.getenv("FORGE_DECKS_PATH")

# Clear the folder at FORGE_PATH
if forge_path and os.path.exists(forge_path):
    for filename in os.listdir(forge_path):
        file_path = os.path.join(forge_path, filename)
        if os.path.isfile(file_path) or os.path.islink(file_path):
            os.unlink(file_path)
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)

# Copy contents of deck_path to FORGE_PATH
if forge_path and os.path.exists(deck_path):
    for filename in os.listdir(deck_path):
        src_file = os.path.join(deck_path, filename)
        dst_file = os.path.join(forge_path, filename)
        shutil.copy2(src_file, dst_file)

# %% [markdown]
# ### Run Games

# %%
original_dir = os.getcwd()

# %%
all_results = evaluate_all_decks_multithreaded(num_games=5, max_workers=8)
# all_results = evaluate_sample_decks_multithreaded(num_combinations=10, num_games=2, max_workers=8)
# Out:
# Found 2145 deck combinations to evaluate
# Running 5 games per combination with 8 workers...
# Processing batch 1/135
# Completed: Aggressive Bloodthirsty vs Aggressive Goblins
# Completed: Aggressive Bloodthirsty vs Aggressive Dragons
# Completed: Aggressive Bloodthirsty vs Aggressive Plundering
# Completed: Aggressive Bloodthirsty vs Aggressive Morbid
# Completed: Aggressive Bloodthirsty vs Aggressive Elvish
# Completed: Aggressive Bloodthirsty vs Aggressive Necromancy
# Completed: Aggressive Bloodthirsty vs Aggressive Dinos
# Completed: Aggressive Bloodthirsty vs Aggressive Flourishing
# Completed: Aggressive Bloodthirsty vs Beefy Bloodthirsty
# Completed: Aggressive Bloodthirsty vs Beefy Dragons
# Completed: Aggressive Bloodthirsty vs Beefy Dinos
# Completed: Aggressive Bloodthirsty vs Beefy Aggressive
# Completed: Aggressive Bloodthirsty vs Beefy Gambling
# Completed: Aggressive Bloodthirsty vs Beefy Goblins
# Completed: Aggressive Bloodthirsty vs Beefy Flourishing
# Completed: Aggressive Bloodthirsty vs Beefy Elvish
# Processing batch 2/135
# Completed: Aggressive Bloodthirsty vs Dinos Dragons
# Completed: Aggressive Bloodthirsty vs Bloodthirsty Morbid
# Completed: Aggressive Bloodthirsty vs Bloodthirsty Dragons
# Completed: Aggressive Bloodthirsty vs Beefy Morbid
# Completed: Aggressive Bloodthirsty vs Beefy Necromancy
# Completed: Aggressive Bloodthirsty vs Bloodthirsty Elvish
# Completed: Aggressive Bloodthirsty vs Bloodthirsty Dinos
# Completed: Aggressive Bloodthirsty vs Dinos Morbid
# Completed: Aggressive Bloodthirsty vs Dragons Morbid
# Completed: Aggressive Bloodthirsty vs Elvish Dragons
# Completed: Aggressive Bloodthirsty vs Elvish Dinos
# Completed: Aggressive Bloodthirsty vs Flourishing Bloodthirsty
# Completed: Aggressive Bloodthirsty vs Flourishing Dragons
# Completed: Aggressive Bloodthirsty vs Beefy Plundering
# Completed: Aggressive Bloodthirsty vs Flourishing Dinos
# Completed: Aggressive Bloodthirsty vs Elvish Morbid
# Processing batch 3/135
# Completed: Aggressive Bloodthirsty vs Gambling Bloodthirsty
# Completed: Aggressive Bloodthirsty vs Flourishing Morbid
# Completed: Aggressive Bloodthirsty vs Gambling Aggressive
# Completed: Aggressive Bloodthirsty vs Gambling Dinos
# Completed: Aggressive Bloodthirsty vs Gambling Dragons
# Completed: Aggressive Bloodthirsty vs Flourishing Goblins
# Completed: Aggressive Bloodthirsty vs Flourishing Necromancy
# Completed: Aggressive Bloodthirsty vs Gambling Morbid
# Completed: Aggressive Bloodthirsty vs Gambling Flourishing
# Completed: Aggressive Bloodthirsty vs Gambling Plundering
# Completed: Aggressive Bloodthirsty vs Gambling Goblins
# Completed: Aggressive Bloodthirsty vs Gambling Necromancy
# Completed: Aggressive Bloodthirsty vs Goblins Bloodthirsty
# Completed: Aggressive Bloodthirsty vs Flourishing Elvish
# Completed: Aggressive Bloodthirsty vs Goblins Dinos
# Completed: Aggressive Bloodthirsty vs Gambling Elvish
# Processing batch 4/135
# Completed: Aggressive Bloodthirsty vs Goblins Necromancy
# Completed: Aggressive Bloodthirsty vs Necromancy Dragons
# Completed: Aggressive Bloodthirsty vs Necromancy Dinos
# Completed: Aggressive Bloodthirsty vs Goblins Dragons
# Completed: Aggressive Bloodthirsty vs Necromancy Bloodthirsty
# Completed: Aggressive Bloodthirsty vs Goblins Morbid
# Completed: Aggressive Bloodthirsty vs Plundering Bloodthirsty
# Completed: Aggressive Bloodthirsty vs Necromancy Elvish
# Completed: Aggressive Bloodthirsty vs Plundering Dinos
# Completed: Aggressive Bloodthirsty vs Plundering Dragons
# Completed: Aggressive Bloodthirsty vs Necromancy Morbid
# Completed: Aggressive Bloodthirsty vs Goblins Elvish
# Completed: Aggressive Bloodthirsty vs Plundering Goblins
# Completed: Aggressive Bloodthirsty vs Plundering Morbid
# Completed: Aggressive Bloodthirsty vs Plundering Flourishing
# Completed: Aggressive Bloodthirsty vs Plundering Elvish
# Processing batch 5/135
# Completed: Aggressive Dinos vs Aggressive Necromancy
# Completed: Aggressive Dinos vs Aggressive Dragons
# Completed: Aggressive Dinos vs Aggressive Plundering
# Completed: Aggressive Dinos vs Aggressive Flourishing
# Completed: Aggressive Dinos vs Aggressive Goblins
# Completed: Aggressive Bloodthirsty vs Plundering Necromancy
# Completed: Aggressive Dinos vs Beefy Bloodthirsty
# Completed: Aggressive Dinos vs Aggressive Elvish
# Completed: Aggressive Dinos vs Beefy Dinos
# Completed: Aggressive Dinos vs Beefy Aggressive
# Completed: Aggressive Dinos vs Beefy Dragons
# Completed: Aggressive Dinos vs Aggressive Morbid
# Completed: Aggressive Dinos vs Beefy Gambling
# Completed: Aggressive Dinos vs Beefy Goblins
# Completed: Aggressive Dinos vs Beefy Elvish
# Completed: Aggressive Dinos vs Beefy Flourishing
# Processing batch 6/135
# Completed: Aggressive Dinos vs Bloodthirsty Dragons
# Completed: Aggressive Dinos vs Bloodthirsty Morbid
# Completed: Aggressive Dinos vs Bloodthirsty Dinos
# Completed: Aggressive Dinos vs Beefy Necromancy
# Completed: Aggressive Dinos vs Beefy Plundering
# Completed: Aggressive Dinos vs Beefy Morbid
# Completed: Aggressive Dinos vs Dragons Morbid
# Completed: Aggressive Dinos vs Elvish Dragons
# Completed: Aggressive Dinos vs Flourishing Bloodthirsty
# Completed: Aggressive Dinos vs Flourishing Dinos
# Completed: Aggressive Dinos vs Elvish Morbid
# Completed: Aggressive Dinos vs Elvish Dinos
# Completed: Aggressive Dinos vs Flourishing Dragons
# Completed: Aggressive Dinos vs Dinos Dragons
# Completed: Aggressive Dinos vs Bloodthirsty Elvish
# Completed: Aggressive Dinos vs Dinos Morbid
# Processing batch 7/135
# Completed: Aggressive Dinos vs Gambling Dragons
# Completed: Aggressive Dinos vs Flourishing Goblins
# Completed: Aggressive Dinos vs Gambling Aggressive
# Completed: Aggressive Dinos vs Gambling Bloodthirsty
# Completed: Aggressive Dinos vs Gambling Dinos
# Completed: Aggressive Dinos vs Flourishing Elvish
# Completed: Aggressive Dinos vs Gambling Morbid
# Completed: Aggressive Dinos vs Gambling Necromancy
# Completed: Aggressive Dinos vs Gambling Goblins
# Completed: Aggressive Dinos vs Flourishing Necromancy
# Completed: Aggressive Dinos vs Gambling Plundering
# Completed: Aggressive Dinos vs Gambling Flourishing
# Completed: Aggressive Dinos vs Goblins Bloodthirsty
# Completed: Aggressive Dinos vs Flourishing Morbid
# Completed: Aggressive Dinos vs Gambling Elvish
# Completed: Aggressive Dinos vs Goblins Dinos
# Processing batch 8/135
# Completed: Aggressive Dinos vs Necromancy Bloodthirsty
# Completed: Aggressive Dinos vs Necromancy Dinos
# Completed: Aggressive Dinos vs Necromancy Dragons
# Completed: Aggressive Dinos vs Goblins Necromancy
# Completed: Aggressive Dinos vs Goblins Morbid
# Completed: Aggressive Dinos vs Goblins Dragons
# Completed: Aggressive Dinos vs Necromancy Morbid
# Completed: Aggressive Dinos vs Goblins Elvish
# Completed: Aggressive Dinos vs Necromancy Elvish
# Completed: Aggressive Dinos vs Plundering Dragons
# Completed: Aggressive Dinos vs Plundering Bloodthirsty
# Completed: Aggressive Dinos vs Plundering Dinos
# Completed: Aggressive Dinos vs Plundering Elvish
# Completed: Aggressive Dinos vs Plundering Goblins
# Completed: Aggressive Dinos vs Plundering Morbid
# Completed: Aggressive Dinos vs Plundering Flourishing
# Processing batch 9/135
# Completed: Aggressive Dragons vs Aggressive Elvish
# Completed: Aggressive Dragons vs Beefy Aggressive
# Completed: Aggressive Dragons vs Aggressive Plundering
# Completed: Aggressive Dragons vs Aggressive Goblins
# Completed: Aggressive Dinos vs Plundering Necromancy
# Completed: Aggressive Dragons vs Aggressive Necromancy
# Completed: Aggressive Dragons vs Aggressive Morbid
# Completed: Aggressive Dragons vs Beefy Dinos
# Completed: Aggressive Dragons vs Aggressive Flourishing
# Completed: Aggressive Dragons vs Beefy Bloodthirsty
# Completed: Aggressive Dragons vs Beefy Dragons
# Completed: Aggressive Dragons vs Beefy Flourishing
# Completed: Aggressive Dragons vs Beefy Goblins
# Completed: Aggressive Dragons vs Beefy Gambling
# Completed: Aggressive Dragons vs Beefy Morbid
# Completed: Aggressive Dragons vs Beefy Elvish
# Processing batch 10/135
# Completed: Aggressive Dragons vs Dinos Morbid
# Completed: Aggressive Dragons vs Beefy Necromancy
# Completed: Aggressive Dragons vs Beefy Plundering
# Completed: Aggressive Dragons vs Dinos Dragons
# Completed: Aggressive Dragons vs Bloodthirsty Morbid
# Completed: Aggressive Dragons vs Bloodthirsty Elvish
# Completed: Aggressive Dragons vs Bloodthirsty Dragons
# Completed: Aggressive Dragons vs Bloodthirsty Dinos
# Completed: Aggressive Dragons vs Dragons Morbid
# Completed: Aggressive Dragons vs Elvish Dinos
# Completed: Aggressive Dragons vs Elvish Dragons
# Completed: Aggressive Dragons vs Flourishing Elvish
# Completed: Aggressive Dragons vs Flourishing Bloodthirsty
# Completed: Aggressive Dragons vs Flourishing Dinos
# Completed: Aggressive Dragons vs Elvish Morbid
# Completed: Aggressive Dragons vs Flourishing Dragons
# Processing batch 11/135
# Completed: Aggressive Dragons vs Gambling Dinos
# Completed: Aggressive Dragons vs Gambling Dragons
# Completed: Aggressive Dragons vs Flourishing Morbid
# Completed: Aggressive Dragons vs Flourishing Goblins
# Completed: Aggressive Dragons vs Gambling Elvish
# Completed: Aggressive Dragons vs Gambling Aggressive
# Completed: Aggressive Dragons vs Gambling Bloodthirsty
# Completed: Aggressive Dragons vs Flourishing Necromancy
# Completed: Aggressive Dragons vs Gambling Morbid
# Completed: Aggressive Dragons vs Gambling Flourishing
# Completed: Aggressive Dragons vs Gambling Plundering
# Completed: Aggressive Dragons vs Goblins Dinos
# Completed: Aggressive Dragons vs Gambling Necromancy
# Completed: Aggressive Dragons vs Goblins Bloodthirsty
# Completed: Aggressive Dragons vs Goblins Dragons
# Completed: Aggressive Dragons vs Gambling Goblins
# Processing batch 12/135
# Completed: Aggressive Dragons vs Necromancy Bloodthirsty
# Completed: Aggressive Dragons vs Necromancy Dragons
# Completed: Aggressive Dragons vs Goblins Morbid
# Completed: Aggressive Dragons vs Necromancy Dinos
# Completed: Aggressive Dragons vs Necromancy Elvish
# Completed: Aggressive Dragons vs Necromancy Morbid
# Completed: Aggressive Dragons vs Goblins Elvish
# Completed: Aggressive Dragons vs Goblins Necromancy
# Completed: Aggressive Dragons vs Plundering Bloodthirsty
# Completed: Aggressive Dragons vs Plundering Dragons
# Completed: Aggressive Dragons vs Plundering Flourishing
# Completed: Aggressive Dragons vs Plundering Dinos
# Completed: Aggressive Dragons vs Plundering Morbid
# Completed: Aggressive Dragons vs Plundering Elvish
# Completed: Aggressive Dragons vs Plundering Goblins
# Completed: Aggressive Dragons vs Plundering Necromancy
# Processing batch 13/135
# Completed: Aggressive Elvish vs Beefy Aggressive
# Completed: Aggressive Elvish vs Beefy Bloodthirsty
# Completed: Aggressive Elvish vs Aggressive Goblins
# Completed: Aggressive Elvish vs Aggressive Necromancy
# Completed: Aggressive Elvish vs Beefy Elvish
# Completed: Aggressive Elvish vs Beefy Dragons
# Completed: Aggressive Elvish vs Beefy Goblins
# Completed: Aggressive Elvish vs Beefy Morbid
# Completed: Aggressive Elvish vs Beefy Flourishing
# Completed: Aggressive Elvish vs Aggressive Flourishing
# Completed: Aggressive Elvish vs Aggressive Morbid
# Completed: Aggressive Elvish vs Beefy Gambling
# Completed: Aggressive Elvish vs Beefy Plundering
# Completed: Aggressive Elvish vs Aggressive Plundering
# Completed: Aggressive Elvish vs Beefy Dinos
# Completed: Aggressive Elvish vs Beefy Necromancy
# Processing batch 14/135
# Completed: Aggressive Elvish vs Dragons Morbid
# Completed: Aggressive Elvish vs Dinos Dragons
# Completed: Aggressive Elvish vs Bloodthirsty Dragons
# Completed: Aggressive Elvish vs Bloodthirsty Dinos
# Completed: Aggressive Elvish vs Dinos Morbid
# Completed: Aggressive Elvish vs Elvish Dragons
# Completed: Aggressive Elvish vs Bloodthirsty Elvish
# Completed: Aggressive Elvish vs Flourishing Bloodthirsty
# Completed: Aggressive Elvish vs Flourishing Dragons
# Completed: Aggressive Elvish vs Flourishing Goblins
# Completed: Aggressive Elvish vs Bloodthirsty Morbid
# Completed: Aggressive Elvish vs Flourishing Dinos
# Completed: Aggressive Elvish vs Elvish Dinos
# Completed: Aggressive Elvish vs Flourishing Morbid
# Completed: Aggressive Elvish vs Elvish Morbid
# Completed: Aggressive Elvish vs Flourishing Elvish
# Processing batch 15/135
# Completed: Aggressive Elvish vs Gambling Bloodthirsty
# Completed: Aggressive Elvish vs Gambling Dinos
# Completed: Aggressive Elvish vs Gambling Aggressive
# Completed: Aggressive Elvish vs Gambling Dragons
# Completed: Aggressive Elvish vs Gambling Flourishing
# Completed: Aggressive Elvish vs Gambling Necromancy
# Completed: Aggressive Elvish vs Gambling Morbid
# Completed: Aggressive Elvish vs Gambling Plundering
# Completed: Aggressive Elvish vs Gambling Elvish
# Completed: Aggressive Elvish vs Flourishing Necromancy
# Completed: Aggressive Elvish vs Gambling Goblins
# Completed: Aggressive Elvish vs Goblins Dragons
# Completed: Aggressive Elvish vs Goblins Bloodthirsty
# Completed: Aggressive Elvish vs Goblins Morbid
# Completed: Aggressive Elvish vs Goblins Elvish
# Completed: Aggressive Elvish vs Goblins Dinos
# Processing batch 16/135
# Completed: Aggressive Elvish vs Necromancy Dragons
# Completed: Aggressive Elvish vs Plundering Bloodthirsty
# Completed: Aggressive Elvish vs Necromancy Bloodthirsty
# Completed: Aggressive Elvish vs Necromancy Dinos
# Completed: Aggressive Elvish vs Goblins Necromancy
# Completed: Aggressive Elvish vs Plundering Dinos
# Completed: Aggressive Elvish vs Plundering Dragons
# Completed: Aggressive Elvish vs Plundering Goblins
# Completed: Aggressive Elvish vs Plundering Elvish
# Completed: Aggressive Elvish vs Plundering Flourishing
# Completed: Aggressive Flourishing vs Aggressive Goblins
# Completed: Aggressive Elvish vs Necromancy Elvish
# Completed: Aggressive Elvish vs Plundering Necromancy
# Completed: Aggressive Elvish vs Necromancy Morbid
# Completed: Aggressive Flourishing vs Aggressive Morbid
# Completed: Aggressive Elvish vs Plundering Morbid
# Processing batch 17/135
# Completed: Aggressive Flourishing vs Beefy Dragons
# Completed: Aggressive Flourishing vs Beefy Elvish
# Completed: Aggressive Flourishing vs Beefy Bloodthirsty
# Completed: Aggressive Flourishing vs Beefy Flourishing
# Completed: Aggressive Flourishing vs Beefy Aggressive
# Completed: Aggressive Flourishing vs Aggressive Necromancy
# Completed: Aggressive Flourishing vs Aggressive Plundering
# Completed: Aggressive Flourishing vs Beefy Dinos
# Completed: Aggressive Flourishing vs Beefy Goblins
# Completed: Aggressive Flourishing vs Bloodthirsty Dragons
# Completed: Aggressive Flourishing vs Bloodthirsty Dinos
# Completed: Aggressive Flourishing vs Beefy Plundering
# Completed: Aggressive Flourishing vs Beefy Necromancy
# Completed: Aggressive Flourishing vs Bloodthirsty Elvish
# Completed: Aggressive Flourishing vs Beefy Morbid
# Completed: Aggressive Flourishing vs Beefy Gambling
# Processing batch 18/135
# Completed: Aggressive Flourishing vs Flourishing Bloodthirsty
# Completed: Aggressive Flourishing vs Bloodthirsty Morbid
# Completed: Aggressive Flourishing vs Dinos Dragons
# Completed: Aggressive Flourishing vs Elvish Dragons
# Completed: Aggressive Flourishing vs Elvish Morbid
# Completed: Aggressive Flourishing vs Elvish Dinos
# Completed: Aggressive Flourishing vs Dragons Morbid
# Completed: Aggressive Flourishing vs Flourishing Dinos
# Completed: Aggressive Flourishing vs Gambling Aggressive
# Completed: Aggressive Flourishing vs Flourishing Dragons
# Completed: Aggressive Flourishing vs Flourishing Elvish
# Completed: Aggressive Flourishing vs Flourishing Goblins
# Completed: Aggressive Flourishing vs Gambling Bloodthirsty
# Completed: Aggressive Flourishing vs Flourishing Necromancy
# Completed: Aggressive Flourishing vs Dinos Morbid
# Completed: Aggressive Flourishing vs Flourishing Morbid
# Processing batch 19/135
# Completed: Aggressive Flourishing vs Gambling Dragons
# Completed: Aggressive Flourishing vs Gambling Plundering
# Completed: Aggressive Flourishing vs Gambling Dinos
# Completed: Aggressive Flourishing vs Goblins Bloodthirsty
# Completed: Aggressive Flourishing vs Gambling Flourishing
# Completed: Aggressive Flourishing vs Gambling Necromancy
# Completed: Aggressive Flourishing vs Gambling Elvish
# Completed: Aggressive Flourishing vs Goblins Dragons
# Completed: Aggressive Flourishing vs Gambling Goblins
# Completed: Aggressive Flourishing vs Gambling Morbid
# Completed: Aggressive Flourishing vs Necromancy Dinos
# Completed: Aggressive Flourishing vs Necromancy Bloodthirsty
# Completed: Aggressive Flourishing vs Goblins Necromancy
# Completed: Aggressive Flourishing vs Goblins Elvish
# Completed: Aggressive Flourishing vs Goblins Morbid
# Completed: Aggressive Flourishing vs Goblins Dinos
# Processing batch 20/135
# Completed: Aggressive Flourishing vs Plundering Dragons
# Completed: Aggressive Flourishing vs Plundering Bloodthirsty
# Completed: Aggressive Flourishing vs Plundering Dinos
# Completed: Aggressive Flourishing vs Plundering Flourishing
# Completed: Aggressive Flourishing vs Necromancy Dragons
# Completed: Aggressive Flourishing vs Plundering Elvish
# Completed: Aggressive Goblins vs Aggressive Morbid
# Completed: Aggressive Flourishing vs Necromancy Morbid
# Completed: Aggressive Flourishing vs Plundering Goblins
# Completed: Aggressive Goblins vs Aggressive Plundering
# Completed: Aggressive Goblins vs Aggressive Necromancy
# Completed: Aggressive Goblins vs Beefy Bloodthirsty
# Completed: Aggressive Goblins vs Beefy Aggressive
# Completed: Aggressive Flourishing vs Necromancy Elvish
# Completed: Aggressive Flourishing vs Plundering Morbid
# Completed: Aggressive Flourishing vs Plundering Necromancy
# Processing batch 21/135
# Completed: Aggressive Goblins vs Beefy Gambling
# Completed: Aggressive Goblins vs Beefy Dragons
# Completed: Aggressive Goblins vs Beefy Dinos
# Completed: Aggressive Goblins vs Beefy Elvish
# Completed: Aggressive Goblins vs Beefy Morbid
# Completed: Aggressive Goblins vs Beefy Flourishing
# Completed: Aggressive Goblins vs Bloodthirsty Dragons
# Completed: Aggressive Goblins vs Bloodthirsty Elvish
# Completed: Aggressive Goblins vs Beefy Goblins
# Completed: Aggressive Goblins vs Bloodthirsty Morbid
# Completed: Aggressive Goblins vs Bloodthirsty Dinos
# Completed: Aggressive Goblins vs Beefy Necromancy
# Completed: Aggressive Goblins vs Dinos Morbid
# Completed: Aggressive Goblins vs Dinos Dragons
# Completed: Aggressive Goblins vs Dragons Morbid
# Completed: Aggressive Goblins vs Beefy Plundering
# Processing batch 22/135
# Completed: Aggressive Goblins vs Flourishing Goblins
# Completed: Aggressive Goblins vs Elvish Morbid
# Completed: Aggressive Goblins vs Flourishing Dragons
# Completed: Aggressive Goblins vs Elvish Dragons
# Completed: Aggressive Goblins vs Flourishing Bloodthirsty
# Completed: Aggressive Goblins vs Flourishing Morbid
# Completed: Aggressive Goblins vs Elvish Dinos
# Completed: Aggressive Goblins vs Gambling Bloodthirsty
# Completed: Aggressive Goblins vs Gambling Aggressive
# Completed: Aggressive Goblins vs Flourishing Dinos
# Completed: Aggressive Goblins vs Gambling Dragons
# Completed: Aggressive Goblins vs Flourishing Necromancy
# Completed: Aggressive Goblins vs Gambling Elvish
# Completed: Aggressive Goblins vs Gambling Dinos
# Completed: Aggressive Goblins vs Flourishing Elvish
# Completed: Aggressive Goblins vs Gambling Flourishing
# Processing batch 23/135
# Completed: Aggressive Goblins vs Goblins Bloodthirsty
# Completed: Aggressive Goblins vs Goblins Elvish
# Completed: Aggressive Goblins vs Gambling Morbid
# Completed: Aggressive Goblins vs Goblins Dragons
# Completed: Aggressive Goblins vs Gambling Plundering
# Completed: Aggressive Goblins vs Gambling Necromancy
# Completed: Aggressive Goblins vs Necromancy Dinos
# Completed: Aggressive Goblins vs Necromancy Bloodthirsty
# Completed: Aggressive Goblins vs Necromancy Dragons
# Completed: Aggressive Goblins vs Goblins Necromancy
# Completed: Aggressive Goblins vs Plundering Bloodthirsty
# Completed: Aggressive Goblins vs Gambling Goblins
# Completed: Aggressive Goblins vs Necromancy Elvish
# Completed: Aggressive Goblins vs Necromancy Morbid
# Completed: Aggressive Goblins vs Goblins Morbid
# Completed: Aggressive Goblins vs Goblins Dinos
# Processing batch 24/135
# Completed: Aggressive Goblins vs Plundering Goblins
# Completed: Aggressive Morbid vs Aggressive Necromancy
# Completed: Aggressive Goblins vs Plundering Elvish
# Completed: Aggressive Goblins vs Plundering Dinos
# Completed: Aggressive Goblins vs Plundering Dragons
# Completed: Aggressive Goblins vs Plundering Morbid
# Completed: Aggressive Morbid vs Beefy Bloodthirsty
# Completed: Aggressive Morbid vs Beefy Dragons
# Completed: Aggressive Morbid vs Beefy Aggressive
# Completed: Aggressive Morbid vs Beefy Dinos
# Completed: Aggressive Morbid vs Beefy Gambling
# Completed: Aggressive Morbid vs Aggressive Plundering
# Completed: Aggressive Morbid vs Beefy Flourishing
# Completed: Aggressive Morbid vs Beefy Elvish
# Completed: Aggressive Goblins vs Plundering Flourishing
# Completed: Aggressive Goblins vs Plundering Necromancy
# Processing batch 25/135
# Completed: Aggressive Morbid vs Bloodthirsty Dinos
# Completed: Aggressive Morbid vs Beefy Goblins
# Completed: Aggressive Morbid vs Bloodthirsty Dragons
# Completed: Aggressive Morbid vs Beefy Necromancy
# Completed: Aggressive Morbid vs Dragons Morbid
# Completed: Aggressive Morbid vs Bloodthirsty Elvish
# Completed: Aggressive Morbid vs Dinos Dragons
# Completed: Aggressive Morbid vs Beefy Morbid
# Completed: Aggressive Morbid vs Bloodthirsty Morbid
# Completed: Aggressive Morbid vs Dinos Morbid
# Completed: Aggressive Morbid vs Elvish Dinos
# Completed: Aggressive Morbid vs Elvish Morbid
# Completed: Aggressive Morbid vs Elvish Dragons
# Completed: Aggressive Morbid vs Flourishing Dinos
# Completed: Aggressive Morbid vs Flourishing Bloodthirsty
# Completed: Aggressive Morbid vs Beefy Plundering
# Processing batch 26/135
# Completed: Aggressive Morbid vs Gambling Aggressive
# Completed: Aggressive Morbid vs Gambling Bloodthirsty
# Completed: Aggressive Morbid vs Flourishing Dragons
# Completed: Aggressive Morbid vs Flourishing Goblins
# Completed: Aggressive Morbid vs Flourishing Necromancy
# Completed: Aggressive Morbid vs Gambling Dragons
# Completed: Aggressive Morbid vs Gambling Elvish
# Completed: Aggressive Morbid vs Gambling Flourishing
# Completed: Aggressive Morbid vs Gambling Dinos
# Completed: Aggressive Morbid vs Gambling Necromancy
# Completed: Aggressive Morbid vs Flourishing Elvish
# Completed: Aggressive Morbid vs Gambling Goblins
# Completed: Aggressive Morbid vs Flourishing Morbid
# Completed: Aggressive Morbid vs Gambling Morbid
# Completed: Aggressive Morbid vs Goblins Bloodthirsty
# Completed: Aggressive Morbid vs Gambling Plundering
# Processing batch 27/135
# Completed: Aggressive Morbid vs Necromancy Dragons
# Completed: Aggressive Morbid vs Necromancy Dinos
# Completed: Aggressive Morbid vs Goblins Dragons
# Completed: Aggressive Morbid vs Necromancy Bloodthirsty
# Completed: Aggressive Morbid vs Goblins Dinos
# Completed: Aggressive Morbid vs Goblins Elvish
# Completed: Aggressive Morbid vs Plundering Bloodthirsty
# Completed: Aggressive Morbid vs Plundering Dragons
# Completed: Aggressive Morbid vs Plundering Dinos
# Completed: Aggressive Morbid vs Necromancy Elvish
# Completed: Aggressive Morbid vs Goblins Morbid
# Completed: Aggressive Morbid vs Goblins Necromancy
# Completed: Aggressive Morbid vs Plundering Goblins
# Completed: Aggressive Morbid vs Plundering Elvish
# Completed: Aggressive Morbid vs Necromancy Morbid
# Completed: Aggressive Morbid vs Plundering Flourishing
# Processing batch 28/135
# Completed: Aggressive Necromancy vs Beefy Aggressive
# Completed: Aggressive Necromancy vs Beefy Bloodthirsty
# Completed: Aggressive Necromancy vs Beefy Elvish
# Completed: Aggressive Necromancy vs Beefy Dragons
# Completed: Aggressive Necromancy vs Aggressive Plundering
# Completed: Aggressive Necromancy vs Beefy Dinos
# Completed: Aggressive Morbid vs Plundering Necromancy
# Completed: Aggressive Morbid vs Plundering Morbid
# Completed: Aggressive Necromancy vs Beefy Gambling
# Completed: Aggressive Necromancy vs Bloodthirsty Dinos
# Completed: Aggressive Necromancy vs Bloodthirsty Dragons
# Completed: Aggressive Necromancy vs Beefy Plundering
# Completed: Aggressive Necromancy vs Beefy Goblins
# Completed: Aggressive Necromancy vs Beefy Flourishing
# Completed: Aggressive Necromancy vs Beefy Necromancy
# Completed: Aggressive Necromancy vs Beefy Morbid
# Processing batch 29/135
# Completed: Aggressive Necromancy vs Elvish Dinos
# Completed: Aggressive Necromancy vs Dinos Dragons
# Completed: Aggressive Necromancy vs Dragons Morbid
# Completed: Aggressive Necromancy vs Bloodthirsty Morbid
# Completed: Aggressive Necromancy vs Bloodthirsty Elvish
# Completed: Aggressive Necromancy vs Elvish Morbid
# Completed: Aggressive Necromancy vs Elvish Dragons
# Completed: Aggressive Necromancy vs Flourishing Dragons
# Completed: Aggressive Necromancy vs Dinos Morbid
# Completed: Aggressive Necromancy vs Flourishing Bloodthirsty
# Completed: Aggressive Necromancy vs Flourishing Dinos
# Completed: Aggressive Necromancy vs Flourishing Elvish
# Completed: Aggressive Necromancy vs Gambling Aggressive
# Completed: Aggressive Necromancy vs Flourishing Necromancy
# Completed: Aggressive Necromancy vs Flourishing Morbid
# Completed: Aggressive Necromancy vs Flourishing Goblins
# Processing batch 30/135
# Completed: Aggressive Necromancy vs Gambling Dragons
# Completed: Aggressive Necromancy vs Gambling Bloodthirsty
# Completed: Aggressive Necromancy vs Gambling Goblins
# Completed: Aggressive Necromancy vs Gambling Dinos
# Completed: Aggressive Necromancy vs Gambling Flourishing
# Completed: Aggressive Necromancy vs Gambling Necromancy
# Completed: Aggressive Necromancy vs Gambling Morbid
# Completed: Aggressive Necromancy vs Gambling Elvish
# Completed: Aggressive Necromancy vs Goblins Elvish
# Completed: Aggressive Necromancy vs Goblins Bloodthirsty
# Completed: Aggressive Necromancy vs Goblins Dragons
# Completed: Aggressive Necromancy vs Goblins Morbid
# Completed: Aggressive Necromancy vs Necromancy Bloodthirsty
# Completed: Aggressive Necromancy vs Goblins Necromancy
# Completed: Aggressive Necromancy vs Gambling Plundering
# Completed: Aggressive Necromancy vs Goblins Dinos
# Processing batch 31/135
# Completed: Aggressive Necromancy vs Plundering Bloodthirsty
# Completed: Aggressive Necromancy vs Plundering Dinos
# Completed: Aggressive Necromancy vs Necromancy Dinos
# Completed: Aggressive Necromancy vs Necromancy Dragons
# Completed: Aggressive Necromancy vs Plundering Dragons
# Completed: Aggressive Necromancy vs Necromancy Elvish
# Completed: Aggressive Necromancy vs Plundering Goblins
# Completed: Aggressive Necromancy vs Necromancy Morbid
# Completed: Aggressive Plundering vs Beefy Aggressive
# Completed: Aggressive Necromancy vs Plundering Elvish
# Completed: Aggressive Plundering vs Beefy Dinos
# Completed: Aggressive Necromancy vs Plundering Necromancy
# Completed: Aggressive Necromancy vs Plundering Morbid
# Completed: Aggressive Plundering vs Beefy Dragons
# Completed: Aggressive Plundering vs Beefy Bloodthirsty
# Completed: Aggressive Necromancy vs Plundering Flourishing
# Processing batch 32/135
# Completed: Aggressive Plundering vs Beefy Gambling
# Completed: Aggressive Plundering vs Beefy Morbid
# Completed: Aggressive Plundering vs Beefy Necromancy
# Completed: Aggressive Plundering vs Bloodthirsty Dinos
# Completed: Aggressive Plundering vs Beefy Goblins
# Completed: Aggressive Plundering vs Bloodthirsty Dragons
# Completed: Aggressive Plundering vs Beefy Flourishing
# Completed: Aggressive Plundering vs Beefy Plundering
# Completed: Aggressive Plundering vs Dinos Dragons
# Completed: Aggressive Plundering vs Bloodthirsty Morbid
# Completed: Aggressive Plundering vs Dinos Morbid
# Completed: Aggressive Plundering vs Dragons Morbid
# Completed: Aggressive Plundering vs Bloodthirsty Elvish
# Completed: Aggressive Plundering vs Elvish Dragons
# Completed: Aggressive Plundering vs Beefy Elvish
# Completed: Aggressive Plundering vs Elvish Dinos
# Processing batch 33/135
# Completed: Aggressive Plundering vs Flourishing Dragons
# Completed: Aggressive Plundering vs Elvish Morbid
# Completed: Aggressive Plundering vs Flourishing Morbid
# Completed: Aggressive Plundering vs Flourishing Elvish
# Completed: Aggressive Plundering vs Flourishing Necromancy
# Completed: Aggressive Plundering vs Flourishing Goblins
# Completed: Aggressive Plundering vs Gambling Dinos
# Completed: Aggressive Plundering vs Gambling Dragons
# Completed: Aggressive Plundering vs Gambling Elvish
# Completed: Aggressive Plundering vs Flourishing Dinos
# Completed: Aggressive Plundering vs Gambling Bloodthirsty
# Completed: Aggressive Plundering vs Gambling Goblins
# Completed: Aggressive Plundering vs Gambling Aggressive
# Completed: Aggressive Plundering vs Flourishing Bloodthirsty
# Completed: Aggressive Plundering vs Gambling Flourishing
# Completed: Aggressive Plundering vs Gambling Morbid
# Processing batch 34/135
# Completed: Aggressive Plundering vs Goblins Bloodthirsty
# Completed: Aggressive Plundering vs Gambling Plundering
# Completed: Aggressive Plundering vs Goblins Morbid
# Completed: Aggressive Plundering vs Goblins Dragons
# Completed: Aggressive Plundering vs Gambling Necromancy
# Completed: Aggressive Plundering vs Necromancy Dinos
# Completed: Aggressive Plundering vs Necromancy Bloodthirsty
# Completed: Aggressive Plundering vs Goblins Dinos
# Completed: Aggressive Plundering vs Necromancy Dragons
# Completed: Aggressive Plundering vs Goblins Necromancy
# Completed: Aggressive Plundering vs Necromancy Morbid
# Completed: Aggressive Plundering vs Plundering Bloodthirsty
# Completed: Aggressive Plundering vs Plundering Dragons
# Completed: Aggressive Plundering vs Goblins Elvish
# Completed: Aggressive Plundering vs Necromancy Elvish
# Completed: Aggressive Plundering vs Plundering Dinos
# Processing batch 35/135
# Completed: Aggressive Plundering vs Plundering Elvish
# Completed: Aggressive Plundering vs Plundering Goblins
# Completed: Beefy Aggressive vs Beefy Dragons
# Completed: Aggressive Plundering vs Plundering Flourishing
# Completed: Beefy Aggressive vs Beefy Bloodthirsty
# Completed: Beefy Aggressive vs Beefy Dinos
# Completed: Beefy Aggressive vs Beefy Gambling
# Completed: Beefy Aggressive vs Beefy Elvish
# Completed: Beefy Aggressive vs Beefy Flourishing
# Completed: Beefy Aggressive vs Beefy Morbid
# Completed: Beefy Aggressive vs Beefy Plundering
# Completed: Beefy Aggressive vs Bloodthirsty Dinos
# Completed: Beefy Aggressive vs Beefy Necromancy
# Completed: Aggressive Plundering vs Plundering Necromancy
# Completed: Beefy Aggressive vs Beefy Goblins
# Completed: Aggressive Plundering vs Plundering Morbid
# Processing batch 36/135
# Completed: Beefy Aggressive vs Bloodthirsty Elvish
# Completed: Beefy Aggressive vs Bloodthirsty Morbid
# Completed: Beefy Aggressive vs Dinos Morbid
# Completed: Beefy Aggressive vs Dinos Dragons
# Completed: Beefy Aggressive vs Bloodthirsty Dragons
# Completed: Beefy Aggressive vs Dragons Morbid
# Completed: Beefy Aggressive vs Elvish Dinos
# Completed: Beefy Aggressive vs Elvish Dragons
# Completed: Beefy Aggressive vs Flourishing Dragons
# Completed: Beefy Aggressive vs Flourishing Morbid
# Completed: Beefy Aggressive vs Flourishing Bloodthirsty
# Completed: Beefy Aggressive vs Flourishing Goblins
# Completed: Beefy Aggressive vs Flourishing Dinos
# Completed: Beefy Aggressive vs Flourishing Necromancy
# Completed: Beefy Aggressive vs Elvish Morbid
# Completed: Beefy Aggressive vs Flourishing Elvish
# Processing batch 37/135
# Completed: Beefy Aggressive vs Gambling Dinos
# Completed: Beefy Aggressive vs Gambling Bloodthirsty
# Completed: Beefy Aggressive vs Gambling Goblins
# Completed: Beefy Aggressive vs Gambling Aggressive
# Completed: Beefy Aggressive vs Gambling Dragons
# Completed: Beefy Aggressive vs Gambling Elvish
# Completed: Beefy Aggressive vs Gambling Morbid
# Completed: Beefy Aggressive vs Goblins Bloodthirsty
# Completed: Beefy Aggressive vs Gambling Necromancy
# Completed: Beefy Aggressive vs Goblins Elvish
# Completed: Beefy Aggressive vs Goblins Dragons
# Completed: Beefy Aggressive vs Goblins Necromancy
# Completed: Beefy Aggressive vs Goblins Dinos
# Completed: Beefy Aggressive vs Goblins Morbid
# Completed: Beefy Aggressive vs Gambling Flourishing
# Completed: Beefy Aggressive vs Gambling Plundering
# Processing batch 38/135
# Completed: Beefy Aggressive vs Plundering Bloodthirsty
# Completed: Beefy Aggressive vs Plundering Dragons
# Completed: Beefy Aggressive vs Necromancy Morbid
# Completed: Beefy Aggressive vs Necromancy Bloodthirsty
# Completed: Beefy Aggressive vs Necromancy Dragons
# Completed: Beefy Aggressive vs Necromancy Elvish
# Completed: Beefy Aggressive vs Necromancy Dinos
# Completed: Beefy Aggressive vs Plundering Elvish
# Completed: Beefy Aggressive vs Plundering Goblins
# Completed: Beefy Bloodthirsty vs Beefy Dinos
# Completed: Beefy Bloodthirsty vs Beefy Dragons
# Completed: Beefy Aggressive vs Plundering Flourishing
# Completed: Beefy Bloodthirsty vs Beefy Elvish
# Completed: Beefy Aggressive vs Plundering Dinos
# Completed: Beefy Aggressive vs Plundering Necromancy
# Completed: Beefy Aggressive vs Plundering Morbid
# Processing batch 39/135
# Completed: Beefy Bloodthirsty vs Bloodthirsty Dinos
# Completed: Beefy Bloodthirsty vs Beefy Goblins
# Completed: Beefy Bloodthirsty vs Beefy Plundering
# Completed: Beefy Bloodthirsty vs Beefy Morbid
# Completed: Beefy Bloodthirsty vs Beefy Gambling
# Completed: Beefy Bloodthirsty vs Bloodthirsty Dragons
# Completed: Beefy Bloodthirsty vs Beefy Necromancy
# Completed: Beefy Bloodthirsty vs Beefy Flourishing
# Completed: Beefy Bloodthirsty vs Bloodthirsty Morbid
# Completed: Beefy Bloodthirsty vs Dinos Morbid
# Completed: Beefy Bloodthirsty vs Dragons Morbid
# Completed: Beefy Bloodthirsty vs Dinos Dragons
# Completed: Beefy Bloodthirsty vs Bloodthirsty Elvish
# Completed: Beefy Bloodthirsty vs Elvish Dragons
# Completed: Beefy Bloodthirsty vs Elvish Morbid
# Completed: Beefy Bloodthirsty vs Elvish Dinos
# Processing batch 40/135
# Completed: Beefy Bloodthirsty vs Flourishing Dinos
# Completed: Beefy Bloodthirsty vs Flourishing Goblins
# Completed: Beefy Bloodthirsty vs Gambling Aggressive
# Completed: Beefy Bloodthirsty vs Flourishing Dragons
# Completed: Beefy Bloodthirsty vs Flourishing Morbid
# Completed: Beefy Bloodthirsty vs Flourishing Necromancy
# Completed: Beefy Bloodthirsty vs Flourishing Bloodthirsty
# Completed: Beefy Bloodthirsty vs Flourishing Elvish
# Completed: Beefy Bloodthirsty vs Gambling Bloodthirsty
# Completed: Beefy Bloodthirsty vs Gambling Dragons
# Completed: Beefy Bloodthirsty vs Gambling Morbid
# Completed: Beefy Bloodthirsty vs Gambling Dinos
# Completed: Beefy Bloodthirsty vs Gambling Necromancy
# Completed: Beefy Bloodthirsty vs Gambling Goblins
# Completed: Beefy Bloodthirsty vs Gambling Flourishing
# Completed: Beefy Bloodthirsty vs Gambling Elvish
# Processing batch 41/135
# Completed: Beefy Bloodthirsty vs Goblins Necromancy
# Completed: Beefy Bloodthirsty vs Goblins Dragons
# Completed: Beefy Bloodthirsty vs Goblins Elvish
# Completed: Beefy Bloodthirsty vs Goblins Dinos
# Completed: Beefy Bloodthirsty vs Necromancy Bloodthirsty
# Completed: Beefy Bloodthirsty vs Gambling Plundering
# Completed: Beefy Bloodthirsty vs Goblins Morbid
# Completed: Beefy Bloodthirsty vs Necromancy Dinos
# Completed: Beefy Bloodthirsty vs Goblins Bloodthirsty
# Completed: Beefy Bloodthirsty vs Plundering Bloodthirsty
# Completed: Beefy Bloodthirsty vs Plundering Dragons
# Completed: Beefy Bloodthirsty vs Necromancy Dragons
# Completed: Beefy Bloodthirsty vs Necromancy Morbid
# Completed: Beefy Bloodthirsty vs Necromancy Elvish
# Completed: Beefy Bloodthirsty vs Plundering Dinos
# Completed: Beefy Bloodthirsty vs Plundering Elvish
# Processing batch 42/135
# Completed: Beefy Dinos vs Beefy Dragons
# Completed: Beefy Dinos vs Beefy Flourishing
# Completed: Beefy Bloodthirsty vs Plundering Morbid
# Completed: Beefy Bloodthirsty vs Plundering Goblins
# Completed: Beefy Dinos vs Beefy Goblins
# Completed: Beefy Dinos vs Beefy Elvish
# Completed: Beefy Bloodthirsty vs Plundering Flourishing
# Completed: Beefy Dinos vs Beefy Gambling
# Completed: Beefy Dinos vs Beefy Morbid
# Completed: Beefy Dinos vs Bloodthirsty Elvish
# Completed: Beefy Dinos vs Bloodthirsty Dragons
# Completed: Beefy Bloodthirsty vs Plundering Necromancy
# Completed: Beefy Dinos vs Beefy Necromancy
# Completed: Beefy Dinos vs Bloodthirsty Morbid
# Completed: Beefy Dinos vs Beefy Plundering
# Completed: Beefy Dinos vs Bloodthirsty Dinos
# Processing batch 43/135
# Completed: Beefy Dinos vs Dinos Dragons
# Completed: Beefy Dinos vs Dragons Morbid
# Completed: Beefy Dinos vs Flourishing Bloodthirsty
# Completed: Beefy Dinos vs Flourishing Dinos
# Completed: Beefy Dinos vs Elvish Dragons
# Completed: Beefy Dinos vs Elvish Morbid
# Completed: Beefy Dinos vs Dinos Morbid
# Completed: Beefy Dinos vs Flourishing Dragons
# Completed: Beefy Dinos vs Flourishing Necromancy
# Completed: Beefy Dinos vs Gambling Bloodthirsty
# Completed: Beefy Dinos vs Gambling Aggressive
# Completed: Beefy Dinos vs Flourishing Morbid
# Completed: Beefy Dinos vs Gambling Dinos
# Completed: Beefy Dinos vs Flourishing Goblins
# Completed: Beefy Dinos vs Elvish Dinos
# Completed: Beefy Dinos vs Flourishing Elvish
# Processing batch 44/135
# Completed: Beefy Dinos vs Gambling Morbid
# Completed: Beefy Dinos vs Gambling Dragons
# Completed: Beefy Dinos vs Gambling Plundering
# Completed: Beefy Dinos vs Gambling Necromancy
# Completed: Beefy Dinos vs Gambling Flourishing
# Completed: Beefy Dinos vs Goblins Bloodthirsty
# Completed: Beefy Dinos vs Gambling Elvish
# Completed: Beefy Dinos vs Goblins Dinos
# Completed: Beefy Dinos vs Goblins Dragons
# Completed: Beefy Dinos vs Necromancy Bloodthirsty
# Completed: Beefy Dinos vs Goblins Morbid
# Completed: Beefy Dinos vs Necromancy Dragons
# Completed: Beefy Dinos vs Necromancy Dinos
# Completed: Beefy Dinos vs Gambling Goblins
# Completed: Beefy Dinos vs Goblins Elvish
# Completed: Beefy Dinos vs Goblins Necromancy
# Processing batch 45/135
# Completed: Beefy Dinos vs Plundering Bloodthirsty
# Completed: Beefy Dinos vs Necromancy Morbid
# Completed: Beefy Dinos vs Plundering Dragons
# Completed: Beefy Dinos vs Necromancy Elvish
# Completed: Beefy Dinos vs Plundering Goblins
# Completed: Beefy Dragons vs Beefy Elvish
# Completed: Beefy Dinos vs Plundering Necromancy
# Completed: Beefy Dragons vs Beefy Gambling
# Completed: Beefy Dragons vs Beefy Flourishing
# Completed: Beefy Dinos vs Plundering Morbid
# Completed: Beefy Dragons vs Beefy Goblins
# Completed: Beefy Dragons vs Beefy Morbid
# Completed: Beefy Dinos vs Plundering Elvish
# Completed: Beefy Dinos vs Plundering Dinos
# Completed: Beefy Dragons vs Beefy Necromancy
# Completed: Beefy Dinos vs Plundering Flourishing
# Processing batch 46/135
# Completed: Beefy Dragons vs Beefy Plundering
# Completed: Beefy Dragons vs Dinos Dragons
# Completed: Beefy Dragons vs Bloodthirsty Dinos
# Completed: Beefy Dragons vs Bloodthirsty Dragons
# Completed: Beefy Dragons vs Bloodthirsty Morbid
# Completed: Beefy Dragons vs Dragons Morbid
# Completed: Beefy Dragons vs Dinos Morbid
# Completed: Beefy Dragons vs Bloodthirsty Elvish
# Completed: Beefy Dragons vs Elvish Morbid
# Completed: Beefy Dragons vs Flourishing Bloodthirsty
# Completed: Beefy Dragons vs Elvish Dinos
# Completed: Beefy Dragons vs Flourishing Dinos
# Completed: Beefy Dragons vs Flourishing Goblins
# Completed: Beefy Dragons vs Flourishing Elvish
# Completed: Beefy Dragons vs Elvish Dragons
# Completed: Beefy Dragons vs Flourishing Dragons
# Processing batch 47/135
# Completed: Beefy Dragons vs Gambling Dinos
# Completed: Beefy Dragons vs Gambling Dragons
# Completed: Beefy Dragons vs Gambling Flourishing
# Completed: Beefy Dragons vs Gambling Bloodthirsty
# Completed: Beefy Dragons vs Gambling Elvish
# Completed: Beefy Dragons vs Gambling Aggressive
# Completed: Beefy Dragons vs Flourishing Morbid
# Completed: Beefy Dragons vs Flourishing Necromancy
# Completed: Beefy Dragons vs Gambling Goblins
# Completed: Beefy Dragons vs Goblins Bloodthirsty
# Completed: Beefy Dragons vs Gambling Plundering
# Completed: Beefy Dragons vs Gambling Necromancy
# Completed: Beefy Dragons vs Goblins Dragons
# Completed: Beefy Dragons vs Goblins Dinos
# Completed: Beefy Dragons vs Goblins Elvish
# Completed: Beefy Dragons vs Gambling Morbid
# Processing batch 48/135
# Completed: Beefy Dragons vs Necromancy Bloodthirsty
# Completed: Beefy Dragons vs Goblins Morbid
# Completed: Beefy Dragons vs Goblins Necromancy
# Completed: Beefy Dragons vs Necromancy Elvish
# Completed: Beefy Dragons vs Necromancy Dinos
# Completed: Beefy Dragons vs Necromancy Morbid
# Completed: Beefy Dragons vs Necromancy Dragons
# Completed: Beefy Dragons vs Plundering Dinos
# Completed: Beefy Dragons vs Plundering Bloodthirsty
# Completed: Beefy Dragons vs Plundering Goblins
# Completed: Beefy Dragons vs Plundering Flourishing
# Completed: Beefy Dragons vs Plundering Elvish
# Completed: Beefy Elvish vs Beefy Flourishing
# Completed: Beefy Dragons vs Plundering Dragons
# Completed: Beefy Dragons vs Plundering Morbid
# Completed: Beefy Dragons vs Plundering Necromancy
# Processing batch 49/135
# Completed: Beefy Elvish vs Bloodthirsty Dragons
# Completed: Beefy Elvish vs Beefy Goblins
# Completed: Beefy Elvish vs Beefy Morbid
# Completed: Beefy Elvish vs Bloodthirsty Morbid
# Completed: Beefy Elvish vs Dinos Dragons
# Completed: Beefy Elvish vs Bloodthirsty Dinos
# Completed: Beefy Elvish vs Dragons Morbid
# Completed: Beefy Elvish vs Bloodthirsty Elvish
# Completed: Beefy Elvish vs Dinos Morbid
# Completed: Beefy Elvish vs Beefy Gambling
# Completed: Beefy Elvish vs Elvish Dragons
# Completed: Beefy Elvish vs Beefy Plundering
# Completed: Beefy Elvish vs Flourishing Bloodthirsty
# Completed: Beefy Elvish vs Elvish Dinos
# Completed: Beefy Elvish vs Beefy Necromancy
# Completed: Beefy Elvish vs Elvish Morbid
# Processing batch 50/135
# Completed: Beefy Elvish vs Flourishing Dragons
# Completed: Beefy Elvish vs Gambling Bloodthirsty
# Completed: Beefy Elvish vs Flourishing Morbid
# Completed: Beefy Elvish vs Flourishing Necromancy
# Completed: Beefy Elvish vs Gambling Aggressive
# Completed: Beefy Elvish vs Gambling Dragons
# Completed: Beefy Elvish vs Flourishing Goblins
# Completed: Beefy Elvish vs Flourishing Dinos
# Completed: Beefy Elvish vs Gambling Goblins
# Completed: Beefy Elvish vs Gambling Necromancy
# Completed: Beefy Elvish vs Flourishing Elvish
# Completed: Beefy Elvish vs Gambling Dinos
# Completed: Beefy Elvish vs Gambling Plundering
# Completed: Beefy Elvish vs Gambling Flourishing
# Completed: Beefy Elvish vs Gambling Elvish
# Completed: Beefy Elvish vs Gambling Morbid
# Processing batch 51/135
# Completed: Beefy Elvish vs Goblins Dragons
# Completed: Beefy Elvish vs Goblins Bloodthirsty
# Completed: Beefy Elvish vs Goblins Elvish
# Completed: Beefy Elvish vs Necromancy Bloodthirsty
# Completed: Beefy Elvish vs Goblins Morbid
# Completed: Beefy Elvish vs Goblins Dinos
# Completed: Beefy Elvish vs Goblins Necromancy
# Completed: Beefy Elvish vs Necromancy Dragons
# Completed: Beefy Elvish vs Plundering Dragons
# Completed: Beefy Elvish vs Plundering Flourishing
# Completed: Beefy Elvish vs Plundering Elvish
# Completed: Beefy Elvish vs Necromancy Morbid
# Completed: Beefy Elvish vs Necromancy Dinos
# Completed: Beefy Elvish vs Plundering Bloodthirsty
# Completed: Beefy Elvish vs Plundering Dinos
# Completed: Beefy Elvish vs Necromancy Elvish
# Processing batch 52/135
# Completed: Beefy Flourishing vs Beefy Plundering
# Completed: Beefy Flourishing vs Beefy Gambling
# Completed: Beefy Flourishing vs Beefy Goblins
# Completed: Beefy Elvish vs Plundering Necromancy
# Completed: Beefy Flourishing vs Beefy Necromancy
# Completed: Beefy Elvish vs Plundering Goblins
# Completed: Beefy Flourishing vs Bloodthirsty Morbid
# Completed: Beefy Flourishing vs Bloodthirsty Dragons
# Completed: Beefy Flourishing vs Bloodthirsty Dinos
# Completed: Beefy Flourishing vs Dinos Dragons
# Completed: Beefy Flourishing vs Dinos Morbid
# Completed: Beefy Flourishing vs Beefy Morbid
# Completed: Beefy Flourishing vs Dragons Morbid
# Completed: Beefy Flourishing vs Bloodthirsty Elvish
# Completed: Beefy Elvish vs Plundering Morbid
# Completed: Beefy Flourishing vs Elvish Dinos
# Processing batch 53/135
# Completed: Beefy Flourishing vs Flourishing Bloodthirsty
# Completed: Beefy Flourishing vs Flourishing Dragons
# Completed: Beefy Flourishing vs Flourishing Dinos
# Completed: Beefy Flourishing vs Flourishing Morbid
# Completed: Beefy Flourishing vs Elvish Dragons
# Completed: Beefy Flourishing vs Flourishing Goblins
# Completed: Beefy Flourishing vs Gambling Bloodthirsty
# Completed: Beefy Flourishing vs Gambling Elvish
# Completed: Beefy Flourishing vs Gambling Dragons
# Completed: Beefy Flourishing vs Flourishing Necromancy
# Completed: Beefy Flourishing vs Gambling Aggressive
# Completed: Beefy Flourishing vs Elvish Morbid
# Completed: Beefy Flourishing vs Gambling Dinos
# Completed: Beefy Flourishing vs Gambling Flourishing
# Completed: Beefy Flourishing vs Flourishing Elvish
# Completed: Beefy Flourishing vs Gambling Goblins
# Processing batch 54/135
# Completed: Beefy Flourishing vs Goblins Dinos
# Completed: Beefy Flourishing vs Goblins Elvish
# Completed: Beefy Flourishing vs Goblins Dragons
# Completed: Beefy Flourishing vs Gambling Morbid
# Completed: Beefy Flourishing vs Gambling Necromancy
# Completed: Beefy Flourishing vs Goblins Bloodthirsty
# Completed: Beefy Flourishing vs Gambling Plundering
# Completed: Beefy Flourishing vs Goblins Morbid
# Completed: Beefy Flourishing vs Goblins Necromancy
# Completed: Beefy Flourishing vs Necromancy Bloodthirsty
# Completed: Beefy Flourishing vs Plundering Dinos
# Completed: Beefy Flourishing vs Plundering Bloodthirsty
# Completed: Beefy Flourishing vs Necromancy Dinos
# Completed: Beefy Flourishing vs Necromancy Dragons
# Completed: Beefy Flourishing vs Necromancy Elvish
# Completed: Beefy Flourishing vs Necromancy Morbid
# Processing batch 55/135
# Completed: Beefy Flourishing vs Plundering Morbid
# Completed: Beefy Flourishing vs Plundering Dragons
# Completed: Beefy Gambling vs Beefy Morbid
# Completed: Beefy Flourishing vs Plundering Necromancy
# Completed: Beefy Gambling vs Beefy Necromancy
# Completed: Beefy Gambling vs Bloodthirsty Dragons
# Completed: Beefy Gambling vs Bloodthirsty Dinos
# Completed: Beefy Gambling vs Beefy Plundering
# Completed: Beefy Gambling vs Beefy Goblins
# Completed: Beefy Flourishing vs Plundering Goblins
# Completed: Beefy Flourishing vs Plundering Elvish
# Completed: Beefy Gambling vs Bloodthirsty Morbid
# Completed: Beefy Gambling vs Dinos Dragons
# Completed: Beefy Gambling vs Dinos Morbid
# Completed: Beefy Gambling vs Bloodthirsty Elvish
# Completed: Beefy Flourishing vs Plundering Flourishing
# Processing batch 56/135
# Completed: Beefy Gambling vs Flourishing Dragons
# Completed: Beefy Gambling vs Flourishing Dinos
# Completed: Beefy Gambling vs Flourishing Bloodthirsty
# Completed: Beefy Gambling vs Dragons Morbid
# Completed: Beefy Gambling vs Elvish Dragons
# Completed: Beefy Gambling vs Gambling Aggressive
# Completed: Beefy Gambling vs Elvish Morbid
# Completed: Beefy Gambling vs Flourishing Elvish
# Completed: Beefy Gambling vs Flourishing Goblins
# Completed: Beefy Gambling vs Flourishing Necromancy
# Completed: Beefy Gambling vs Gambling Bloodthirsty
# Completed: Beefy Gambling vs Elvish Dinos
# Completed: Beefy Gambling vs Gambling Dragons
# Completed: Beefy Gambling vs Gambling Dinos
# Completed: Beefy Gambling vs Gambling Elvish
# Completed: Beefy Gambling vs Flourishing Morbid
# Processing batch 57/135
# Completed: Beefy Gambling vs Goblins Dragons
# Completed: Beefy Gambling vs Gambling Morbid
# Completed: Beefy Gambling vs Gambling Flourishing
# Completed: Beefy Gambling vs Gambling Plundering
# Completed: Beefy Gambling vs Gambling Necromancy
# Completed: Beefy Gambling vs Necromancy Bloodthirsty
# Completed: Beefy Gambling vs Goblins Bloodthirsty
# Completed: Beefy Gambling vs Goblins Elvish
# Completed: Beefy Gambling vs Gambling Goblins
# Completed: Beefy Gambling vs Goblins Dinos
# Completed: Beefy Gambling vs Necromancy Dragons
# Completed: Beefy Gambling vs Goblins Necromancy
# Completed: Beefy Gambling vs Necromancy Morbid
# Completed: Beefy Gambling vs Necromancy Dinos
# Completed: Beefy Gambling vs Necromancy Elvish
# Completed: Beefy Gambling vs Goblins Morbid
# Processing batch 58/135
# Completed: Beefy Gambling vs Plundering Goblins
# Completed: Beefy Gambling vs Plundering Dragons
# Completed: Beefy Gambling vs Plundering Bloodthirsty
# Completed: Beefy Gambling vs Plundering Dinos
# Completed: Beefy Goblins vs Beefy Necromancy
# Completed: Beefy Gambling vs Plundering Elvish
# Completed: Beefy Gambling vs Plundering Necromancy
# Completed: Beefy Goblins vs Beefy Plundering
# Completed: Beefy Gambling vs Plundering Flourishing
# Completed: Beefy Goblins vs Bloodthirsty Morbid
# Completed: Beefy Goblins vs Bloodthirsty Dinos
# Completed: Beefy Goblins vs Beefy Morbid
# Completed: Beefy Goblins vs Bloodthirsty Elvish
# ...
# Completed: Gambling Dragons vs Plundering Morbid
# Completed: Gambling Elvish vs Gambling Flourishing
# Completed: Gambling Elvish vs Gambling Morbid
# Completed: Gambling Elvish vs Gambling Necromancy
# Completed: Gambling Elvish vs Gambling Plundering
# Completed: Gambling Elvish vs Goblins Dragons
# Completed: Gambling Elvish vs Goblins Dinos
# Completed: Gambling Elvish vs Goblins Necromancy
# Completed: Gambling Elvish vs Gambling Goblins
# Completed: Gambling Elvish vs Goblins Morbid
# Completed: Gambling Elvish vs Goblins Bloodthirsty
# Completed: Gambling Elvish vs Goblins Elvish
# Processing batch 117/135
# Completed: Gambling Elvish vs Necromancy Elvish
# Completed: Gambling Elvish vs Plundering Bloodthirsty
# Completed: Gambling Elvish vs Plundering Dinos
# Completed: Gambling Elvish vs Plundering Dragons
# Completed: Gambling Elvish vs Necromancy Morbid
# Completed: Gambling Elvish vs Necromancy Dragons
# Completed: Gambling Elvish vs Plundering Morbid
# Completed: Gambling Elvish vs Necromancy Dinos
# Completed: Gambling Elvish vs Necromancy Bloodthirsty
# Completed: Gambling Elvish vs Plundering Necromancy
# Completed: Gambling Elvish vs Plundering Flourishing
# Completed: Gambling Flourishing vs Gambling Goblins
# Completed: Gambling Flourishing vs Gambling Necromancy
# Completed: Gambling Flourishing vs Gambling Morbid
# Completed: Gambling Elvish vs Plundering Elvish
# Completed: Gambling Elvish vs Plundering Goblins
# Processing batch 118/135
# Completed: Gambling Flourishing vs Goblins Dinos
# Completed: Gambling Flourishing vs Goblins Dragons
# Completed: Gambling Flourishing vs Necromancy Bloodthirsty
# Completed: Gambling Flourishing vs Gambling Plundering
# Completed: Gambling Flourishing vs Goblins Elvish
# Completed: Gambling Flourishing vs Necromancy Dinos
# Completed: Gambling Flourishing vs Goblins Morbid
# Completed: Gambling Flourishing vs Goblins Bloodthirsty
# Completed: Gambling Flourishing vs Plundering Dinos
# Completed: Gambling Flourishing vs Goblins Necromancy
# Completed: Gambling Flourishing vs Plundering Bloodthirsty
# Completed: Gambling Flourishing vs Plundering Elvish
# Completed: Gambling Flourishing vs Necromancy Morbid
# Completed: Gambling Flourishing vs Necromancy Dragons
# Completed: Gambling Flourishing vs Plundering Dragons
# Completed: Gambling Flourishing vs Necromancy Elvish
# Processing batch 119/135
# Completed: Gambling Flourishing vs Plundering Flourishing
# Completed: Gambling Goblins vs Gambling Plundering
# Completed: Gambling Goblins vs Gambling Necromancy
# Completed: Gambling Goblins vs Goblins Elvish
# Completed: Gambling Goblins vs Goblins Dragons
# Completed: Gambling Flourishing vs Plundering Goblins
# Completed: Gambling Goblins vs Goblins Necromancy
# Completed: Gambling Goblins vs Necromancy Bloodthirsty
# Completed: Gambling Flourishing vs Plundering Necromancy
# Completed: Gambling Goblins vs Goblins Morbid
# Completed: Gambling Goblins vs Goblins Dinos
# Completed: Gambling Goblins vs Goblins Bloodthirsty
# Completed: Gambling Goblins vs Necromancy Dinos
# Completed: Gambling Goblins vs Necromancy Dragons
# Completed: Gambling Flourishing vs Plundering Morbid
# Completed: Gambling Goblins vs Gambling Morbid
# Processing batch 120/135
# Completed: Gambling Goblins vs Plundering Dragons
# Completed: Gambling Goblins vs Plundering Dinos
# Completed: Gambling Goblins vs Plundering Goblins
# Completed: Gambling Goblins vs Necromancy Elvish
# Completed: Gambling Goblins vs Plundering Elvish
# Completed: Gambling Goblins vs Plundering Morbid
# Completed: Gambling Goblins vs Plundering Bloodthirsty
# Completed: Gambling Goblins vs Necromancy Morbid
# Completed: Gambling Morbid vs Gambling Necromancy
# Completed: Gambling Morbid vs Gambling Plundering
# Completed: Gambling Goblins vs Plundering Necromancy
# Completed: Gambling Morbid vs Goblins Dragons
# Completed: Gambling Morbid vs Goblins Bloodthirsty
# Completed: Gambling Morbid vs Goblins Dinos
# Completed: Gambling Goblins vs Plundering Flourishing
# Completed: Gambling Morbid vs Goblins Elvish
# Processing batch 121/135
# Completed: Gambling Morbid vs Necromancy Morbid
# Completed: Gambling Morbid vs Necromancy Dragons
# Completed: Gambling Morbid vs Plundering Bloodthirsty
# Completed: Gambling Morbid vs Necromancy Dinos
# Completed: Gambling Morbid vs Goblins Morbid
# Completed: Gambling Morbid vs Necromancy Elvish
# Completed: Gambling Morbid vs Necromancy Bloodthirsty
# Completed: Gambling Morbid vs Goblins Necromancy
# Completed: Gambling Morbid vs Plundering Dinos
# Completed: Gambling Morbid vs Plundering Goblins
# Completed: Gambling Morbid vs Plundering Dragons
# Completed: Gambling Morbid vs Plundering Necromancy
# Completed: Gambling Morbid vs Plundering Elvish
# Completed: Gambling Morbid vs Plundering Flourishing
# Completed: Gambling Morbid vs Plundering Morbid
# Completed: Gambling Necromancy vs Gambling Plundering
# Processing batch 122/135
# Completed: Gambling Necromancy vs Goblins Dragons
# Completed: Gambling Necromancy vs Goblins Dinos
# Completed: Gambling Necromancy vs Goblins Bloodthirsty
# Completed: Gambling Necromancy vs Necromancy Dinos
# Completed: Gambling Necromancy vs Goblins Elvish
# Completed: Gambling Necromancy vs Necromancy Bloodthirsty
# Completed: Gambling Necromancy vs Goblins Morbid
# Completed: Gambling Necromancy vs Necromancy Dragons
# Completed: Gambling Necromancy vs Necromancy Morbid
# Completed: Gambling Necromancy vs Plundering Dragons
# Completed: Gambling Necromancy vs Plundering Dinos
# Completed: Gambling Necromancy vs Plundering Bloodthirsty
# Completed: Gambling Necromancy vs Plundering Elvish
# Completed: Gambling Necromancy vs Goblins Necromancy
# Completed: Gambling Necromancy vs Plundering Flourishing
# Completed: Gambling Necromancy vs Necromancy Elvish
# Processing batch 123/135
# Completed: Gambling Plundering vs Goblins Dinos
# Completed: Gambling Plundering vs Goblins Dragons
# Completed: Gambling Necromancy vs Plundering Necromancy
# Completed: Gambling Necromancy vs Plundering Morbid
# Completed: Gambling Plundering vs Necromancy Bloodthirsty
# Completed: Gambling Plundering vs Goblins Bloodthirsty
# Completed: Gambling Plundering vs Necromancy Dinos
# Completed: Gambling Plundering vs Goblins Morbid
# Completed: Gambling Plundering vs Necromancy Dragons
# Completed: Gambling Plundering vs Necromancy Elvish
# Completed: Gambling Plundering vs Plundering Bloodthirsty
# Completed: Gambling Plundering vs Necromancy Morbid
# Completed: Gambling Plundering vs Goblins Elvish
# Completed: Gambling Necromancy vs Plundering Goblins
# Completed: Gambling Plundering vs Goblins Necromancy
# Completed: Gambling Plundering vs Plundering Dinos
# Processing batch 124/135
# Completed: Gambling Plundering vs Plundering Dragons
# Completed: Goblins Bloodthirsty vs Goblins Dragons
# Completed: Goblins Bloodthirsty vs Goblins Dinos
# Completed: Gambling Plundering vs Plundering Goblins
# Completed: Gambling Plundering vs Plundering Necromancy
# Completed: Gambling Plundering vs Plundering Morbid
# Completed: Goblins Bloodthirsty vs Necromancy Bloodthirsty
# Completed: Goblins Bloodthirsty vs Goblins Necromancy
# Completed: Goblins Bloodthirsty vs Goblins Elvish
# Completed: Goblins Bloodthirsty vs Necromancy Dragons
# Completed: Goblins Bloodthirsty vs Necromancy Dinos
# Completed: Goblins Bloodthirsty vs Goblins Morbid
# Completed: Goblins Bloodthirsty vs Necromancy Elvish
# Completed: Gambling Plundering vs Plundering Elvish
# Completed: Goblins Bloodthirsty vs Necromancy Morbid
# Completed: Gambling Plundering vs Plundering Flourishing
# Processing batch 125/135
# Completed: Goblins Bloodthirsty vs Plundering Necromancy
# Completed: Goblins Bloodthirsty vs Plundering Dragons
# Completed: Goblins Bloodthirsty vs Plundering Bloodthirsty
# Completed: Goblins Bloodthirsty vs Plundering Morbid
# Completed: Goblins Bloodthirsty vs Plundering Goblins
# Completed: Goblins Bloodthirsty vs Plundering Dinos
# Completed: Goblins Bloodthirsty vs Plundering Flourishing
# Completed: Goblins Dinos vs Goblins Dragons
# Completed: Goblins Dinos vs Necromancy Dragons
# Completed: Goblins Dinos vs Necromancy Bloodthirsty
# Completed: Goblins Dinos vs Goblins Necromancy
# Completed: Goblins Dinos vs Goblins Morbid
# Completed: Goblins Bloodthirsty vs Plundering Elvish
# Completed: Goblins Dinos vs Necromancy Dinos
# Completed: Goblins Dinos vs Necromancy Elvish
# Completed: Goblins Dinos vs Goblins Elvish
# Processing batch 126/135
# Completed: Goblins Dinos vs Plundering Dinos
# Completed: Goblins Dinos vs Plundering Dragons
# Completed: Goblins Dinos vs Plundering Bloodthirsty
# Completed: Goblins Dinos vs Necromancy Morbid
# Completed: Goblins Dinos vs Plundering Necromancy
# Completed: Goblins Dragons vs Goblins Morbid
# Completed: Goblins Dinos vs Plundering Morbid
# Completed: Goblins Dragons vs Necromancy Bloodthirsty
# Completed: Goblins Dinos vs Plundering Elvish
# Completed: Goblins Dragons vs Goblins Necromancy
# Completed: Goblins Dragons vs Goblins Elvish
# Completed: Goblins Dragons vs Necromancy Dinos
# Completed: Goblins Dragons vs Necromancy Dragons
# Completed: Goblins Dragons vs Necromancy Elvish
# Completed: Goblins Dinos vs Plundering Flourishing
# Completed: Goblins Dinos vs Plundering Goblins
# Processing batch 127/135
# Completed: Goblins Dragons vs Plundering Dragons
# Completed: Goblins Dragons vs Plundering Dinos
# Completed: Goblins Dragons vs Plundering Goblins
# Completed: Goblins Dragons vs Plundering Elvish
# Completed: Goblins Dragons vs Necromancy Morbid
# Completed: Goblins Dragons vs Plundering Flourishing
# Completed: Goblins Dragons vs Plundering Bloodthirsty
# Completed: Goblins Dragons vs Plundering Necromancy
# Completed: Goblins Elvish vs Necromancy Dragons
# Completed: Goblins Elvish vs Necromancy Bloodthirsty
# Completed: Goblins Elvish vs Goblins Necromancy
# Completed: Goblins Dragons vs Plundering Morbid
# Completed: Goblins Elvish vs Necromancy Elvish
# Completed: Goblins Elvish vs Necromancy Dinos
# Completed: Goblins Elvish vs Necromancy Morbid
# Completed: Goblins Elvish vs Goblins Morbid
# Processing batch 128/135
# Completed: Goblins Elvish vs Plundering Elvish
# Completed: Goblins Elvish vs Plundering Necromancy
# Completed: Goblins Elvish vs Plundering Morbid
# Completed: Goblins Elvish vs Plundering Goblins
# Completed: Goblins Elvish vs Plundering Dragons
# Completed: Goblins Morbid vs Necromancy Dinos
# Completed: Goblins Morbid vs Necromancy Bloodthirsty
# Completed: Goblins Elvish vs Plundering Bloodthirsty
# Completed: Goblins Elvish vs Plundering Flourishing
# Completed: Goblins Morbid vs Goblins Necromancy
# Completed: Goblins Elvish vs Plundering Dinos
# Completed: Goblins Morbid vs Necromancy Dragons
# Completed: Goblins Morbid vs Necromancy Morbid
# Completed: Goblins Morbid vs Plundering Dinos
# Completed: Goblins Morbid vs Plundering Bloodthirsty
# Completed: Goblins Morbid vs Necromancy Elvish
# Processing batch 129/135
# Completed: Goblins Morbid vs Plundering Dragons
# Completed: Goblins Morbid vs Plundering Necromancy
# Completed: Goblins Morbid vs Plundering Morbid
# Completed: Goblins Necromancy vs Necromancy Dinos
# Completed: Goblins Necromancy vs Necromancy Dragons
# Completed: Goblins Morbid vs Plundering Flourishing
# Completed: Goblins Necromancy vs Necromancy Morbid
# Completed: Goblins Morbid vs Plundering Goblins
# Completed: Goblins Necromancy vs Necromancy Elvish
# Completed: Goblins Necromancy vs Necromancy Bloodthirsty
# Completed: Goblins Necromancy vs Plundering Dragons
# Completed: Goblins Necromancy vs Plundering Dinos
# Completed: Goblins Morbid vs Plundering Elvish
# Completed: Goblins Necromancy vs Plundering Bloodthirsty
# Completed: Goblins Necromancy vs Plundering Flourishing
# Completed: Goblins Necromancy vs Plundering Elvish
# Processing batch 130/135
# Completed: Goblins Necromancy vs Plundering Goblins
# Completed: Necromancy Bloodthirsty vs Necromancy Dinos
# Completed: Necromancy Bloodthirsty vs Necromancy Dragons
# Completed: Necromancy Bloodthirsty vs Necromancy Morbid
# Completed: Necromancy Bloodthirsty vs Plundering Bloodthirsty
# Completed: Necromancy Bloodthirsty vs Plundering Dinos
# Completed: Goblins Necromancy vs Plundering Necromancy
# Completed: Necromancy Bloodthirsty vs Necromancy Elvish
# Completed: Goblins Necromancy vs Plundering Morbid
# Completed: Necromancy Bloodthirsty vs Plundering Dragons
# Completed: Necromancy Bloodthirsty vs Plundering Morbid
# Completed: Necromancy Bloodthirsty vs Plundering Elvish
# Completed: Necromancy Bloodthirsty vs Plundering Flourishing
# Completed: Necromancy Bloodthirsty vs Plundering Necromancy
# Completed: Necromancy Bloodthirsty vs Plundering Goblins
# Completed: Necromancy Dinos vs Necromancy Dragons
# Processing batch 131/135
# Completed: Necromancy Dinos vs Plundering Dragons
# Completed: Necromancy Dinos vs Necromancy Morbid
# Completed: Necromancy Dinos vs Plundering Bloodthirsty
# Completed: Necromancy Dinos vs Plundering Goblins
# Completed: Necromancy Dinos vs Plundering Dinos
# Completed: Necromancy Dinos vs Plundering Flourishing
# Completed: Necromancy Dinos vs Plundering Morbid
# Completed: Necromancy Dinos vs Plundering Necromancy
# Completed: Necromancy Dragons vs Plundering Dinos
# Completed: Necromancy Dragons vs Plundering Bloodthirsty
# Completed: Necromancy Dragons vs Plundering Dragons
# Completed: Necromancy Dragons vs Necromancy Elvish
# Completed: Necromancy Dragons vs Necromancy Morbid
# Completed: Necromancy Dragons vs Plundering Elvish
# Completed: Necromancy Dinos vs Plundering Elvish
# Completed: Necromancy Dinos vs Necromancy Elvish
# Processing batch 132/135
# Completed: Necromancy Elvish vs Plundering Dinos
# Completed: Necromancy Dragons vs Plundering Morbid
# Completed: Necromancy Dragons vs Plundering Goblins
# Completed: Necromancy Dragons vs Plundering Flourishing
# Completed: Necromancy Elvish vs Plundering Dragons
# Completed: Necromancy Elvish vs Plundering Bloodthirsty
# Completed: Necromancy Elvish vs Necromancy Morbid
# Completed: Necromancy Elvish vs Plundering Goblins
# Completed: Necromancy Elvish vs Plundering Flourishing
# Completed: Necromancy Elvish vs Plundering Morbid
# Completed: Necromancy Morbid vs Plundering Dragons
# Completed: Necromancy Dragons vs Plundering Necromancy
# Completed: Necromancy Morbid vs Plundering Bloodthirsty
# Completed: Necromancy Morbid vs Plundering Dinos
# Completed: Necromancy Elvish vs Plundering Necromancy
# Completed: Necromancy Elvish vs Plundering Elvish
# Processing batch 133/135
# Completed: Plundering Bloodthirsty vs Plundering Dragons
# Completed: Plundering Bloodthirsty vs Plundering Dinos
# Completed: Plundering Bloodthirsty vs Plundering Flourishing
# Completed: Necromancy Morbid vs Plundering Morbid
# Completed: Plundering Bloodthirsty vs Plundering Elvish
# Completed: Plundering Bloodthirsty vs Plundering Goblins
# Completed: Necromancy Morbid vs Plundering Goblins
# Completed: Necromancy Morbid vs Plundering Flourishing
# Completed: Plundering Bloodthirsty vs Plundering Morbid
# Completed: Plundering Bloodthirsty vs Plundering Necromancy
# Completed: Plundering Dinos vs Plundering Dragons
# Completed: Necromancy Morbid vs Plundering Necromancy
# Completed: Plundering Dinos vs Plundering Goblins
# Completed: Plundering Dinos vs Plundering Elvish
# Completed: Necromancy Morbid vs Plundering Elvish
# Completed: Plundering Dinos vs Plundering Flourishing
# Processing batch 134/135
# Completed: Plundering Dragons vs Plundering Necromancy
# Completed: Plundering Dragons vs Plundering Goblins
# Completed: Plundering Dragons vs Plundering Morbid
# Completed: Plundering Dinos vs Plundering Necromancy
# Completed: Plundering Dragons vs Plundering Flourishing
# Completed: Plundering Elvish vs Plundering Flourishing
# Completed: Plundering Dragons vs Plundering Elvish
# Completed: Plundering Flourishing vs Plundering Goblins
# Completed: Plundering Dinos vs Plundering Morbid
# Completed: Plundering Elvish vs Plundering Necromancy
# Completed: Plundering Goblins vs Plundering Morbid
# Completed: Plundering Goblins vs Plundering Necromancy
# Completed: Plundering Flourishing vs Plundering Morbid
# Completed: Plundering Flourishing vs Plundering Necromancy
# Completed: Plundering Elvish vs Plundering Morbid
# Completed: Plundering Elvish vs Plundering Goblins
# Processing batch 135/135
# Completed: Plundering Morbid vs Plundering Necromancy
# Completed in 29323.67 seconds
# Results: 2143 successful, 2 failed

# %%
os.chdir(original_dir)
game_df = parse_game_results(all_results)
game_time = time.time()
game_df.to_csv(f'output/game_results_{game_time}.csv', index=False)
# Out:
# Deck Performance Summary:
# Total decks analyzed: 66
# Best performing deck: Beefy Elvish (69.35% win rate)
# Worst performing deck: Gambling Morbid (27.82% win rate)

# %% [markdown]
# ### Analyze Results

# %%
game_results_df = pd.read_csv(f'output/game_results_{game_time}.csv')
# game_results_df = pd.read_csv(f'output/game_results_69.csv')

# %%
game_results_df['deck1'] = game_results_df['deck'].str.split().str[0]
game_results_df['deck2'] = game_results_df['deck'].str.split().str[1]

# %%
game_results_df.head()
# Out:
#                       deck  wins  losses  total_games  winrate  avg_turns  \
# 0             Beefy Elvish   172      76          248   0.6935       8.98
# 1  Plundering Bloodthirsty   172      87          259   0.6641       9.40
# 2             Elvish Dinos   168      85          253   0.6640       9.22
# 3        Necromancy Elvish   167      86          253   0.6601       9.69
# 4  Necromancy Bloodthirsty   169      88          257   0.6576       9.19
#
#    median_turns  mode_turns       deck1         deck2
# 0          8.68        9.08       Beefy        Elvish
# 1          9.14        9.00  Plundering  Bloodthirsty
# 2          8.92        8.77      Elvish         Dinos
# 3          9.64        9.34  Necromancy        Elvish
# 4          8.95        8.80  Necromancy  Bloodthirsty

# %%
game_results_df[game_results_df['deck']=='Dinos Dragons']
# Out:
#              deck  wins  losses  total_games  winrate  avg_turns  \
# 48  Dinos Dragons   120     150          270   0.4444       8.65
#
#     median_turns  mode_turns  deck1    deck2
# 48          8.52        8.51  Dinos  Dragons

# %%
deck1_summary = game_results_df.groupby('deck1').agg({
    'wins': 'sum',
    'losses': 'sum',
    'total_games': 'sum'
}).reset_index()

deck1_summary['winrate'] = deck1_summary['wins'] / deck1_summary['total_games']
deck1_summary['winrate'] = deck1_summary['winrate'].round(4)
deck1_summary.rename(columns={'deck1': 'deck'}, inplace=True)

deck2_summary = game_results_df.groupby('deck2').agg({
    'wins': 'sum',
    'losses': 'sum',
    'total_games': 'sum'
}).reset_index()

deck2_summary['winrate'] = deck2_summary['wins'] / deck2_summary['total_games']
deck2_summary['winrate'] = deck2_summary['winrate'].round(4)
deck2_summary.rename(columns={'deck2': 'deck'}, inplace=True)

combined_summary = pd.concat([deck1_summary, deck2_summary], ignore_index=True)
combined_summary = combined_summary.groupby('deck').agg({
    'wins': 'sum',
    'losses': 'sum',
    'total_games': 'sum'
}).reset_index()

combined_summary['winrate'] = combined_summary['wins'] / combined_summary['total_games']
combined_summary['winrate'] = combined_summary['winrate'].round(4)
combined_summary.sort_values(by='winrate', ascending=False, inplace=True)
combined_summary.to_csv('output/combined_deck_summary.csv', index=False)

# %%
combined_summary.head(12)
# Out:
#             deck  wins  losses  total_games  winrate
# 5         Elvish  1696    1155         2851   0.5949
# 2   Bloodthirsty  1605    1294         2899   0.5536
# 1          Beefy  1603    1333         2936   0.5460
# 10    Necromancy  1528    1345         2873   0.5318
# 3          Dinos  1522    1384         2906   0.5237
# 11    Plundering  1489    1441         2930   0.5082
# 8        Goblins  1453    1459         2912   0.4990
# 0     Aggressive  1456    1510         2966   0.4909
# 9         Morbid  1319    1544         2863   0.4607
# 4        Dragons  1322    1605         2927   0.4517
# 6    Flourishing  1309    1599         2908   0.4501
# 7       Gambling  1114    1747         2861   0.3894
