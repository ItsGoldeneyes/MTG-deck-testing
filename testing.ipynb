# %%
from packages.database_tools import connect
conn, cur = connect()

import pandas as pd
# Out:
# Connected to PostgreSQL

# %%
from collections import defaultdict

def fetch_job_results(job_id=None):
    if job_id is None:
        query = """
        SELECT * FROM games
        WHERE job_id = (SELECT job_id FROM games WHERE finished_on IS NOT NULL ORDER BY finished_on DESC LIMIT 1)
        """
    else:
        query = f"""
        SELECT * FROM games
        WHERE job_id = '{job_id}'
        """
    
    cur.execute(query)
    results = cur.fetchall()
    df = pd.DataFrame(results, columns=[desc[0] for desc in cur.description])
    return df

def get_deck_stats(df):
    combination_stats = defaultdict(lambda: {'games': 0, 'wins': 0})
    single_stats = defaultdict(lambda: {'games': 0, 'wins': 0})
    
    for _, row in df.iterrows():
        # Deck 1
        d1 = row['deck1_name']
        d1_wins = row['deck1_wins']
        if d1:
            combination_stats[d1]['games'] += row['game_count']
            combination_stats[d1]['wins'] += d1_wins
            # Sub-decks
            for part in d1.split():
                single_stats[part]['games'] += row['game_count']
                single_stats[part]['wins'] += d1_wins

        # Deck 2
        d2 = row['deck2_name']
        d2_wins = row['deck2_wins']
        if d2:
            combination_stats[d2]['games'] += row['game_count']
            combination_stats[d2]['wins'] += d2_wins
            for part in d2.split():
                single_stats[part]['games'] += row['game_count']
                single_stats[part]['wins'] += d2_wins

        # Deck 3
        d3 = row['deck3_name']
        d3_wins = row['deck3_wins']
        if d3:
            combination_stats[d3]['games'] += row['game_count']
            combination_stats[d3]['wins'] += d3_wins
            for part in d3.split():
                single_stats[part]['games'] += row['game_count']
                single_stats[part]['wins'] += d3_wins

        # Deck 4
        d4 = row['deck4_name']
        d4_wins = row['deck4_wins']
        if d4:
            combination_stats[d4]['games'] += row['game_count']
            combination_stats[d4]['wins'] += d4_wins
            for part in d4.split():
                single_stats[part]['games'] += row['game_count']
                single_stats[part]['wins'] += d4_wins

    # Convert to DataFrame
    combination_stats_df = pd.DataFrame([
        {'deck': k, 'games': v['games'], 'wins': v['wins'], 'win_rate': v['wins'] / v['games'] if v['games'] > 0 else 0}
        for k, v in combination_stats.items()
    ])
    single_stats_df = pd.DataFrame([
        {'deck': k, 'games': v['games'], 'wins': v['wins'], 'win_rate': v['wins'] / v['games'] if v['games'] > 0 else 0}
        for k, v in single_stats.items()
    ])
    combination_stats_df = combination_stats_df.sort_values(by='games', ascending=False).reset_index(drop=True)
    single_stats_df = single_stats_df.sort_values(by='games', ascending=False).reset_index(drop=True)
    return combination_stats_df, single_stats_df

def get_subdeck_stats(df):
    stats = defaultdict(lambda: {'games': 0, 'wins': 0})

    for _, row in df.iterrows():
        for i in range(1, 5):
            deck_name = row.get(f'deck{i}_name')
            deck_wins = row.get(f'deck{i}_wins')
            game_count = row.get('game_count')
            if deck_name and isinstance(deck_name, str):
                for part in deck_name.split():
                    stats[part]['games'] += game_count
                    stats[part]['wins'] += deck_wins

    stats_df = pd.DataFrame([
        {'subdeck': k, 'games': v['games'], 'wins': v['wins'], 'win_rate': v['wins'] / v['games'] if v['games'] > 0 else 0}
        for k, v in stats.items()
    ])
    stats_df = stats_df.sort_values(by='games', ascending=False).reset_index(drop=True)
    return stats_df

# %%
cur.execute("SELECT job_id FROM games WHERE finished_on IS NOT NULL ORDER BY finished_on;")
job_id = cur.fetchone()[0]
job_id
# Out:
# 'f4a32d0d-7ed1-4502-a897-93f0cdc54eec'

# %%
df = fetch_job_results(job_id)
# Out:
# ---------------------------------------------------------------------------
# InFailedSqlTransaction                    Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = fetch_job_results(job_id)
#
# Cell In[10], line 15, in fetch_job_results(job_id)
#       9 else:
#      10     query = f"""
#      11     SELECT * FROM games
#      12     WHERE job_id = "{job_id}"
#      13     """
# ---> 15 cur.execute(query)
#      16 results = cur.fetchall()
#      17 df = pd.DataFrame(results, columns=[desc[0] for desc in cur.description])
#
# InFailedSqlTransaction: current transaction is aborted, commands ignored until end of transaction block

# %%
combo_df, single_df = get_deck_stats(df)

# %%
combo_df.head()
# Out:
#                       deck  games  wins  win_rate
# 0  Aggressive Bloodthirsty   3250   746  0.229538
# 1         Beefy Aggressive   3250    26  0.008000
# 2       Bloodthirsty Dinos   3250    28  0.008615
# 3            Goblins Dinos   3250     0  0.000000
# 4  Necromancy Bloodthirsty   3250     0  0.000000

# %%
single_df.head()
# Out:
#            deck  games  wins  win_rate
# 0    Aggressive  35750   883  0.024699
# 1  Bloodthirsty  35750   869  0.024308
# 2   Flourishing  35750   133  0.003720
# 3         Beefy  35750   293  0.008196
# 4      Gambling  35750    65  0.001818

# %%
df_high_wins = df[(df['deck1_wins'] > 9) | (df['deck2_wins'] > 9)]
df_high_wins
# Out:
#                                primary_key               deck1_name
# 1     561c063f-f970-439f-96e0-afd827995d5b  Aggressive Bloodthirsty  \
# 12    5b896178-c538-4f23-9c0c-d969752fb909  Aggressive Bloodthirsty
# 13    73ce55e1-5eeb-401a-ad09-204274047689  Aggressive Bloodthirsty
# 15    f344f004-3f00-40aa-8a54-cdf3231bc71a  Aggressive Bloodthirsty
# 21    b514ed99-3dfe-4349-9ee4-50a77b6ae2d6  Aggressive Bloodthirsty
# 30    77b66d95-5ab9-496a-8ac2-8bed5e741d18  Aggressive Bloodthirsty
# 31    93c9eadf-6f0f-4415-be6c-d3731e310f1b  Aggressive Bloodthirsty
# 32    d63d05ca-a129-4b43-b415-f93750c6d353  Aggressive Bloodthirsty
# 34    51b7db88-a0a8-42df-aa21-f63711b1a02a  Aggressive Bloodthirsty
# 2120  d50c0f1e-c33f-402f-966c-b78b39205e50  Aggressive Bloodthirsty
# 2121  32b1c96c-f0d6-43ba-b46a-911a0afd4d61  Aggressive Bloodthirsty
# 2122  789339e8-c329-4f1e-bd49-b83398959694  Aggressive Bloodthirsty
# 2123  3076cb49-02e8-4ad2-a834-4235d1f058e5  Aggressive Bloodthirsty
# 2124  5e403374-a635-426b-803b-8e526f0edf89  Aggressive Bloodthirsty
# 2125  7cc7472d-ddc5-4f58-95a4-dad23cfb8fc3  Aggressive Bloodthirsty
# 2120  89fae921-6800-4f4c-9839-5647476403c6          50          27
# 2121  89fae921-6800-4f4c-9839-5647476403c6          50          24
# 2122  89fae921-6800-4f4c-9839-5647476403c6          50          18
# 2123  89fae921-6800-4f4c-9839-5647476403c6          50          31
# 2124  89fae921-6800-4f4c-9839-5647476403c6          50          25
# 2125  89fae921-6800-4f4c-9839-5647476403c6          50          29
# 2126  89fae921-6800-4f4c-9839-5647476403c6          50          29
# 2131  89fae921-6800-4f4c-9839-5647476403c6          50          23
# 2132  89fae921-6800-4f4c-9839-5647476403c6          50          13
# 2133  89fae921-6800-4f4c-9839-5647476403c6          50          22
# 2134  89fae921-6800-4f4c-9839-5647476403c6          50          31
# 2135  89fae921-6800-4f4c-9839-5647476403c6          50          34
# 2136  89fae921-6800-4f4c-9839-5647476403c6          50          35
# 2137  89fae921-6800-4f4c-9839-5647476403c6          50          27
# 2138  89fae921-6800-4f4c-9839-5647476403c6          50          21
# 2140  89fae921-6800-4f4c-9839-5647476403c6          50          25
# 2141  89fae921-6800-4f4c-9839-5647476403c6          50          11
# 2142  89fae921-6800-4f4c-9839-5647476403c6          50          35
# 2143  89fae921-6800-4f4c-9839-5647476403c6          50          15
# 2144  89fae921-6800-4f4c-9839-5647476403c6          50          26
#
#       deck2_wins  deck3_wins  deck4_wins
# 1             26           0           0  \
# 12            27           0           0
# 13            19           0           0
# 15            24           0           0
# 21            20           0           0
# 30            20           0           0
# 31            20           0           0
# 32            21           0           0
# 34            28           0           0
# 2120          23           0           0
# 2121          26           0           0
# 2122          32           0           0
# 2123          19           0           0
# 2124          25           0           0
# 2125          21           0           0
# 2126          21           0           0
# 2131          27           0           0
# 2132          37           0           0
# 2133          28           0           0
# 2134          19           0           0
# 2135          16           0           0
# 2136          15           0           0
# 2137          23           0           0
# 2138          29           0           0
# 2140          25           0           0
# 2141          39           0           0
# 2142          15           0           0
# 2143          35           0           0
# 2144          24           0           0
#
#                                             turn_counts
# 1     [8, 7, 13, 13, 10, 7, 9, 9, 9, 9, 11, 7, 8, 7,...  \
# 12    [8, 8, 11, 10, 7, 8, 9, 9, 10, 13, 8, 11, 9, 1...
# 13    [9, 7, 9, 9, 14, 9, 12, 10, 8, 8, 7, 10, 6, 10...
# 15    [9, 7, 9, 9, 11, 8, 9, 8, 7, 9, 19, 14, 10, 10...
# 21    [9, 8, 10, 11, 10, 8, 10, 9, 7, 9, 10, 15, 6, ...
# 30    [8, 12, 12, 7, 10, 25, 8, 9, 11, 9, 8, 8, 8, 6...
# 31    [11, 9, 10, 7, 8, 8, 8, 7, 12, 7, 9, 8, 6, 7, ...
# 32    [11, 10, 9, 10, 7, 9, 6, 7, 8, 9, 8, 11, 10, 6...
# 34    [9, 8, 7, 10, 11, 8, 14, 8, 9, 11, 14, 8, 8, 9...
# 2120  [9, 10, 10, 10, 8, 7, 7, 6, 10, 9, 10, 8, 10, ...
# 2121  [6, 8, 10, 7, 6, 8, 8, 7, 9, 9, 7, 9, 8, 6, 14...
# 2122  [8, 8, 6, 9, 7, 10, 7, 8, 9, 13, 7, 9, 8, 9, 7...
# 2123  [8, 7, 8, 7, 10, 7, 7, 7, 9, 8, 7, 8, 12, 10, ...
# 2124  [12, 10, 8, 8, 14, 8, 12, 11, 14, 9, 11, 9, 8,...
# 2125  [7, 12, 6, 9, 10, 12, 10, 14, 10, 10, 11, 7, 1...
# 2126  [11, 13, 11, 24, 10, 7, 12, 8, 8, 10, 10, 13, ...
# 2131  [13, 9, 11, 8, 8, 9, 6, 8, 8, 11, 10, 8, 13, 1...
# 2132  [11, 7, 7, 9, 11, 12, 9, 8, 7, 7, 8, 9, 11, 9,...
# 2133  [9, 9, 6, 6, 9, 8, 8, 8, 8, 8, 5, 7, 7, 6, 9, ...
# 2134  [13, 9, 7, 12, 12, 7, 9, 10, 6, 9, 8, 9, 8, 9,...
# 2135  [6, 10, 8, 10, 9, 9, 6, 13, 7, 8, 7, 9, 7, 7, ...
# 2136  [10, 11, 9, 10, 9, 9, 8, 9, 7, 7, 8, 6, 8, 9, ...
# 2137  [9, 13, 11, 8, 9, 9, 9, 10, 12, 10, 11, 10, 9,...
# 2138  [6, 11, 7, 9, 7, 10, 7, 11, 8, 6, 11, 10, 9, 9...
# 2140  [12, 10, 10, 8, 8, 8, 9, 7, 7, 11, 12, 8, 9, 9...
# 2141  [8, 8, 9, 8, 11, 10, 10, 8, 8, 10, 7, 7, 8, 11...
# 2142  [8, 9, 8, 9, 9, 8, 7, 10, 12, 6, 12, 8, 12, 7,...
# 2143  [11, 11, 8, 8, 13, 10, 16, 9, 10, 9, 10, 8, 14...
# 2144  [8, 8, 10, 8, 8, 15, 8, 7, 8, 17, 10, 9, 13, 9...
#
#                                  device_id     format
# 1     9f229602-c78c-4859-b4c6-b53fbc1c5042  jumpstart  \
# 12    9f229602-c78c-4859-b4c6-b53fbc1c5042  jumpstart
# 13    c7980169-fdca-4130-a51a-719b66849bf0  jumpstart
# 15    c7980169-fdca-4130-a51a-719b66849bf0  jumpstart
# 21    9f229602-c78c-4859-b4c6-b53fbc1c5042  jumpstart
# 30    9f229602-c78c-4859-b4c6-b53fbc1c5042  jumpstart
# 31    c7980169-fdca-4130-a51a-719b66849bf0  jumpstart
# 32    c7980169-fdca-4130-a51a-719b66849bf0  jumpstart
# 34    c7980169-fdca-4130-a51a-719b66849bf0  jumpstart
# 2120  9f229602-c78c-4859-b4c6-b53fbc1c5042  jumpstart
# 2121  9f229602-c78c-4859-b4c6-b53fbc1c5042  jumpstart
# 2122  9f229602-c78c-4859-b4c6-b53fbc1c5042  jumpstart
# 2123  9f229602-c78c-4859-b4c6-b53fbc1c5042  jumpstart
# 2124  9f229602-c78c-4859-b4c6-b53fbc1c5042  jumpstart
# 2125  9f229602-c78c-4859-b4c6-b53fbc1c5042  jumpstart
# 2126  9f229602-c78c-4859-b4c6-b53fbc1c5042  jumpstart
# 2131  9f229602-c78c-4859-b4c6-b53fbc1c5042  jumpstart
